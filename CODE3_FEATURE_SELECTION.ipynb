# %%
import numpy as np
import pandas as pd
import gc
import time
from contextlib import contextmanager
from lightgbm import LGBMClassifier
from sklearn.metrics import roc_auc_score, roc_curve
from sklearn.model_selection import KFold, StratifiedKFold
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
# pandas and numpy for data manipulation
import pandas as pd
import numpy as np

# matplotlib and seaborn for plotting
import matplotlib.pyplot as plt
import seaborn as sns

# Suppress warnings from pandas
import warnings
warnings.filterwarnings('ignore')

plt.style.use('fivethirtyeight')

# Memory management
import gc 
import lightgbm as lgb

# utilities
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
from sklearn.metrics import roc_auc_score
from sklearn.preprocessing import LabelEncoder

# %%
#from pandas_profiling import ProfileReport
#import lux

import numpy as np
import pandas as pd

# matplotlib and seaborn for plotting
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline 

import scipy
import scipy.stats as stats
from scipy.stats import normaltest
import gc

# File system manangement
import os

# Suppress warnings 
import warnings
warnings.filterwarnings('ignore')

from sklearn.preprocessing import OneHotEncoder
from sklearn.preprocessing import OrdinalEncoder
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.impute import SimpleImputer
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split

from sklearn.model_selection import train_test_split

from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.linear_model import SGDClassifier
from sklearn.ensemble import RandomForestClassifier

from sklearn.calibration import CalibratedClassifierCV
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import roc_auc_score, precision_recall_curve, roc_curve, average_precision_score

from sklearn.model_selection import KFold
from lightgbm import LGBMClassifier


from sklearn.compose import ColumnTransformer
from sklearn.decomposition import PCA
from sklearn.linear_model  import LogisticRegression


from sklearn.ensemble import (
    RandomForestClassifier,
    BaggingClassifier,
    AdaBoostClassifier,
)

from sklearn.feature_selection import (
    f_classif,
    f_regression,
    mutual_info_classif, 
    mutual_info_regression,
    VarianceThreshold
)
# to select the features
from sklearn.feature_selection import SelectKBest, SelectPercentile

# wrapper methods
from mlxtend.feature_selection import SequentialFeatureSelector as SFS
from sklearn.ensemble import RandomForestRegressor, RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier, GradientBoostingRegressor
from sklearn.metrics import roc_auc_score, r2_score

from mlxtend.feature_selection import ExhaustiveFeatureSelector as EFS

# embedded methods
from sklearn.linear_model import LogisticRegression
from sklearn.feature_selection import SelectFromModel
from sklearn.feature_selection import RFE


# imblearn
from imblearn.over_sampling import SMOTE
from imblearn.under_sampling import (
    TomekLinks,
    EditedNearestNeighbours,
)

from imblearn.over_sampling import (
    RandomOverSampler,
    SMOTE,
    ADASYN,
    BorderlineSMOTE,
    SVMSMOTE,
    SMOTENC,
    KMeansSMOTE
)

from imblearn.combine import SMOTEENN, SMOTETomek

import plotly.offline as py
import plotly.graph_objs as go
from plotly.offline import init_notebook_mode, iplot

from pycaret.classification import *

# %% [markdown]
# # COMMON FUNCTIONS

# %%
def discover_app_train_features(feature,label_rotation=False,horizontal_layout=True):
    temp = app_train[feature].value_counts()
    df1 = pd.DataFrame({feature: temp.index,'Loan Contract Distribution': temp.values})

    # Calculate the percentage of target=1 per category value
    cat_perc = app_train[[feature, 'TARGET']].groupby([feature],as_index=False).mean()
    cat_perc['TARGET'] = cat_perc['TARGET']*100
    
    cat_perc.sort_values(by='TARGET', ascending=False, inplace=True)
    #print(df1.head())
    tot = df1['Loan Contract Distribution'].sum()
    df1['Loan Contract Distribution'] = round(df1['Loan Contract Distribution'] / tot * 100)
    
    if(horizontal_layout):
        fig, (ax1, ax2) = plt.subplots(ncols=2, figsize=(12,6))
    else:
        fig, (ax1, ax2) = plt.subplots(nrows=2, figsize=(12,14))
    sns.set_color_codes("pastel")
    

    
    s = sns.barplot(ax=ax1, x = feature, y="Loan Contract Distribution",data=df1)
    for index, row in df1.iterrows():
        s.text(row.name,row[1], row[1], color='black', ha="center")        
    if(label_rotation):
        s.set_xticklabels(s.get_xticklabels(),rotation=90)
    
    s = sns.barplot(ax=ax2, x = feature, y='TARGET', order=cat_perc[feature], data=cat_perc)
    for index, row in cat_perc.iterrows():
        s.text(row.name,row[1], round(row[1],0), color='black', ha="center")        
    if(label_rotation):
        s.set_xticklabels(s.get_xticklabels(),rotation=90)
    plt.ylabel('Loan Default Percentages [%]', fontsize=10)
    plt.tick_params(axis='both', which='major', labelsize=10)

    plt.show();

# %%
# Function to display box plot for univariate analysis 
def disp_boxplot(column):
    plt.figure(figsize=[10,2])
    sns.boxplot(column)
    plt.show()
    
# Function to cap the higher outliers of  the column to the 99 quantile value
def cap_higher_range(df,col_name): 
    q2 = df[col_name].quantile(0.99)
    df[col_name][df[col_name]>=q2]=q2

# %%
def findnulls(df): 
    collist = []
    for col in df.columns : 
        if df[col].isnull().sum() > 0 :
            print (col)
            print (df[col].isnull().sum() * 100 / len(df[col]))

# %%
def display_importances(feature_importance_df_):
    # Plot feature importances
    cols = feature_importance_df_[["feature", "importance"]].groupby("feature").mean().sort_values(
        by="importance", ascending=False)[:50].index
    
    best_features = feature_importance_df_.loc[feature_importance_df_.feature.isin(cols)]
    
    plt.figure(figsize=(8,10))
    sns.barplot(x="importance", y="feature", 
                data=best_features.sort_values(by="importance", ascending=False))
    plt.title('Dataset Important Features ')
    plt.tight_layout()

# %%
def discover_feature_importance(feat_importance):
    feats = [f for f in data.columns if f not in ['SK_ID_CURR']]
    n_fold = 0
    feature_importance_df = pd.DataFrame()
    fold_importance_df = pd.DataFrame()
    fold_importance_df["feature"] = feats
    fold_importance_df["importance"] = feat_importance
    fold_importance_df["fold"] = n_fold + 1
    feature_importance_df = pd.concat([feature_importance_df, fold_importance_df], axis=0)
    display_importances(feature_importance_df)

# %%
def plot_distribution(feature,color):
    plt.figure(figsize=(10,6))
    plt.title("Distribution of %s" % feature)
    sns.distplot(app_train[feature].dropna(),color=color, kde=True,bins=100)
    plt.show()

# %%
# Plot distribution of multiple features, with TARGET = 1/0 on the same graph
def plot_distribution_comp(var,nrow=2):
    
    i = 0
    t1 = app_train.loc[app_train['TARGET'] != 0]
    t0 = app_train.loc[app_train['TARGET'] == 0]

    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(nrow,2,figsize=(12,6*nrow))

    for feature in var:
        i += 1
        plt.subplot(nrow,2,i)
        sns.kdeplot(t1[feature], bw=0.5,label="TARGET = 1")
        sns.kdeplot(t0[feature], bw=0.5,label="TARGET = 0")
        plt.ylabel('Density plot', fontsize=12)
        plt.xlabel(feature, fontsize=12)
        locs, labels = plt.xticks()
        plt.tick_params(axis='both', which='major', labelsize=12)
    plt.show();

# %%
def plot_box_comp(var,nrow=2):
    
    i = 0

    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(nrow,2,figsize=(12,3*nrow))

    for feature in var:
        i += 1
        plt.subplot(nrow,2,i)
        #plt.subplot(2,2,i)
        sns.boxplot(app_train[feature])
        plt.xlabel(feature, fontsize=12)
        locs, labels = plt.xticks()
        plt.tick_params(axis='both', which='major', labelsize=12)
        
    plt.show();

def plot_distribution_comp(var,nrow=2):
    
    i = 0
    t1 = app_train.loc[app_train['TARGET'] != 0]
    t0 = app_train.loc[app_train['TARGET'] == 0]

    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(nrow,2,figsize=(12,6*nrow))

    for feature in var:
        i += 1
        plt.subplot(nrow,2,i)
        sns.kdeplot(t1[feature], bw=0.5,label="TARGET = 1")
        sns.kdeplot(t0[feature], bw=0.5,label="TARGET = 0")
        plt.ylabel('Density plot', fontsize=12)
        plt.xlabel(feature, fontsize=12)
        locs, labels = plt.xticks()
        plt.tick_params(axis='both', which='major', labelsize=12)
    plt.show();

# %% [markdown]
# #### Encode Categorical features

# %%
# function to obtain Categorical Features
def _get_categorical_features(df):
    feats = [col for col in list(df.columns) if df[col].dtype == 'object']
    return feats

# function to factorize categorical features
def _factorize_categoricals(df, cats):
    for col in cats:
        df[col], _ = pd.factorize(df[col])
    return df 

# function to create dummy variables of categorical features
def _get_dummies(df, cats):
    for col in cats:
        df = pd.concat([df, pd.get_dummies(df[col], prefix=col)], axis=1)
    return df 

def applyLabelEncoding(df, collist):
    le = LabelEncoder()
    le_count = 0
    for col in collist:
        le.fit(app_train[col])
        # Transform both training and testing data
        df[col] = le.transform(df[col])
    return df

def _applyLabelEncoding(df,collist):
    le = LabelEncoder()
    le_count = 0
    for col in collist :
        le.fit(df[col])
        # Transform both training and testing data
        df[col] = le.transform(df[col])
        
    return df 

def CategoricalEncoding_WOE(df,variable,target_variable):
    # now we calculate the probability of target=1 
    prob_df = df.groupby([variable])[target_variable].mean()
    prob_df = pd.DataFrame(prob_df)
    
    # and now the probability of target = 0 
    # and we add it to the dataframe
    prob_df['target_0'] = 1-prob_df[target_variable]
    prob_df.loc[prob_df[target_variable] == 0, target_variable] = 0.001
    prob_df['WoE'] = np.log(prob_df[target_variable]/prob_df['target_0'])
    ordered_labels = prob_df['WoE'].to_dict()
    df[variable+'_ordered'] = df[variable].map(ordered_labels)
    
def apply_feat_encoding(df):
    feats = [col for col in list(df.columns) if df[col].dtype == 'object']
    labelencodedfeaturelist =  [col for col in feats if df[col].nunique() <= 3]
    woefeaturelist = [col for col in feats if df[col].nunique() > 3]
    df = _applyLabelEncoding(df,labelencodedfeaturelist)
    target = 'TARGET'
    for col in woefeaturelist:
        CategoricalEncoding_WOE(df,col,target)
    df.drop(woefeaturelist, axis = 1, inplace=True)    
    return df

# get categorical features
#data_cats = _get_categorical_features(data)
#prev_app_cats = _get_categorical_features(previous_application)
#bureau_cats = _get_categorical_features(bureau)
#pcb_cats = _get_categorical_features(pcb)
#ccbal_cats = _get_categorical_features(credit_card_balance)

# create additional dummy features - 
#previous_application = _get_dummies(previous_application, prev_app_cats)
#bureau = _get_dummies(bureau, bureau_cats)
#pcb = _get_dummies(pcb, pcb_cats)
#credit_card_balance = _get_dummies(credit_card_balance, ccbal_cats)

# factorize the categorical features from train and test data
#data = _factorize_categoricals(data, data_cats)

# %% [markdown]
# ### Missing value functions

# %%
def find_missing_columns(df):
    for col in df.columns:
        if df[col].isnull().sum() > 0:
            print (col)
            print (df[col].isnull().sum()* 100 / len(df[col]))

# %%
def fill_missing_columns(df):
    for col in df.columns:
        if df[col].isnull().sum() > 0:
            df[col].fillna(0, inplace = True)

# %%
def fill_missing_columns_other_than_target(df):
    for col in df.columns:
        if df[col].isnull().sum() > 0:
            if col != 'TARGET':
                df[col].fillna(0, inplace = True)

# %%
def get_column_categories(df):
    categorical_columns = []
    for col in df.columns:
        if df[col].dtype in ['object']:
            categorical_columns.append(col)
    numerical_columns = []
    for col in df.columns:
        if col not in categorical_columns:
            numerical_columns.append(col)
    return categorical_columns, numerical_columns

def normal_test(df, significance = .01):
    """
    Function to perform ks test and test against normal distribution using  
    D’Agostino, R. B. (1971), “An omnibus test of normality for moderate and large sample size”
    
    frame: a pandas dataframe
    significance: float. Alpha level for which the null hypotesis will be rejected (H0: series comes from a normal distribution)
    plot: Boolean, whether or not plot a histogram for resulting columns
    
    returns a dataframe with only those columns that follow a normal distribution according to test.
"""
    columns = df.columns.tolist()
    non_normal_columns = []

    for col in columns:
        aux = df[col]
    
        _, p = normaltest(aux)
    
        if p <= significance:
            # col is not normally distributed
            non_normal_columns.append(col)
        
    normal_columns = [cols for cols in columns if cols not in non_normal_columns]
    return normal_columns, non_normal_columns

# Outlier treatment for Normal distribution
#Treating outliers with top coding-Any value greater than maximum limit will be capped at maximum
def outliers_TopCoding_gaussian(df,variable):
    # top coding: upper boundary for outliers according to gaussian rule
    Upper_fence = df[variable].mean()+3*df[variable].std()
    df.loc[df[variable]>Upper_fence, variable] = Upper_fence
    
    
#Treating outliers with top coding-Any value less than minimum limit will be capped at minimum
def outliers_BottomCoding_gaussian(df,variable):
    # bottom coding: lower boundary for outliers according to gaussian rule
    Lower_fence = df[variable].mean()-3*df[variable].std()
    df.loc[df[variable]<Lower_fence, variable] = Lower_fence    
    
#Outlier treatment for Non-Normal distribution
#Treating outliers with zero coding-Any value less than zero will be made zero
def outliers_ZeroCoding(X,variable):
    X.loc[X[variable]<0, variable] = 0
    
#Treating outliers with top coding-Any value greater than maximum limit will be capped at maximum
def outliers_TopCoding_quantile(df,variable):
    # top coding: upper boundary for outliers according to interquantile proximity rule
    IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)
    Upper_fence = df[variable].quantile(0.75) + (IQR * 3)
    df.loc[df[variable]>Upper_fence, variable] = Upper_fence
    
#Treating outliers with top coding-Any value less than minimum limit will be capped at minimum
def outliers_BottomCoding_quantile(df,variable):
    # bottom coding: lower boundary for outliers according to interquantile proximity rule
    IQR = df[variable].quantile(0.75) - df[variable].quantile(0.25)
    Lower_fence = df[variable].quantile(0.25) - (IQR * 3)
    df.loc[df[variable]<Lower_fence, variable] = Lower_fence

# %%
def disp_box(df,collist,nrow=3):
    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(nrow,2,figsize=(12,6*nrow))
    i = 0

    for col in collist:
        i += 1
        plt.subplot(nrow,2,i)
        sns.boxplot(df[col])
        plt.xlabel(col, fontsize=12)
        locs, labels = plt.xticks()
        plt.tick_params(axis='both', which='major', labelsize=12)
    plt.show()

def disp_dist(df,collist,nrow=3):

    sns.set_style('whitegrid')
    plt.figure()
    fig, ax = plt.subplots(nrow,2,figsize=(12,6*nrow))
    i = 0

    for col in collist:
        i += 1
        plt.subplot(nrow,2,i)
        sns.kdeplot(df[col], bw=0.5)
        plt.xlabel(col, fontsize=12)
        locs, labels = plt.xticks()
        plt.tick_params(axis='both', which='major', labelsize=12)
    plt.show()

# %%
@contextmanager
def timer(title):
    t0 = time.time()
    yield
    print("{} - done in {:.0f}s".format(title, time.time() - t0))

# %%
# One-hot encoding for categorical columns with get_dummies
def old_one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    categorical_columns = [col for col in df.columns if df[col].dtype == 'object']
    df = pd.get_dummies(df, columns= categorical_columns, dummy_na= nan_as_category)
    new_columns = [c for c in df.columns if c not in original_columns]
    return df, new_columns

# %%
def CategoricalEncoding_WOE(df,variable,target_variable):
    # now we calculate the probability of target=1 
    prob_df = df.groupby([variable])[target_variable].mean()
    prob_df = pd.DataFrame(prob_df)
    
    # and now the probability of target = 0 
    # and we add it to the dataframe
    prob_df['target_0'] = 1-prob_df[target_variable]
    prob_df.loc[prob_df[target_variable] == 0, target_variable] = 0.001
    prob_df['WoE'] = np.log(prob_df[target_variable]/prob_df['target_0'])
    ordered_labels = prob_df['WoE'].to_dict()
    df[variable+'_ordered'] = df[variable].map(ordered_labels)
    
def one_hot_encoder(df, nan_as_category = True):
    original_columns = list(df.columns)
    feats = [col for col in list(df.columns) if df[col].dtype == 'object']
    woefeaturelist = [col for col in feats if df[col].nunique() > 1]
    target = 'TARGET'
    for col in woefeaturelist:
        CategoricalEncoding_WOE(df,col,target)
    new_columns = [c for c in df.columns if c not in original_columns]
    df.drop(woefeaturelist, axis = 1, inplace=True)   
    
    return df, new_columns

# %%
def remove_columns_app_train(train):
    collist = []
    for col in train.columns:
        if (train[col].isnull().sum() *100 / len(train[col])) > 47 :
            if col.startswith('EXT_SOURCE') or col.startswith('HOUSETYPE_MODE') or col.startswith('EMERGENCYSTATE_MODE'):
                i=0
            else :
                collist.append(col)
    train.drop(collist, axis = 1, inplace=True)
    collist = []
    for col in train.columns:
        if col.startswith('FLAG_DOC'):
                collist.append(col)
    collist.remove('FLAG_DOCUMENT_3')
    train.drop(collist, axis = 1, inplace=True)
    columns_drop = ['AMT_REQ_CREDIT_BUREAU_HOUR','AMT_REQ_CREDIT_BUREAU_DAY','AMT_REQ_CREDIT_BUREAU_WEEK','AMT_REQ_CREDIT_BUREAU_MON','AMT_REQ_CREDIT_BUREAU_QRT']
    train.drop(columns_drop, axis = 1, inplace=True)
    


#    APPLICATION DATASET MISSING VALUE TREATMENT 
def treat_missing_values_app_train(train):
    # EXT_SOURCE_1 : 173378 entries ( 56%) have null values out of a total of 307511 Entries. The median value is 0.506. 
    train['EXT_SOURCE_1'].fillna(0.506, inplace = True)
    # EXT_SOURCE_2 : 660 entries have null values out of a total of 307511 Entries. The median value is 0.566. 
    train['EXT_SOURCE_2'].fillna(0.566, inplace = True)
    # EXT_SOURCE_3 : 60965 entries (19.8% )have null values out of a total of 307511 Entries. The median value is 0.535. 
    train['EXT_SOURCE_3'].fillna(0.535, inplace = True)
    # NAME_TYPE_SUITE : 1292 entries have null values out of 307511. Value imputed to "Unaccompanied" which is highest value 248526 for field
    train['NAME_TYPE_SUITE'].fillna("Unaccompanied", inplace = True)
    #DEF_30_CNT_SOCIAL_CIRCLE : 1021 entries have null values out of 307511. Missing value imputed to median value of 0.0
    train['DEF_30_CNT_SOCIAL_CIRCLE'].fillna(0.0, inplace = True)
    #DEF_60_CNT_SOCIAL_CIRCLE : 1021 entries have null values out of 307511. Missing value imputed to median value of 0.0
    train['DEF_60_CNT_SOCIAL_CIRCLE'].fillna(0.0, inplace = True)
    #OBS_30_CNT_SOCIAL_CIRCLE : 1021 entries have null values out of 307511. Missing value imputed to median value of 0.0
    train['OBS_30_CNT_SOCIAL_CIRCLE'].fillna(0.0, inplace = True)
    #OBS_60_CNT_SOCIAL_CIRCLE : 1021 entries have null values out of 307511. Missing value imputed to median value of 0.0
    train['OBS_60_CNT_SOCIAL_CIRCLE'].fillna(0.0, inplace = True)
    train['CNT_FAM_MEMBERS'] = train['CNT_FAM_MEMBERS'].fillna(0)
    train['HOUSETYPE_MODE'].fillna('block of flats', inplace=True)
    train['EMERGENCYSTATE_MODE'].fillna('No', inplace=True)
    train['OCCUPATION_TYPE'].fillna('Others', inplace=True)
   
    
    # TREAT THE AMT COLUMNS. FIX OUTLIERS AND ANOMALIES. REMOVE NULLS AND MISSING VALUES 
    for col in train.columns:
        if col.startswith('AMT'):
            train[col] = train[col] / 100000
    train['AMT_INCOME_TOTAL'][train['AMT_INCOME_TOTAL'] > 3] = 3
    train['AMT_INCOME_TOTAL'][train['AMT_INCOME_TOTAL'] < 0.5] = 0.5
    train['AMT_CREDIT'][train['AMT_CREDIT'] > 11] = 11
    train['AMT_ANNUITY'][train['AMT_ANNUITY'] > 0.45] = 0.45
    train['AMT_GOODS_PRICE'][train['AMT_GOODS_PRICE'] > 10] = 10
    for col in train.columns:
        if col.startswith('AMT'):
            train[col] = train[col] * 100000
    train['AMT_REQ_CREDIT_BUREAU_YEAR'][train['AMT_REQ_CREDIT_BUREAU_YEAR'] > 3.5] = 3.5
    for col in train.columns:
        if col.startswith('AMT'):
            if train[col].isnull().sum() > 0:
                #print (col)
                #print (train[col].isnull().sum() / len(train[col]*100))
                train[col].fillna(0, inplace = True)    

    train['CNT_CHILDREN'][train['CNT_CHILDREN'] > 5] = 5
    train['CNT_FAM_MEMBERS'][train['CNT_FAM_MEMBERS'] > 5] = 5
    train['REGION_POPULATION_RELATIVE'][train['REGION_POPULATION_RELATIVE'] > 0.05] = 0.05
    train['OBS_30_CNT_SOCIAL_CIRCLE'][train['OBS_30_CNT_SOCIAL_CIRCLE'] > 10] = 10
    train['OBS_60_CNT_SOCIAL_CIRCLE'][train['OBS_60_CNT_SOCIAL_CIRCLE'] > 10] = 10
    train['DEF_30_CNT_SOCIAL_CIRCLE'][train['DEF_30_CNT_SOCIAL_CIRCLE'] > 3] = 3
    train['DEF_60_CNT_SOCIAL_CIRCLE'][train['DEF_60_CNT_SOCIAL_CIRCLE'] > 3] = 3
                
    
    # TREAT THE DAYS COLUMNS. FIX OUTLIERS AND ANOMALIES. REMOVE NULLS AND MISSING VALUES 
    for col in train.columns:
        if col.startswith('DAY'):
            if train[col].isnull().sum() > 0:
                train[col].fillna(0, inplace = True)
            train[col] = train[col] / 365
    train['DAYS_EMPLOYED'][train['DAYS_EMPLOYED'] > 1000] = 0
    train['DAYS_EMPLOYED'][train['DAYS_EMPLOYED'] < -10] = -10
    train['DAYS_REGISTRATION'][train['DAYS_REGISTRATION'] < -27] = -27
    train['DAYS_LAST_PHONE_CHANGE'][train['DAYS_LAST_PHONE_CHANGE'] < -6] =-6
    # FIX ANOMALIES AND MISSING VALUES
    train['CODE_GENDER'].value_counts()
    train['CODE_GENDER'].replace('XNA', 'F', inplace =True)
    

    return train

# %%
#            BUREAU MISSING VALUE TREATMENT 
def treat_missing_values_bureau(df_bueau):
    df_bueau['DAYS_CREDIT_ENDDATE'][df_bueau['DAYS_CREDIT_ENDDATE'] < -2300] = -2300
    df_bueau['DAYS_CREDIT_ENDDATE'][df_bueau['DAYS_CREDIT_ENDDATE'] > 1600] = 1600
    df_bueau['DAYS_ENDDATE_FACT'][df_bueau['DAYS_ENDDATE_FACT'] < -2000] = -2000
    df_bueau['AMT_CREDIT_SUM'][df_bueau['AMT_CREDIT_SUM'] > 500000] = 500000
    df_bueau['AMT_CREDIT_SUM_DEBT'][df_bueau['AMT_CREDIT_SUM_DEBT'] > 50000]  = 50000
    df_bueau['AMT_CREDIT_SUM_DEBT'][df_bueau['AMT_CREDIT_SUM_DEBT'] < -600] = -600
    df_bueau['DAYS_CREDIT_UPDATE'][df_bueau['DAYS_CREDIT_UPDATE'] < -1500] = -1500
    df_bueau['DAYS_CREDIT_ENDDATE'].fillna(-330, inplace =True)
    df_bueau['AMT_CREDIT_SUM'].fillna(125518.5, inplace = True)
    df_bueau['DAYS_ENDDATE_FACT'].fillna(-897, inplace =True)
    df_bueau['AMT_CREDIT_SUM_DEBT'].fillna(0, inplace =True)
    # CREDIT_DAY_OVERDUE majority are 0.. can be dropped
    # only 7 % of data is above zero
    # CNT_CREDIT_PROLONG only 0.5% of data is above zero
    #AMT_CREDIT_SUM_LIMIT only a fraction of values are not zero
    return df_bueau

def remove_columns_bureau(df_bueau):
    coldrop = ['CREDIT_DAY_OVERDUE', 'AMT_CREDIT_MAX_OVERDUE','CNT_CREDIT_PROLONG','AMT_CREDIT_SUM_LIMIT','AMT_CREDIT_SUM_OVERDUE','AMT_ANNUITY'] 
    df_bueau.drop(coldrop, axis = 1, inplace=True)

# %%
#            PREV_APP MISSING VALUE TREATMENT 
def treat_missing_values_prev_app(df_prev_app):
    df_prev_app['AMT_ANNUITY'][df_prev_app['AMT_ANNUITY'] > 20000] = 20000
    df_prev_app['AMT_ANNUITY'][df_prev_app['AMT_ANNUITY'] < 5000] = 5000
    df_prev_app['AMT_APPLICATION'][df_prev_app['AMT_APPLICATION'] > 200000] = 200000
    df_prev_app['AMT_CREDIT'][df_prev_app['AMT_CREDIT'] > 250000] = 250000
    df_prev_app['AMT_GOODS_PRICE'][df_prev_app['AMT_GOODS_PRICE'] > 250000] = 250000
    df_prev_app['HOUR_APPR_PROCESS_START'][df_prev_app['HOUR_APPR_PROCESS_START'] >17] = 17
    df_prev_app['HOUR_APPR_PROCESS_START'][df_prev_app['HOUR_APPR_PROCESS_START'] <8] = 8
    df_prev_app['SELLERPLACE_AREA'][df_prev_app['SELLERPLACE_AREA'] > 100 ] = 100
    df_prev_app['DAYS_DECISION'][df_prev_app['DAYS_DECISION'] < -2000] = -2000
    df_prev_app['RATE_DOWN_PAYMENT'][df_prev_app['RATE_DOWN_PAYMENT'] >0.125] = 0.125
    df_prev_app['CNT_PAYMENT'][df_prev_app['CNT_PAYMENT'] > 25 ] = 25
    df_prev_app['DAYS_LAST_DUE'][df_prev_app['DAYS_LAST_DUE'] > 0 ] = 0
    df_prev_app['DAYS_LAST_DUE'][df_prev_app['DAYS_LAST_DUE'] <-1500 ] = -1500
    df_prev_app['DAYS_LAST_DUE_1ST_VERSION'][df_prev_app['DAYS_LAST_DUE_1ST_VERSION'] > 0 ]= 0
    df_prev_app['DAYS_LAST_DUE_1ST_VERSION'][df_prev_app['DAYS_LAST_DUE_1ST_VERSION'] < -1400 ] = -1400
    df_prev_app['DAYS_FIRST_DUE'][df_prev_app['DAYS_FIRST_DUE'] > -250 ] = -250
    df_prev_app['DAYS_DECISION'][df_prev_app['DAYS_DECISION'] < -1750 ] = -1750
    df_prev_app['DAYS_FIRST_DUE'][df_prev_app['DAYS_FIRST_DUE'] < -1700 ] = -1700
    df_prev_app['DAYS_TERMINATION'][df_prev_app['DAYS_TERMINATION'] > 0 ] = 0
    df_prev_app['DAYS_TERMINATION'][df_prev_app['DAYS_TERMINATION'] < -1700 ] = -1700
    df_prev_app['AMT_ANNUITY'].fillna(11250.0, inplace=True)
    df_prev_app['AMT_CREDIT'].fillna(80541.0, inplace=True)
    df_prev_app['AMT_GOODS_PRICE'].fillna(112320.0, inplace=True)
    df_prev_app['RATE_DOWN_PAYMENT'].fillna(0.0516, inplace=True)
    df_prev_app['CNT_PAYMENT'].fillna(12.0, inplace=True)
    df_prev_app['DAYS_FIRST_DUE'].fillna(-831.0, inplace=True)
    df_prev_app['DAYS_LAST_DUE_1ST_VERSION'].fillna(-361, inplace=True)
    df_prev_app['DAYS_LAST_DUE'].fillna(-537.0, inplace=True)
    df_prev_app['DAYS_TERMINATION'].fillna(-499.0, inplace=True)
    df_prev_app['NFLAG_INSURED_ON_APPROVAL'].fillna(0, inplace=True)
    df_prev_app['PRODUCT_COMBINATION'].fillna("Cash", inplace = True)
    df_prev_app['NAME_CONTRACT_TYPE'][df_prev_app['NAME_CONTRACT_TYPE'] == 'XNA'] = "Cash loans"
    return df_prev_app

def remove_columns_prev_app(df_prev_app):
    coldrop = ['DAYS_FIRST_DRAWING','AMT_DOWN_PAYMENT','RATE_INTEREST_PRIMARY','RATE_INTEREST_PRIVILEGED','NAME_TYPE_SUITE']
    df_prev_app.drop(coldrop, axis = 1, inplace=True)

# %%
#            POS_CASH_BAL MISSING VALUE TREATMENT 
def treat_missing_values_pos_cash_bal(df_pos_cash_bal):
    df_pos_cash_bal['CNT_INSTALMENT_FUTURE'][df_pos_cash_bal['CNT_INSTALMENT_FUTURE'] > 15 ] = 15
    df_pos_cash_bal['MONTHS_BALANCE'][df_pos_cash_bal['MONTHS_BALANCE'] < -70 ] = -70
    df_pos_cash_bal['CNT_INSTALMENT'][df_pos_cash_bal['CNT_INSTALMENT'] > 25 ] = 25
    df_pos_cash_bal['CNT_INSTALMENT'].fillna(12.0, inplace=True)
    df_pos_cash_bal['CNT_INSTALMENT_FUTURE'].fillna(7.0, inplace=True)
    return df_pos_cash_bal

def remove_columns_pos_cash_bal(df_pos_cash_bal):
    coldrop = ['SK_DPD','SK_DPD_DEF']
    df_pos_cash_bal.drop(coldrop, axis = 1, inplace=True)

# %%
#            CREDIT_CARD DATASET MISSING VALUE TREATMENT 
def treat_missing_values_cc_bal(df_cc_bal):
    df_cc_bal['AMT_ANNUITY'][df_cc_bal['AMT_ANNUITY'] > 25000 ] = 25000
    df_cc_bal['AMT_APPLICATION'][df_cc_bal['AMT_APPLICATION'] > 200000 ] = 200000
    df_cc_bal['AMT_GOODS_PRICE'][df_cc_bal['AMT_GOODS_PRICE'] > 300000 ] = 300000
    df_cc_bal['AMT_CREDIT'][df_cc_bal['AMT_CREDIT'] > 300000 ] = 300000
    df_cc_bal['HOUR_APPR_PROCESS_START'][df_cc_bal['HOUR_APPR_PROCESS_START'] > 17 ] = 17
    df_cc_bal['HOUR_APPR_PROCESS_START'][df_cc_bal['HOUR_APPR_PROCESS_START'] < 8 ] = 8
    df_cc_bal['RATE_DOWN_PAYMENT'][df_cc_bal['RATE_DOWN_PAYMENT'] >0.15] = 0.15
    df_cc_bal['DAYS_DECISION'][df_cc_bal['DAYS_DECISION'] < -1750 ] = -1750
    df_cc_bal['SELLERPLACE_AREA'][df_cc_bal['SELLERPLACE_AREA'] > 100 ] = 100
    df_cc_bal['CNT_PAYMENT'][df_cc_bal['CNT_PAYMENT'] > 25 ] = 25
    df_cc_bal['DAYS_LAST_DUE'][df_cc_bal['DAYS_LAST_DUE'] <-1500 ] = -1500
    df_cc_bal['DAYS_LAST_DUE_1ST_VERSION'][df_cc_bal['DAYS_LAST_DUE_1ST_VERSION'] > 0 ]= 0
    df_cc_bal['DAYS_LAST_DUE_1ST_VERSION'][df_cc_bal['DAYS_LAST_DUE_1ST_VERSION'] < -1400 ] = -1400
    df_cc_bal['DAYS_FIRST_DUE'][df_cc_bal['DAYS_FIRST_DUE'] > -250 ] = -250    
    df_cc_bal['DAYS_FIRST_DUE'][df_cc_bal['DAYS_FIRST_DUE'] < -1700 ] = -1700
    df_cc_bal['DAYS_TERMINATION'][df_cc_bal['DAYS_TERMINATION'] > 0 ] = 0
    df_cc_bal['DAYS_TERMINATION'][df_cc_bal['DAYS_TERMINATION'] < -1700 ] = -1700
    df_cc_bal['AMT_ANNUITY'].fillna(11250.0, inplace=True)
    df_cc_bal['AMT_CREDIT'].fillna(80541.0, inplace=True)
    df_cc_bal['AMT_GOODS_PRICE'].fillna(112320.0, inplace=True)
    df_cc_bal['RATE_DOWN_PAYMENT'].fillna(0.0516, inplace=True)
    df_cc_bal['CNT_PAYMENT'].fillna(12.0, inplace=True)
    df_cc_bal['DAYS_FIRST_DUE'].fillna(-831.0, inplace=True)
    df_cc_bal['DAYS_LAST_DUE_1ST_VERSION'].fillna(-361, inplace=True)
    df_cc_bal['DAYS_LAST_DUE'].fillna(-537.0, inplace=True)
    df_cc_bal['DAYS_TERMINATION'].fillna(-499.0, inplace=True)
    df_cc_bal['NFLAG_INSURED_ON_APPROVAL'].fillna(0, inplace=True)
    df_cc_bal['PRODUCT_COMBINATION'].fillna("Cash", inplace = True)
    df_cc_bal['NAME_CONTRACT_TYPE'][df_prev_app['NAME_CONTRACT_TYPE'] == 'XNA'] = "Cash loans"
    return df_cc_bal

def remove_columns_cc_bal(df_cc_bal):
    coldrop = ['DAYS_FIRST_DRAWING','AMT_DOWN_PAYMENT','RATE_INTEREST_PRIMARY','RATE_INTEREST_PRIVILEGED','NAME_TYPE_SUITE']
    df_cc_bal.drop(coldrop, axis = 1, inplace=True)

# %%
#            INSTALLMENT PAYMENT DATASET MISSING VALUE TREATMENT 
def treat_missing_values_inst_pay(df_inst_pay):
    df_inst_pay['AMT_PAYMENT'][df_inst_pay['AMT_PAYMENT'] > 30000 ] = 30000
    df_inst_pay['AMT_PAYMENT'].fillna(8125.515, inplace = True)
    df_inst_pay['AMT_INSTALMENT'][df_inst_pay['AMT_INSTALMENT'] > 30000 ] = 30000
    df_inst_pay['AMT_INSTALMENT'].fillna(8884.08, inplace = True)
    df_inst_pay['DAYS_ENTRY_PAYMENT'].fillna(-827.0, inplace = True)
    df_inst_pay['DAYS_ENTRY_PAYMENT'][df_inst_pay['DAYS_ENTRY_PAYMENT'] < -2000 ] = -2000
    df_inst_pay['DAYS_INSTALMENT'][df_inst_pay['DAYS_INSTALMENT'] < -2000 ] = -2000
    df_inst_pay['NUM_INSTALMENT_NUMBER'][df_inst_pay['NUM_INSTALMENT_NUMBER'] > 35 ] = 35    
    return df_inst_pay

# %% [markdown]
# # CLASS IMBALANCE TECHNIQUES

# %%
# method for testing
def run_method(method, df, target):
    class_cnt = df[target].value_counts()
    print('Before run size majority:{0}, minority:{1}'.format(class_cnt[0], class_cnt[1]))
    df_sampled = method(df,target)
    class_cnt = df_sampled[target].value_counts()
    print('After run size majority:{0}, minority:{1}'.format(class_cnt[0], class_cnt[1]))
    return df_sampled

# %%
def apply_adasyn_oversampling(df, target, strategy='auto'):
    
    # define oversampling strategy
    ada = ADASYN(
        sampling_strategy=strategy,  # samples only the minority class
        random_state=0,  # for reproducibility
        n_neighbors=5,
        n_jobs=4
    )   
    
    #separate train and test
    x_train = df.drop(columns=[target])
    y_train=df[target]
    
    # fit and apply the transform
    x_train_resampled, y_train_resampled = ada.fit_resample(x_train, y_train)
    
    # merging y to x
    x_train_resampled[target] = y_train_resampled
    return x_train_resampled

# %%
def apply_tomeklink_undersampling(df, target, strategy='auto'):
    
    # define oversampling strategy
    tl = TomekLinks(
        sampling_strategy=strategy,  # undersamples only the majority class
        n_jobs=4                   # I have 4 cores in my laptop
    )    
    
    # fit and apply the transform
    x_train = df.drop(columns=[target])
    y_train=df[target]
    x_train_resampled, y_train_resampled = tl.fit_resample(x_train, y_train)
    
    # merging y to x
    x_train_resampled[target] = y_train_resampled
    return x_train_resampled

# %%
def apply_editednearestneighbour_undersampling(df, target, strategy='majority'):
    
    # define oversampling strategy
    enn = EditedNearestNeighbours(
        sampling_strategy='auto',  # undersamples only the majority class
        n_neighbors=3,
        kind_sel='all',            # all neighbours need to have the same label as the observation examined
        n_jobs=4                   # I have 4 cores in my laptop 
    ) 
    
    # fit and apply the transform
    x_train = df.drop(columns=[target])
    y_train=df[target]
    x_train_resampled, y_train_resampled = enn.fit_resample(x_train, y_train)
    
    # merging y to x
    x_train_resampled[target] = y_train_resampled
    return x_train_resampled

# %%
def apply_smote_oversampling(df, target, strategy='auto'):
    sm = SMOTE(
        random_state=42,
        sampling_strategy=strategy,
        n_jobs=4
    )

    x_train = df.drop(columns=[target])
    y_train=df[target]
    
    x_train_sm, y_train_sm = sm.fit_resample(x_train, y_train)

    x_train_sm[target] = y_train_sm
    return x_train_sm

# %%
def apply_sm_tomek_sampling(df, target, strategy='auto'):
    
    # define oversampling strategy
    sm = SMOTE(
        sampling_strategy=strategy,  # samples only the minority class
        random_state=0,  # for reproducibility
        k_neighbors=5,
        n_jobs=4
    )
    
    # define under sampling strategy
    # need tomek as argument of SMOTETomek
    tl = TomekLinks(
        sampling_strategy='all',
        n_jobs=4)

    smtomek = SMOTETomek(
        sampling_strategy='auto',  # samples only the minority class
        random_state=0,  # for reproducibility
        smote=sm,
        tomek=tl,
        n_jobs=4
    )
    
    #separate train and test
    x_train = df.drop(columns=[target])
    y_train=df[target]
    
    # fit and apply the transform
    x_train_resampled, y_train_resampled = smtomek.fit_resample(x_train, y_train)
    
    # merging y to x
    x_train_resampled[target] = y_train_resampled
    return x_train_resampled

# %% [markdown]
# # FEATURE ENGINEERING METHODS

# %%
def feature_engineering_application_train_test(df):

    docs = [_f for _f in df.columns if 'FLAG_DOC' in _f]
    live = [_f for _f in df.columns if ('FLAG_' in _f) & ('FLAG_DOC' not in _f) & ('_FLAG_' not in _f)]
    inc_by_org = df[['AMT_INCOME_TOTAL', 'ORGANIZATION_TYPE']].groupby('ORGANIZATION_TYPE').median()['AMT_INCOME_TOTAL']
    #Annuity as a percentage of income 
    df['NEW_ANNUITY_TO_INCOME_RATIO'] = df['AMT_ANNUITY'] / (1 + df['AMT_INCOME_TOTAL'])
    #Annuity as a percentage of credit 
    df['NEW_CREDIT_TO_ANNUITY_RATIO'] = df['AMT_CREDIT'] / df['AMT_ANNUITY']
    #Available credit as a percentage of income
    df['NEW_CREDIT_TO_INCOME_RATIO'] = df['AMT_CREDIT'] / df['AMT_INCOME_TOTAL']    
    
    df['NEW_CREDIT_TO_GOODS_RATIO'] = df['AMT_CREDIT'] / df['AMT_GOODS_PRICE']
#    df['NEW_DOC_IND_AVG'] = df[docs].mean(axis=1)
#    df['NEW_DOC_IND_STD'] = df[docs].std(axis=1)
#    df['NEW_DOC_IND_KURT'] = df[docs].kurtosis(axis=1)
#    df['NEW_LIVE_IND_SUM'] = df[live].sum(axis=1)
#    df['NEW_LIVE_IND_STD'] = df[live].std(axis=1)
#    df['NEW_LIVE_IND_KURT'] = df[live].kurtosis(axis=1)
    df['NEW_INC_PER_CHLD'] = df['AMT_INCOME_TOTAL'] / (1 + df['CNT_CHILDREN'])
    df['NEW_INC_BY_ORG'] = df['ORGANIZATION_TYPE'].map(inc_by_org)
    df['NEW_EMPLOY_TO_BIRTH_RATIO'] = df['DAYS_EMPLOYED'] / df['DAYS_BIRTH']
    df['NEW_SOURCES_PROD'] = df['EXT_SOURCE_1'] * df['EXT_SOURCE_2'] * df['EXT_SOURCE_3']
    df['NEW_EXT_SOURCES_MEAN'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].mean(axis=1)
    df['NEW_SCORES_STD'] = df[['EXT_SOURCE_1', 'EXT_SOURCE_2', 'EXT_SOURCE_3']].std(axis=1)
    df['NEW_SCORES_STD'] = df['NEW_SCORES_STD'].fillna(df['NEW_SCORES_STD'].mean())
#    df['NEW_PHONE_TO_BIRTH_RATIO'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_BIRTH']
#    df['NEW_PHONE_TO_EMPLOY_RATIO'] = df['DAYS_LAST_PHONE_CHANGE'] / df['DAYS_EMPLOYED']

    return df

# %% [markdown]
# ### MODEL FUNCTIONS

# %%
def model(features, test_features, encoding = 'ohe', n_folds = 5):
    
    """Train and test a light gradient boosting model using
    cross validation. 
    
    Parameters
    --------
        features (pd.DataFrame): 
            dataframe of training features to use 
            for training a model. Must include the TARGET column.
        test_features (pd.DataFrame): 
            dataframe of testing features to use
            for making predictions with the model. 
        encoding (str, default = 'ohe'): 
            method for encoding categorical variables. Either 'ohe' for one-hot encoding or 'le' for integer label encoding
            n_folds (int, default = 5): number of folds to use for cross validation
        
    Return
    --------
        submission (pd.DataFrame): 
            dataframe with `SK_ID_CURR` and `TARGET` probabilities
            predicted by the model.
        feature_importances (pd.DataFrame): 
            dataframe with the feature importances from the model.
        valid_metrics (pd.DataFrame): 
            dataframe with training and validation metrics (ROC AUC) for each fold and overall.
        
    """
    submission = pd.DataFrame()
    feature_importances = pd.DataFrame()
    metrics = pd.DataFrame()

    # Extract the ids
    train_ids = features['SK_ID_CURR']
    test_ids = test_features['SK_ID_CURR']
    
    # Extract the labels for training
    labels = features['TARGET']
    features,test_features = features.align(test_features, join='inner',axis=1)
    
    # Remove the ids and target
    features = features.drop(columns = ['SK_ID_CURR', 'TARGET'])
    test_features = test_features.drop(columns = ['SK_ID_CURR','TARGET'])
    
    
        
    print('Training Data Shape: ', features.shape)
    print('Testing Data Shape: ', test_features.shape)
    
    # Extract feature names
    feature_names = list(features.columns)
    
    # Convert to np arrays
    features = np.array(features)
    test_features = np.array(test_features)
    
    # Create the kfold object
    k_fold = KFold(n_splits = n_folds, shuffle = False, random_state = 50)
    
    # Empty array for feature importances
    feature_importance_values = np.zeros(len(feature_names))
    
    # Empty array for test predictions
    test_predictions = np.zeros(test_features.shape[0])
    
    # Empty array for out of fold validation predictions
    out_of_fold = np.zeros(features.shape[0])
    
    # Lists for recording validation and training scores
    valid_scores = []
    train_scores = []
    
    # Iterate through each fold
    for train_indices, valid_indices in k_fold.split(features):
        
        # Training data for the fold
        train_features, train_labels = features[train_indices], labels[train_indices]
        # Validation data for the fold
        valid_features, valid_labels = features[valid_indices], labels[valid_indices]
        
        # Create the model
        model = lgb.LGBMClassifier( nthread=4,
            n_estimators=10000,
            learning_rate=0.02,
            num_leaves=34,
            colsample_bytree=0.9497036,
            subsample=0.8715623,
            max_depth=8,
            reg_alpha=0.071545473,
            reg_lambda=0.0935294,
            min_split_gain=0.0222415,
            min_child_weight=39.3259775,
            silent=-1,
            verbose=-1,)
        
        # Train the model
        model.fit(train_features, train_labels, eval_metric = 'auc',
                  eval_set = [(valid_features, valid_labels), (train_features, train_labels)],
                  eval_names = ['valid', 'train'],
                  early_stopping_rounds = 100, verbose = 200)
        
        # Record the best iteration
        best_iteration = model.best_iteration_
        
        # Record the feature importances
        feature_importance_values += model.feature_importances_ / k_fold.n_splits
        
        # Make predictions
        test_predictions += model.predict_proba(test_features, num_iteration = best_iteration)[:, 1] / k_fold.n_splits
        
        # Record the out of fold predictions
        out_of_fold[valid_indices] = model.predict_proba(valid_features, num_iteration = best_iteration)[:, 1]
        
        # Record the best score
        valid_score = model.best_score_['valid']['auc']
        train_score = model.best_score_['train']['auc']
        
        valid_scores.append(valid_score)
        train_scores.append(train_score)
        
        # Clean up memory
        gc.enable()
        del model, train_features, valid_features
        gc.collect()
        
    # Make the submission dataframe
    submission = pd.DataFrame({'SK_ID_CURR': test_ids, 'TARGET': test_predictions})
    
    feature_importances = pd.DataFrame()
    
    # Make the feature importance dataframe
    feature_importances = pd.DataFrame({'feature': feature_names, 'importance': feature_importance_values})
    
    # Overall validation score
    valid_auc = roc_auc_score(labels, out_of_fold)
    
    # Add the overall scores to the metrics
    valid_scores.append(valid_auc)
    train_scores.append(np.mean(train_scores))
    
    # Needed for creating dataframe of validation scores
    fold_names = list(range(n_folds))
    fold_names.append('overall')
    
    # Dataframe of validation scores
    metrics = pd.DataFrame({'fold': fold_names,
                            'train': train_scores,
                            'valid': valid_scores}) 
    
    return submission, feature_importances, metrics

# %% [markdown]
# # FEATURE SELECTION TECHNIQUES

# %%
def step_forward_selection_reg(x_train, y_train, k = 10, print_res=False):
    # review to increase the n_estimators
    sfs = SFS(RandomForestRegressor(n_estimators=10, n_jobs=4, random_state=10), 
           k_features=30, 
           forward=True, 
           floating=False, 
           verbose=2,
           scoring='r2',
           cv=2)

    sfs = sfs.fit(np.array(x_train), y_train)
    selected_feat = x_train.columns[list(sfs.k_feature_idx_)]
    if print_res:
        print(selected_feat)
        
    return x_train[selected_feat]

# %%
def step_backward_selection_clf(x_train, y_train, k = 10, print_res=False):
    # review to increase the n_estimators
    sfs = SFS(RandomForestClassifier(n_estimators=10, n_jobs=4, random_state=0), 
           k_features=30, # the more features we want, the longer it will take to run
           forward=False, 
           floating=False, # see the docs for more details in this parameter
           verbose=2, # this indicates how much to print out intermediate steps
           scoring='roc_auc',
           cv=2)

    sfs = sfs.fit(np.array(x_train), y_train)
    selected_feat = x_train.columns[list(sfs.k_feature_idx_)]
    if print_res:
        print(selected_feat)
        
    return x_train[selected_feat]

# %%
def random_forest_selection_reg_rfe(x_train, y_train, print_res=False):
    sel = RFE(RandomForestRegressor(n_estimators=10, random_state=10), n_features_to_select=30)

    sel.fit(x_train, y_train)
    selected_feat = x_train.columns[(sel.get_support())]
    if print_res:
        print(selected_feat)
    #return sel.transform(x_train)
    return (selected_feat)

# %% [markdown]
# # Load train and test  dataset

# %%
dataset_path = '3NOVtrain_alldataset.csv'
train = pd.read_csv(dataset_path, parse_dates=True, keep_date_col=True)
print(' Train data shape: ', train.shape)

dataset_path = '3NOVtest_alldataset.csv'
test = pd.read_csv(dataset_path, parse_dates=True, keep_date_col=True)
print(' Test dataset shape: ',test.shape)
# Out:
#  Train data shape:  (307511, 169)
#  Test dataset shape:  (92254, 169)

# %% [markdown]
# ### SELECT COLUMNS WITH FEATURE IMPORTANCES FOR FEATURE SELECTION

# %%
coldrop = ['BURO_CREDIT_ACTIVE_ordered_MEAN','PREV_AMT_GOODS_PRICE_MIN','PREV_HOUR_APPR_PROCESS_START_MEAN','PREV_CHANNEL_TYPE_ordered_MEAN','POS_MONTHS_BALANCE_SIZE','PREV_AMT_ANNUITY_MEAN','PREV_APP_CREDIT_PERC_MIN','BURO_AMT_CREDIT_SUM_DEBT_SUM','BURO_DAYS_CREDIT_VAR','BURO_DAYS_CREDIT_ENDDATE_MIN','PREV_NAME_CLIENT_TYPE_ordered_MEAN','PREV_NAME_PAYMENT_TYPE_ordered_MEAN','PREV_CNT_PAYMENT_SUM','PREV_DAYS_DECISION_MEAN','INS_DAYS_ENTRY_PAYMENT_SUM','PREV_NAME_GOODS_CATEGORY_ordered_MEAN','PREV_NAME_PRODUCT_TYPE_ordered_MEAN','BURO_STATUS_0_MEAN_MEAN','BURO_DAYS_CREDIT_MEAN','BURO_DAYS_CREDIT_MIN','AMT_REQ_CREDIT_BUREAU_YEAR','POS_MONTHS_BALANCE_MEAN','INS_AMT_INSTALMENT_MEAN','PREV_DAYS_DECISION_MIN','BURO_AMT_CREDIT_SUM_DEBT_MEAN','NAME_HOUSING_TYPE_ordered','PREV_AMT_ANNUITY_MIN','PREV_AMT_CREDIT_MIN','BURO_AMT_CREDIT_SUM_MAX','BURO_DAYS_CREDIT_UPDATE_MEAN','PREV_AMT_CREDIT_MEAN','OBS_60_CNT_SOCIAL_CIRCLE','INS_AMT_INSTALMENT_SUM','PREV_AMT_GOODS_PRICE_MEAN','PREV_AMT_APPLICATION_MEAN','INS_PAYMENT_DIFF_SUM','CODE_GENDER','INS_PAYMENT_DIFF_MAX','INS_PAYMENT_DIFF_MEAN','BURO_MONTHS_BALANCE_SIZE_MEAN','BURO_DAYS_CREDIT_UPDATE_MIN','PREV_NAME_PORTFOLIO_ordered_MEAN','BURO_STATUS_X_MEAN_MEAN','INS_PAYMENT_PERC_SUM','INS_PAYMENT_DIFF_VAR','PREV_NAME_CASH_LOAN_PURPOSE_ordered_MEAN','INS_PAYMENT_PERC_VAR','INS_DPD_SUM','PREV_AMT_APPLICATION_MIN','BURO_STATUS_C_MEAN_MEAN','INS_PAYMENT_PERC_MEAN','INS_COUNT','PREV_NAME_CONTRACT_TYPE_ordered_MEAN','FLAG_EMP_PHONE','PREV_AMT_ANNUITY_MAX','BURO_MONTHS_BALANCE_SIZE_SUM','INS_AMT_PAYMENT_MAX','BURO_MONTHS_BALANCE_MIN_MIN','CNT_CHILDREN','FLAG_OWN_CAR','FLAG_PHONE','INS_AMT_INSTALMENT_MAX','DEF_60_CNT_SOCIAL_CIRCLE','FLAG_DOCUMENT_3','FLAG_WORK_PHONE','PREV_AMT_GOODS_PRICE_MAX','PREV_AMT_CREDIT_MAX','REGION_RATING_CLIENT_W_CITY','FLAG_OWN_REALTY','BURO_STATUS_1_MEAN_MEAN','BURO_AMT_CREDIT_SUM_DEBT_MAX','PREV_AMT_APPLICATION_MAX','INS_PAYMENT_PERC_MAX','REGION_RATING_CLIENT','NAME_CONTRACT_TYPE','REG_CITY_NOT_WORK_CITY','REG_CITY_NOT_LIVE_CITY','FLAG_EMAIL','LIVE_CITY_NOT_WORK_CITY','BURO_STATUS_2_MEAN_MEAN','BURO_CREDIT_CURRENCY_ordered_MEAN','REG_REGION_NOT_WORK_REGION','POS_COUNT','BURO_MONTHS_BALANCE_MAX_MAX','LIVE_REGION_NOT_WORK_REGION','PREV_FLAG_LAST_APPL_PER_CONTRACT_ordered_MEAN','REG_REGION_NOT_LIVE_REGION','BURO_STATUS_4_MEAN_MEAN','BURO_STATUS_5_MEAN_MEAN','BURO_STATUS_3_MEAN_MEAN']
train.drop(coldrop, axis = 1, inplace=True)
test.drop(coldrop, axis = 1, inplace=True)

# %%
coldrop2 = ['HOUSETYPE_MODE','EMERGENCYSTATE_MODE','FLAG_MOBIL','FLAG_CONT_MOBILE','BURO_STATUS_nan_MEAN_MEAN']
train.drop(coldrop2, axis = 1, inplace=True)
test.drop(coldrop2, axis = 1, inplace=True)

# %%
print(' Train data shape: ', train.shape)
print(' Test dataset shape: ',test.shape)
# Out:
#  Train data shape:  (307511, 74)
#  Test dataset shape:  (92254, 74)

# %%
train_df_wo_imbalance_74_feat = train
test_df_wo_imbalance_74_feat = test

# %%
train_df_wo_imbalance_74_feat.to_csv("train_df_wo_imbalance_74_feat.csv")

# %% [markdown]
# # APPLY CLASS IMBALANCE TECHNIQUE

# %% [markdown]
# #### SMOTE + TOMEK

# %%
#test_subset = test.iloc[10000:40000,:]
test_subset = test

# %%
#train_wo_imbalance = train.iloc[0:200000,:]
train_wo_imbalance = train
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# C:\Users\SUDHIR~1\AppData\Local\Temp/ipykernel_8396/3400307218.py in <module>
#       1 #train_wo_imbalance = train.iloc[0:200000,:]
# ----> 2 train_wo_imbalance = train
#
# NameError: name 'train' is not defined

# %%
train_wo_imbalance = train_wo_imbalance[~train_wo_imbalance.isin([np.nan, np.inf, -np.inf]).any(1)]

# %%
# columns = train_wo_imbalance.columns.tolist()
# train_wo_imbalance.reindex(columns=columns)

# %%
train_imbalanced_sm_tk = run_method(apply_sm_tomek_sampling, train_wo_imbalance, 'TARGET')
# Out:
# Before run size majority:282416, minority:24804
# After run size majority:281355, minority:281355

# %%
train_imbalanced_sm_tk.shape
# Out:
# (562710, 74)

# %%
train_imbalanced_sm_tk.to_csv("4NOVtrain_sm_tomek_balanced.csv")

# %%
del train, test, train_wo_imbalance
gc.collect()
# Out:
# 0

# %% [markdown]
# #### SMOTE

# %%
train_imbalanced_sm = run_method(apply_smote_oversampling, train_wo_imbalance, 'TARGET')
# Out:
# Before run size majority:282416, minority:24804
# After run size majority:282416, minority:282416

# %%
train_imbalanced_sm.shape
# Out:
# (564832, 74)

# %%
train_imbalanced_sm.to_csv("4NOVtrain_sm_balanced.csv")

# %% [markdown]
# #### ADASYN

# %%
train_imbalanced_ad = run_method(apply_adasyn_oversampling, train_wo_imbalance, 'TARGET')
# Out:
# Before run size majority:282416, minority:24804
# After run size majority:282416, minority:274479

# %%
train_imbalanced_ad.shape
# Out:
# (556895, 74)

# %%
train_imbalanced_ad.to_csv("4NOVtrain_adasyn_balanced.csv")

# %% [markdown]
# #### TOMEK

# %%
train_imbalanced_tm = run_method(apply_tomeklink_undersampling, train_wo_imbalance, 'TARGET')
# Out:
# Before run size majority:282416, minority:24804
# After run size majority:271323, minority:24804

# %%
train_imbalanced_tm.shape
# Out:
# (296127, 74)

# %%
train_imbalanced_tm.to_csv("4NOVtrain_tomek_balanced.csv")

# %% [markdown]
# #### ENN

# %%
train_imbalanced_enn = run_method(apply_editednearestneighbour_undersampling, train_wo_imbalance, 'TARGET')
# Out:
# Before run size majority:282416, minority:24804
# After run size majority:220998, minority:24804

# %%
train_imbalanced_enn.shape
# Out:
# (245802, 74)

# %%
train_imbalanced_enn.to_csv("4NOVtrain_enn_balanced.csv")

# %%
del train_imbalanced_enn, train_imbalanced_sm, train_imbalanced_ad, train_imbalanced_tm
gc.collect()
# Out:
# 12

# %% [markdown]
# # FEATURE SELECTION

# %%
dataset_path = '4NOVtrain_sm_tomek_balanced.csv'
train_imbalanced_sm_tk = pd.read_csv(dataset_path, parse_dates=True, keep_date_col=True)
print(' Train data shape: ', train_imbalanced_sm_tk.shape)
# Out:
#  Train data shape:  (562710, 75)

# %%
#data = train.head(100000)
data = train_imbalanced_sm_tk

# %%
# SEPERATE DATASET INTO TRAIN AND TEST

x_train, x_test, y_train, y_test = train_test_split(
    data.drop(labels=['TARGET'], axis=1),  # drop the target
    data['TARGET'],  # just the target
    test_size=0.3,
    random_state=0)

x_train.shape, x_test.shape
# Out:
# ((393897, 74), (168813, 74))

# %%
df_step_forward_selection = step_forward_selection_reg(x_train, y_train, k = 30, print_res=True)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   25.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed:  7.3min finished
#
# [2021-10-30 16:17:33] Features: 1/30 -- score: 0.8009765058381328[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed:  3.4min finished
#
# [2021-10-30 16:20:58] Features: 2/30 -- score: 0.8194042210160115[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed:  3.5min finished
#
# [2021-10-30 16:24:30] Features: 3/30 -- score: 0.8159673040205722[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed:  4.1min finished
#
# [2021-10-30 16:28:36] Features: 4/30 -- score: 0.8123382339121048[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    3.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed:  4.2min finished
#
# [2021-10-30 16:32:49] Features: 5/30 -- score: 0.8071035213380908[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed:  4.7min finished
#
# [2021-10-30 16:37:31] Features: 6/30 -- score: 0.8008483417424508[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed:  4.8min finished
#
# [2021-10-30 16:42:17] Features: 7/30 -- score: 0.790056900174511[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    4.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed:  5.7min finished
#
# [2021-10-30 16:47:56] Features: 8/30 -- score: 0.7837710557145153[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed:  7.8min finished
#
# [2021-10-30 16:55:42] Features: 9/30 -- score: 0.7842388373361389[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed: 10.4min finished
#
# [2021-10-30 17:06:07] Features: 10/30 -- score: 0.7897907372288495[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed: 10.4min finished
#
# [2021-10-30 17:16:30] Features: 11/30 -- score: 0.7933763850674357[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed: 10.1min finished
#
# [2021-10-30 17:26:38] Features: 12/30 -- score: 0.7959152057420761[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 14.5min finished
#
# [2021-10-30 17:41:06] Features: 13/30 -- score: 0.7980110936634967[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   20.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed: 11.8min finished
#
# [2021-10-30 17:52:52] Features: 14/30 -- score: 0.798772351743315[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed: 10.7min finished
#
# [2021-10-30 18:03:32] Features: 15/30 -- score: 0.7988504308950154[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed: 11.5min finished
#
# [2021-10-30 18:15:01] Features: 16/30 -- score: 0.7986450128224989[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   15.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed: 12.1min finished
#
# [2021-10-30 18:27:05] Features: 17/30 -- score: 0.798506526170758[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   13.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed: 14.5min finished
#
# [2021-10-30 18:41:33] Features: 18/30 -- score: 0.7981426294809142[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   15.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed: 21.9min finished
#
# [2021-10-30 19:03:30] Features: 19/30 -- score: 0.7987406249905863[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   20.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed: 17.4min finished
#
# [2021-10-30 19:20:55] Features: 20/30 -- score: 0.7988189971249544[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   32.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed: 16.0min finished
#
# [2021-10-30 19:36:53] Features: 21/30 -- score: 0.798583592298165[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   17.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed: 14.6min finished
#
# [2021-10-30 19:51:31] Features: 22/30 -- score: 0.7983209524205321[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   18.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed: 15.6min finished
#
# [2021-10-30 20:07:08] Features: 23/30 -- score: 0.7980196387464484[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   19.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed: 16.5min finished
#
# [2021-10-30 20:23:38] Features: 24/30 -- score: 0.7980135560636945[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   22.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 18.7min finished
#
# [2021-10-30 20:42:18] Features: 25/30 -- score: 0.7974850929650701[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   24.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed: 18.6min finished
#
# [2021-10-30 21:00:55] Features: 26/30 -- score: 0.7980436891761478[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   22.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed: 18.0min finished
#
# [2021-10-30 21:18:57] Features: 27/30 -- score: 0.7976631274724522[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   24.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 19.7min finished
#
# [2021-10-30 21:38:38] Features: 28/30 -- score: 0.7972169530717192[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   28.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed: 21.8min finished
#
# [2021-10-30 22:00:24] Features: 29/30 -- score: 0.7965989657210633[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   32.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed: 22.4min finished
#
# [2021-10-30 22:22:46] Features: 30/30 -- score: 0.7962198567111174
# Index(['AMT_INCOME_TOTAL', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        'REGION_POPULATION_RELATIVE', 'CNT_FAM_MEMBERS',
#        'HOUR_APPR_PROCESS_START', 'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE',
#        'DEF_30_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'NEW_INC_BY_ORG',
#        'NEW_EXT_SOURCES_MEAN', 'NAME_TYPE_SUITE_ordered',
#        'NAME_INCOME_TYPE_ordered', 'NAME_EDUCATION_TYPE_ordered',
#        'NAME_FAMILY_STATUS_ordered', 'WEEKDAY_APPR_PROCESS_START_ordered',
#        'BURO_DAYS_CREDIT_ENDDATE_MAX', 'BURO_AMT_CREDIT_SUM_MEAN',
#        'BURO_AMT_CREDIT_SUM_SUM', 'PREV_APP_CREDIT_PERC_MEAN',
#        'PREV_HOUR_APPR_PROCESS_START_MIN', 'PREV_RATE_DOWN_PAYMENT_MIN',
#        'INS_NUM_INSTALMENT_VERSION_NUNIQUE', 'INS_DBD_MAX', 'INS_DBD_SUM',
#        'INS_AMT_PAYMENT_MIN', 'INS_AMT_PAYMENT_MEAN', 'INS_AMT_PAYMENT_SUM',
#        'INS_DAYS_ENTRY_PAYMENT_MEAN'],
#       dtype='object')

# %%
df_step_forward_selection.columns
# Out:
# Index(['AMT_INCOME_TOTAL', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
#        'REGION_POPULATION_RELATIVE', 'CNT_FAM_MEMBERS',
#        'HOUR_APPR_PROCESS_START', 'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE',
#        'DEF_30_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'NEW_INC_BY_ORG',
#        'NEW_EXT_SOURCES_MEAN', 'NAME_TYPE_SUITE_ordered',
#        'NAME_INCOME_TYPE_ordered', 'NAME_EDUCATION_TYPE_ordered',
#        'NAME_FAMILY_STATUS_ordered', 'WEEKDAY_APPR_PROCESS_START_ordered',
#        'BURO_DAYS_CREDIT_ENDDATE_MAX', 'BURO_AMT_CREDIT_SUM_MEAN',
#        'BURO_AMT_CREDIT_SUM_SUM', 'PREV_APP_CREDIT_PERC_MEAN',
#        'PREV_HOUR_APPR_PROCESS_START_MIN', 'PREV_RATE_DOWN_PAYMENT_MIN',
#        'INS_NUM_INSTALMENT_VERSION_NUNIQUE', 'INS_DBD_MAX', 'INS_DBD_SUM',
#        'INS_AMT_PAYMENT_MIN', 'INS_AMT_PAYMENT_MEAN', 'INS_AMT_PAYMENT_SUM',
#        'INS_DAYS_ENTRY_PAYMENT_MEAN'],
#       dtype='object')

# %%
_selection = step_backward_selection_clf(x_train, y_train, k = 30, print_res=True)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   15.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  72 out of  72 | elapsed: 19.0min finished
#
# [2021-10-31 00:53:33] Features: 71/30 -- score: 0.9704585527522593[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  71 out of  71 | elapsed: 18.5min finished
#
# [2021-10-31 01:12:03] Features: 70/30 -- score: 0.971250146246399[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   14.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  70 out of  70 | elapsed: 16.3min finished
#
# [2021-10-31 01:28:24] Features: 69/30 -- score: 0.9709761296327286[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   12.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  69 out of  69 | elapsed: 15.0min finished
#
# [2021-10-31 01:43:22] Features: 68/30 -- score: 0.9710064747856382[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   12.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  68 out of  68 | elapsed: 14.6min finished
#
# [2021-10-31 01:57:58] Features: 67/30 -- score: 0.9713668901989968[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  67 out of  67 | elapsed: 14.6min finished
#
# [2021-10-31 02:12:33] Features: 66/30 -- score: 0.971296708582511[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   12.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  66 out of  66 | elapsed: 14.1min finished
#
# [2021-10-31 02:26:39] Features: 65/30 -- score: 0.9714120810117506[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   12.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  65 out of  65 | elapsed: 13.7min finished
#
# [2021-10-31 02:40:19] Features: 64/30 -- score: 0.9713375734361269[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  64 out of  64 | elapsed: 11.9min finished
#
# [2021-10-31 02:52:10] Features: 63/30 -- score: 0.9711735519420907[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  63 out of  63 | elapsed: 11.7min finished
#
# [2021-10-31 03:03:54] Features: 62/30 -- score: 0.9715259643480714[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  62 out of  62 | elapsed: 11.3min finished
#
# [2021-10-31 03:15:11] Features: 61/30 -- score: 0.9714728584551916[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  61 out of  61 | elapsed: 11.0min finished
#
# [2021-10-31 03:26:13] Features: 60/30 -- score: 0.9712107033470634[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  60 out of  60 | elapsed: 10.7min finished
#
# [2021-10-31 03:36:58] Features: 59/30 -- score: 0.9710232418317966[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  59 out of  59 | elapsed: 10.7min finished
#
# [2021-10-31 03:47:38] Features: 58/30 -- score: 0.9715620163958094[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.9s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  58 out of  58 | elapsed: 10.4min finished
#
# [2021-10-31 03:58:05] Features: 57/30 -- score: 0.9715147593637099[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  57 out of  57 | elapsed: 10.6min finished
#
# [2021-10-31 04:08:43] Features: 56/30 -- score: 0.9718788230168484[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  56 out of  56 | elapsed: 10.2min finished
#
# [2021-10-31 04:18:54] Features: 55/30 -- score: 0.9718513785447198[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  55 out of  55 | elapsed:  9.7min finished
#
# [2021-10-31 04:28:36] Features: 54/30 -- score: 0.9717350288417479[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  54 out of  54 | elapsed:  9.5min finished
#
# [2021-10-31 04:38:04] Features: 53/30 -- score: 0.9715524317665637[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  53 out of  53 | elapsed:  9.4min finished
#
# [2021-10-31 04:47:27] Features: 52/30 -- score: 0.9719566435536326[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  52 out of  52 | elapsed:  8.9min finished
#
# [2021-10-31 04:56:20] Features: 51/30 -- score: 0.9721004593536455[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  51 out of  51 | elapsed:  8.9min finished
#
# [2021-10-31 05:05:16] Features: 50/30 -- score: 0.9718455557810337[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  50 out of  50 | elapsed:  9.7min finished
#
# [2021-10-31 05:14:58] Features: 49/30 -- score: 0.9720591841268479[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  49 out of  49 | elapsed:  8.0min finished
#
# [2021-10-31 05:23:01] Features: 48/30 -- score: 0.9716012609509788[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.1s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  48 out of  48 | elapsed: 11.3min finished
#
# [2021-10-31 05:34:21] Features: 47/30 -- score: 0.9721459009938525[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   17.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  47 out of  47 | elapsed: 13.5min finished
#
# [2021-10-31 05:47:53] Features: 46/30 -- score: 0.9715781828571182[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   16.6s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  46 out of  46 | elapsed: 13.6min finished
#
# [2021-10-31 06:01:29] Features: 45/30 -- score: 0.9717759846286907[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   15.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  45 out of  45 | elapsed: 10.3min finished
#
# [2021-10-31 06:11:44] Features: 44/30 -- score: 0.9714258239075442[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  44 out of  44 | elapsed:  7.7min finished
#
# [2021-10-31 06:19:24] Features: 43/30 -- score: 0.9720166284031267[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  43 out of  43 | elapsed:  8.0min finished
#
# [2021-10-31 06:27:23] Features: 42/30 -- score: 0.9716705677914572[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.4s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  42 out of  42 | elapsed:  6.9min finished
#
# [2021-10-31 06:34:14] Features: 41/30 -- score: 0.9714408399514785[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  41 out of  41 | elapsed:  5.9min finished
#
# [2021-10-31 06:40:07] Features: 40/30 -- score: 0.9714122214031777[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  40 out of  40 | elapsed:  6.3min finished
#
# [2021-10-31 06:46:27] Features: 39/30 -- score: 0.9716921682908979[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  39 out of  39 | elapsed:  7.0min finished
#
# [2021-10-31 06:53:26] Features: 38/30 -- score: 0.9715591045556733[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   12.8s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  38 out of  38 | elapsed:  6.9min finished
#
# [2021-10-31 07:00:18] Features: 37/30 -- score: 0.9714535478281027[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   11.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  37 out of  37 | elapsed:  7.4min finished
#
# [2021-10-31 07:07:43] Features: 36/30 -- score: 0.9712865728179884[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.5s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  36 out of  36 | elapsed:  6.1min finished
#
# [2021-10-31 07:13:49] Features: 35/30 -- score: 0.9709652222275988[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  35 out of  35 | elapsed:  5.2min finished
#
# [2021-10-31 07:19:00] Features: 34/30 -- score: 0.9713619835782172[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:   10.3s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  34 out of  34 | elapsed:  5.2min finished
#
# [2021-10-31 07:24:12] Features: 33/30 -- score: 0.9712932111443164[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    7.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  33 out of  33 | elapsed:  4.7min finished
#
# [2021-10-31 07:28:56] Features: 32/30 -- score: 0.9715645488029809[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    8.7s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  32 out of  32 | elapsed:  4.8min finished
#
# [2021-10-31 07:33:43] Features: 31/30 -- score: 0.9715893829209867[Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    9.2s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done  31 out of  31 | elapsed:  4.6min finished
#
# [2021-10-31 07:38:18] Features: 30/30 -- score: 0.9714994758741105
# Index(['SK_ID_CURR', 'AMT_CREDIT', 'AMT_ANNUITY', 'DAYS_BIRTH',
#        'DAYS_ID_PUBLISH', 'CNT_FAM_MEMBERS', 'EXT_SOURCE_3',
#        'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
#        'NEW_CREDIT_TO_INCOME_RATIO', 'NEW_SOURCES_PROD', 'NEW_SCORES_STD',
#        'NAME_TYPE_SUITE_ordered', 'NAME_INCOME_TYPE_ordered',
#        'NAME_EDUCATION_TYPE_ordered', 'NAME_FAMILY_STATUS_ordered',
#        'WEEKDAY_APPR_PROCESS_START_ordered', 'ORGANIZATION_TYPE_ordered',
#        'BURO_AMT_CREDIT_SUM_MEAN', 'BURO_DAYS_CREDIT_UPDATE_MAX',
#        'PREV_APP_CREDIT_PERC_MAX', 'PREV_RATE_DOWN_PAYMENT_MIN',
#        'PREV_DAYS_DECISION_MAX', 'PREV_CNT_PAYMENT_MEAN',
#        'POS_MONTHS_BALANCE_MAX', 'INS_NUM_INSTALMENT_VERSION_NUNIQUE',
#        'INS_DPD_MAX', 'INS_AMT_PAYMENT_MEAN', 'INS_AMT_PAYMENT_SUM',
#        'INS_DAYS_ENTRY_PAYMENT_MEAN'],
#       dtype='object')

# %%
_selection
# Out:
#         SK_ID_CURR    AMT_CREDIT   AMT_ANNUITY  DAYS_BIRTH  DAYS_ID_PUBLISH  \
# 375267      163728  2.254308e+05  10028.366951  -37.062019        -7.175664
# 366557      263643  7.982704e+05  39622.912645  -36.047622       -10.201369
# 45914       320678  2.472750e+05  17338.500000  -63.805479       -10.101370
# 56204       147718  2.673360e+05  17082.000000  -50.843836        -5.676712
# 388132      158492  1.062049e+06  38884.459437  -45.481346       -12.869366
# ...            ...           ...           ...         ...              ...
# 359783      260722  5.723471e+05  28029.559408  -47.912980        -2.789237
# 358083      214586  3.945037e+05  21085.832217  -29.834505        -8.828966
# 152315      148344  9.000000e+05  29164.500000  -48.490411        -3.408219
# 117952      128128  2.295000e+05  13302.000000  -52.301370        -7.202740
# 305711      300489  2.098536e+05  15169.388696  -49.884651        -5.544593
#
#         CNT_FAM_MEMBERS  EXT_SOURCE_3  OBS_30_CNT_SOCIAL_CIRCLE  \
# 375267         1.747981      0.385765                  2.243943
# 366557         4.608612      0.284436                  2.348329
# 45914          2.000000      0.535000                  0.000000
# 56204          2.000000      0.535000                  0.000000
# 388132         3.249700      0.503861                  2.874550
# ...                 ...           ...                       ...
# 359783         3.374927      0.624768                  1.791642
# 358083         3.845097      0.535000                  0.154903
# 152315         2.000000      0.328063                  0.000000
# 117952         3.000000      0.374021                  0.000000
# 305711         3.000000      0.535000                  0.000000
#
#         DEF_30_CNT_SOCIAL_CIRCLE  NEW_CREDIT_TO_INCOME_RATIO  \
# 375267                  0.000000                    2.505037
# 366557                  0.000000                    2.838036
# 45914                   0.000000                    3.434375
# 56204                   0.000000                    1.697371
# 388132                  0.375150                    8.029610
# ...                          ...                         ...
# 359783                  1.583285                    4.209222
# 358083                  0.154903                    5.628739
# 152315                  0.000000                    4.444444
# 117952                  0.000000                    1.133333
# 305711                  0.000000                    1.980245
#
#         NEW_SOURCES_PROD  NEW_SCORES_STD  NAME_TYPE_SUITE_ordered  \
# 375267          0.025855        0.157820                -2.478138
# 366557          0.046917        0.153520                -2.419637
# 45914           0.053477        0.187023                -2.513087
# 56204           0.155680        0.034688                -2.419637
# 388132          0.177392        0.114937                -2.419637
# ...                  ...             ...                      ...
# 359783          0.237803        0.111998                -2.451529
# 358083          0.032428        0.186468                -2.434113
# 152315          0.095056        0.126433                -2.419637
# 117952          0.099482        0.082459                -2.513087
# 305711          0.100578        0.087266                -2.419637
#
#         NAME_INCOME_TYPE_ordered  NAME_EDUCATION_TYPE_ordered  \
# 375267                 -2.243810                    -2.320992
# 366557                 -2.514577                    -2.536681
# 45914                  -2.865931                    -2.320992
# 56204                  -2.514577                    -2.872080
# 388132                 -2.588743                    -2.665339
# ...                          ...                          ...
# 359783                 -2.373434                    -2.320992
# 358083                 -2.329320                    -2.320992
# 152315                 -2.243810                    -2.320992
# 117952                 -2.243810                    -2.320992
# 305711                 -2.243810                    -2.320992
#
#         NAME_FAMILY_STATUS_ordered  WEEKDAY_APPR_PROCESS_START_ordered  \
# 375267                   -2.448955                           -2.420756
# 366557                   -2.503707                           -2.464822
# 45914                    -2.503707                           -2.457763
# 56204                    -2.416244                           -2.420756
# 388132                   -2.503707                           -2.416366
# ...                            ...                                 ...
# 359783                   -2.485484                           -2.421130
# 358083                   -2.503707                           -2.428803
# 152315                   -2.503707                           -2.457763
# 117952                   -2.503707                           -2.422549
# 305711                   -2.493007                           -2.473902
#
#         ORGANIZATION_TYPE_ordered  BURO_AMT_CREDIT_SUM_MEAN  \
# 375267                  -2.215276             112475.843848
# 366557                  -2.523564             231590.543974
# 45914                   -2.863328                  0.000000
# 56204                   -2.277588                  0.000000
# 388132                  -2.385260             179801.119994
# ...                           ...                       ...
# 359783                  -2.320833              68712.385403
# 358083                  -2.193468                  0.000000
# 152315                  -2.277588             162617.625000
# 117952                  -2.581343             240824.700000
# 305711                  -2.277588                  0.000000
#
#         BURO_DAYS_CREDIT_UPDATE_MAX  PREV_APP_CREDIT_PERC_MAX  \
# 375267                   -17.268171                  1.000047
# 366557                   -22.955012                  0.800000
# 45914                      0.000000                  0.853539
# 56204                      0.000000                  1.045562
# 388132                   -25.880546                  0.896720
# ...                             ...                       ...
# 359783                   -28.417300                  1.178214
# 358083                     0.000000                  1.077988
# 152315                  -118.000000                  1.111148
# 117952                    -3.000000                  0.800000
# 305711                     0.000000                  0.820458
#
#         PREV_RATE_DOWN_PAYMENT_MIN  PREV_DAYS_DECISION_MAX  \
# 375267                    0.000004             -260.359495
# 366557                    0.051600             -447.980704
# 45914                     0.000000             -700.000000
# 56204                     0.051600             -249.000000
# 388132                    0.000000             -149.217325
# ...                            ...                     ...
# 359783                    0.051600             -423.789302
# 358083                    0.105637            -1484.032381
# 152315                    0.051600             -127.000000
# 117952                    0.099999             -827.000000
# 305711                    0.049761             -342.636233
#
#         PREV_CNT_PAYMENT_MEAN  POS_MONTHS_BALANCE_MAX  \
# 375267              17.990309               -5.487886
# 366557              17.968038              -18.868894
# 45914               24.000000               -1.000000
# 56204               17.571429               -1.000000
# 388132              16.998668               -1.375150
# ...                       ...                     ...
# 359783              11.583402               -3.583285
# 358083              10.929415              -54.396044
# 152315              15.000000               -2.000000
# 117952              18.000000              -10.000000
# 305711              20.072043               -1.000000
#
#         INS_NUM_INSTALMENT_VERSION_NUNIQUE  INS_DPD_MAX  INS_AMT_PAYMENT_MEAN  \
# 375267                            1.000000    13.260095           3116.452612
# 366557                            4.825835     6.696659          17437.593423
# 45914                             2.000000     0.000000          13114.123043
# 56204                             2.000000     0.000000          19387.282642
# 388132                            9.248501     0.750300          10498.555191
# ...                                    ...          ...                   ...
# 359783                            1.208358    13.416715           6522.276864
# 358083                            2.000000     0.000000          10048.545739
# 152315                            2.000000     0.000000           9231.032812
# 117952                            2.000000     1.000000          25095.882353
# 305711                            1.964370     0.000000           3115.062441
#
#         INS_AMT_PAYMENT_SUM  INS_DAYS_ENTRY_PAYMENT_MEAN
# 375267         1.360614e+05                  -664.211921
# 366557         3.358677e+05                  -667.990250
# 45914          3.016248e+05                  -353.478261
# 56204          1.027526e+06                  -380.660377
# 388132         7.520036e+05                 -1161.464254
# ...                     ...                          ...
# 359783         3.314643e+05                  -867.673593
# 358083         8.869347e+04                 -1780.348829
# 152315         1.476965e+05                  -267.750000
# 117952         4.266300e+05                  -558.176471
# 305711         2.819951e+05                 -1214.342366
#
# [276123 rows x 30 columns]

# %%
df_RFE_rf_embedded = random_forest_selection_reg_rfe(x_train, y_train, print_res=True)
# Out:
# Index(['Unnamed: 0', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH',
#        'CNT_FAM_MEMBERS', 'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE',
#        'NEW_ANNUITY_TO_INCOME_RATIO', 'NEW_CREDIT_TO_ANNUITY_RATIO',
#        'NEW_CREDIT_TO_GOODS_RATIO', 'NEW_INC_BY_ORG', 'NEW_SOURCES_PROD',
#        'NEW_EXT_SOURCES_MEAN', 'NAME_INCOME_TYPE_ordered',
#        'NAME_EDUCATION_TYPE_ordered', 'NAME_FAMILY_STATUS_ordered',
#        'OCCUPATION_TYPE_ordered', 'ORGANIZATION_TYPE_ordered',
#        'BURO_DAYS_CREDIT_ENDDATE_MEAN', 'BURO_AMT_CREDIT_SUM_SUM',
#        'PREV_APP_CREDIT_PERC_MAX', 'PREV_HOUR_APPR_PROCESS_START_MIN',
#        'PREV_HOUR_APPR_PROCESS_START_MAX', 'PREV_RATE_DOWN_PAYMENT_MIN',
#        'PREV_RATE_DOWN_PAYMENT_MAX', 'PREV_CODE_REJECT_REASON_ordered_MEAN',
#        'POS_MONTHS_BALANCE_MAX', 'INS_DPD_MEAN', 'INS_AMT_PAYMENT_MIN',
#        'INS_AMT_PAYMENT_SUM'],
#       dtype='object')

# %%
df_RFE_rf_embedded
# Out:
# Index(['Unnamed: 0', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH',
#        'CNT_FAM_MEMBERS', 'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE',
#        'NEW_ANNUITY_TO_INCOME_RATIO', 'NEW_CREDIT_TO_ANNUITY_RATIO',
#        'NEW_CREDIT_TO_GOODS_RATIO', 'NEW_INC_BY_ORG', 'NEW_SOURCES_PROD',
#        'NEW_EXT_SOURCES_MEAN', 'NAME_INCOME_TYPE_ordered',
#        'NAME_EDUCATION_TYPE_ordered', 'NAME_FAMILY_STATUS_ordered',
#        'OCCUPATION_TYPE_ordered', 'ORGANIZATION_TYPE_ordered',
#        'BURO_DAYS_CREDIT_ENDDATE_MEAN', 'BURO_AMT_CREDIT_SUM_SUM',
#        'PREV_APP_CREDIT_PERC_MAX', 'PREV_HOUR_APPR_PROCESS_START_MIN',
#        'PREV_HOUR_APPR_PROCESS_START_MAX', 'PREV_RATE_DOWN_PAYMENT_MIN',
#        'PREV_RATE_DOWN_PAYMENT_MAX', 'PREV_CODE_REJECT_REASON_ordered_MEAN',
#        'POS_MONTHS_BALANCE_MAX', 'INS_DPD_MEAN', 'INS_AMT_PAYMENT_MIN',
#        'INS_AMT_PAYMENT_SUM'],
#       dtype='object')

# %%
# Find columns that are common in feature selection algorithms
columns_from_feat_select = []

# %%
coldrop = []
for col in train_imbalanced.columns: 
    if col not in (columns_from_feat_select):
        coldrop.append(col)
coldrop

# %%
train_imbalanced.drop(coldrop, axis = 1, inplace=True)
test_subset.drop(coldrop, axis = 1, inplace=True)

# %%
rfe_feat = ['Unnamed: 0', 'DAYS_BIRTH', 'DAYS_EMPLOYED', 'DAYS_ID_PUBLISH',
       'CNT_FAM_MEMBERS', 'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE',
       'NEW_ANNUITY_TO_INCOME_RATIO', 'NEW_CREDIT_TO_ANNUITY_RATIO',
       'NEW_CREDIT_TO_GOODS_RATIO', 'NEW_INC_BY_ORG', 'NEW_SOURCES_PROD',
       'NEW_EXT_SOURCES_MEAN', 'NAME_INCOME_TYPE_ordered',
       'NAME_EDUCATION_TYPE_ordered', 'NAME_FAMILY_STATUS_ordered',
       'OCCUPATION_TYPE_ordered', 'ORGANIZATION_TYPE_ordered',
       'BURO_DAYS_CREDIT_ENDDATE_MEAN', 'BURO_AMT_CREDIT_SUM_SUM',
       'PREV_APP_CREDIT_PERC_MAX', 'PREV_HOUR_APPR_PROCESS_START_MIN',
       'PREV_HOUR_APPR_PROCESS_START_MAX', 'PREV_RATE_DOWN_PAYMENT_MIN',
       'PREV_RATE_DOWN_PAYMENT_MAX', 'PREV_CODE_REJECT_REASON_ordered_MEAN',
       'POS_MONTHS_BALANCE_MAX', 'INS_DPD_MEAN', 'INS_AMT_PAYMENT_MIN',
       'INS_AMT_PAYMENT_SUM']

# %%
step_fwd_feat = ['AMT_INCOME_TOTAL', 'AMT_ANNUITY', 'AMT_GOODS_PRICE',
       'REGION_POPULATION_RELATIVE', 'CNT_FAM_MEMBERS',
       'HOUR_APPR_PROCESS_START', 'EXT_SOURCE_2', 'OBS_30_CNT_SOCIAL_CIRCLE',
       'DEF_30_CNT_SOCIAL_CIRCLE', 'DAYS_LAST_PHONE_CHANGE', 'NEW_INC_BY_ORG',
       'NEW_EXT_SOURCES_MEAN', 'NAME_TYPE_SUITE_ordered',
       'NAME_INCOME_TYPE_ordered', 'NAME_EDUCATION_TYPE_ordered',
       'NAME_FAMILY_STATUS_ordered', 'WEEKDAY_APPR_PROCESS_START_ordered',
       'BURO_DAYS_CREDIT_ENDDATE_MAX', 'BURO_AMT_CREDIT_SUM_MEAN',
       'BURO_AMT_CREDIT_SUM_SUM', 'PREV_APP_CREDIT_PERC_MEAN',
       'PREV_HOUR_APPR_PROCESS_START_MIN', 'PREV_RATE_DOWN_PAYMENT_MIN',
       'INS_NUM_INSTALMENT_VERSION_NUNIQUE', 'INS_DBD_MAX', 'INS_DBD_SUM',
       'INS_AMT_PAYMENT_MIN', 'INS_AMT_PAYMENT_MEAN', 'INS_AMT_PAYMENT_SUM',
       'INS_DAYS_ENTRY_PAYMENT_MEAN']

# %%
step_bkwd_feat = ['SK_ID_CURR', 'AMT_CREDIT', 'AMT_ANNUITY', 'DAYS_BIRTH',
       'DAYS_ID_PUBLISH', 'CNT_FAM_MEMBERS', 'EXT_SOURCE_3',
       'OBS_30_CNT_SOCIAL_CIRCLE', 'DEF_30_CNT_SOCIAL_CIRCLE',
       'NEW_CREDIT_TO_INCOME_RATIO', 'NEW_SOURCES_PROD', 'NEW_SCORES_STD',
       'NAME_TYPE_SUITE_ordered', 'NAME_INCOME_TYPE_ordered',
       'NAME_EDUCATION_TYPE_ordered', 'NAME_FAMILY_STATUS_ordered',
       'WEEKDAY_APPR_PROCESS_START_ordered', 'ORGANIZATION_TYPE_ordered',
       'BURO_AMT_CREDIT_SUM_MEAN', 'BURO_DAYS_CREDIT_UPDATE_MAX',
       'PREV_APP_CREDIT_PERC_MAX', 'PREV_RATE_DOWN_PAYMENT_MIN',
       'PREV_DAYS_DECISION_MAX', 'PREV_CNT_PAYMENT_MEAN',
       'POS_MONTHS_BALANCE_MAX', 'INS_NUM_INSTALMENT_VERSION_NUNIQUE',
       'INS_DPD_MAX', 'INS_AMT_PAYMENT_MEAN', 'INS_AMT_PAYMENT_SUM',
       'INS_DAYS_ENTRY_PAYMENT_MEAN']

# %%
s1 = set(rfe_feat)
s2 = set(step_fwd_feat)
s3 = set(step_bkwd_feat)
s4 = s1.intersection(s2) # features common to step fwd and rfe
s5 = s3.intersection(s4)
s5 # features common to rfe and step bkwd and step fwd
# Out:
# {'CNT_FAM_MEMBERS',
#  'INS_AMT_PAYMENT_SUM',
#  'NAME_EDUCATION_TYPE_ordered',
#  'NAME_FAMILY_STATUS_ordered',
#  'NAME_INCOME_TYPE_ordered',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'PREV_RATE_DOWN_PAYMENT_MIN'}

# %%
# features from rfe selection
rfe_feat
# Out:
# ['Unnamed: 0',
#  'DAYS_BIRTH',
#  'DAYS_EMPLOYED',
#  'DAYS_ID_PUBLISH',
#  'CNT_FAM_MEMBERS',
#  'EXT_SOURCE_2',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'NEW_ANNUITY_TO_INCOME_RATIO',
#  'NEW_CREDIT_TO_ANNUITY_RATIO',
#  'NEW_CREDIT_TO_GOODS_RATIO',
#  'NEW_INC_BY_ORG',
#  'NEW_SOURCES_PROD',
#  'NEW_EXT_SOURCES_MEAN',
#  'NAME_INCOME_TYPE_ordered',
#  'NAME_EDUCATION_TYPE_ordered',
#  'NAME_FAMILY_STATUS_ordered',
#  'OCCUPATION_TYPE_ordered',
#  'ORGANIZATION_TYPE_ordered',
#  'BURO_DAYS_CREDIT_ENDDATE_MEAN',
#  'BURO_AMT_CREDIT_SUM_SUM',
#  'PREV_APP_CREDIT_PERC_MAX',
#  'PREV_HOUR_APPR_PROCESS_START_MIN',
#  'PREV_HOUR_APPR_PROCESS_START_MAX',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'PREV_RATE_DOWN_PAYMENT_MAX',
#  'PREV_CODE_REJECT_REASON_ordered_MEAN',
#  'POS_MONTHS_BALANCE_MAX',
#  'INS_DPD_MEAN',
#  'INS_AMT_PAYMENT_MIN',
#  'INS_AMT_PAYMENT_SUM']

# %%
# features from step forward selection
step_fwd_feat
# Out:
# ['AMT_INCOME_TOTAL',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'REGION_POPULATION_RELATIVE',
#  'CNT_FAM_MEMBERS',
#  'HOUR_APPR_PROCESS_START',
#  'EXT_SOURCE_2',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'DAYS_LAST_PHONE_CHANGE',
#  'NEW_INC_BY_ORG',
#  'NEW_EXT_SOURCES_MEAN',
#  'NAME_TYPE_SUITE_ordered',
#  'NAME_INCOME_TYPE_ordered',
#  'NAME_EDUCATION_TYPE_ordered',
#  'NAME_FAMILY_STATUS_ordered',
#  'WEEKDAY_APPR_PROCESS_START_ordered',
#  'BURO_DAYS_CREDIT_ENDDATE_MAX',
#  'BURO_AMT_CREDIT_SUM_MEAN',
#  'BURO_AMT_CREDIT_SUM_SUM',
#  'PREV_APP_CREDIT_PERC_MEAN',
#  'PREV_HOUR_APPR_PROCESS_START_MIN',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'INS_NUM_INSTALMENT_VERSION_NUNIQUE',
#  'INS_DBD_MAX',
#  'INS_DBD_SUM',
#  'INS_AMT_PAYMENT_MIN',
#  'INS_AMT_PAYMENT_MEAN',
#  'INS_AMT_PAYMENT_SUM',
#  'INS_DAYS_ENTRY_PAYMENT_MEAN']

# %%
# features common to stepfwd and rfe 
feat_common_rfe_step_fwd = list(s4)
feat_common_rfe_step_fwd.append('TARGET')
feat_common_rfe_step_fwd
# Out:
# ['CNT_FAM_MEMBERS',
#  'EXT_SOURCE_2',
#  'INS_AMT_PAYMENT_MIN',
#  'NAME_EDUCATION_TYPE_ordered',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'NEW_EXT_SOURCES_MEAN',
#  'INS_AMT_PAYMENT_SUM',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'NEW_INC_BY_ORG',
#  'NAME_INCOME_TYPE_ordered',
#  'PREV_HOUR_APPR_PROCESS_START_MIN',
#  'BURO_AMT_CREDIT_SUM_SUM',
#  'NAME_FAMILY_STATUS_ordered',
#  'TARGET']

# %%
# features common to stepbkwd and rfe 
s7 = s3.intersection(s1)
s7
feat_common_stepbkwd_rfe = list(s7)
feat_common_stepbkwd_rfe.append('TARGET')
feat_common_stepbkwd_rfe
# Out:
# ['CNT_FAM_MEMBERS',
#  'NAME_INCOME_TYPE_ordered',
#  'NAME_EDUCATION_TYPE_ordered',
#  'DAYS_ID_PUBLISH',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'ORGANIZATION_TYPE_ordered',
#  'INS_AMT_PAYMENT_SUM',
#  'DAYS_BIRTH',
#  'POS_MONTHS_BALANCE_MAX',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'NEW_SOURCES_PROD',
#  'PREV_APP_CREDIT_PERC_MAX',
#  'NAME_FAMILY_STATUS_ordered',
#  'TARGET']

# %%
# features common to stepbwd and step fwd
s6 = s3.intersection(s2)
feat_common_stepbkwd_stepfwd = list(s6)
feat_common_stepbkwd_stepfwd.append('TARGET')
feat_common_stepbkwd_stepfwd
# Out:
# ['CNT_FAM_MEMBERS',
#  'INS_NUM_INSTALMENT_VERSION_NUNIQUE',
#  'AMT_ANNUITY',
#  'NAME_TYPE_SUITE_ordered',
#  'INS_AMT_PAYMENT_MEAN',
#  'WEEKDAY_APPR_PROCESS_START_ordered',
#  'NAME_EDUCATION_TYPE_ordered',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'INS_DAYS_ENTRY_PAYMENT_MEAN',
#  'INS_AMT_PAYMENT_SUM',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'BURO_AMT_CREDIT_SUM_MEAN',
#  'NAME_INCOME_TYPE_ordered',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'NAME_FAMILY_STATUS_ordered',
#  'TARGET']

# %%
s4
# Out:
# {'BURO_AMT_CREDIT_SUM_SUM',
#  'CNT_FAM_MEMBERS',
#  'EXT_SOURCE_2',
#  'INS_AMT_PAYMENT_MIN',
#  'INS_AMT_PAYMENT_SUM',
#  'NAME_EDUCATION_TYPE_ordered',
#  'NAME_FAMILY_STATUS_ordered',
#  'NAME_INCOME_TYPE_ordered',
#  'NEW_EXT_SOURCES_MEAN',
#  'NEW_INC_BY_ORG',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'PREV_HOUR_APPR_PROCESS_START_MIN',
#  'PREV_RATE_DOWN_PAYMENT_MIN'}

# %%
s3
# Out:
# {'AMT_ANNUITY',
#  'AMT_CREDIT',
#  'BURO_AMT_CREDIT_SUM_MEAN',
#  'BURO_DAYS_CREDIT_UPDATE_MAX',
#  'CNT_FAM_MEMBERS',
#  'DAYS_BIRTH',
#  'DAYS_ID_PUBLISH',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'EXT_SOURCE_3',
#  'INS_AMT_PAYMENT_MEAN',
#  'INS_AMT_PAYMENT_SUM',
#  'INS_DAYS_ENTRY_PAYMENT_MEAN',
#  'INS_DPD_MAX',
#  'INS_NUM_INSTALMENT_VERSION_NUNIQUE',
#  'NAME_EDUCATION_TYPE_ordered',
#  'NAME_FAMILY_STATUS_ordered',
#  'NAME_INCOME_TYPE_ordered',
#  'NAME_TYPE_SUITE_ordered',
#  'NEW_CREDIT_TO_INCOME_RATIO',
#  'NEW_SCORES_STD',
#  'NEW_SOURCES_PROD',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'ORGANIZATION_TYPE_ordered',
#  'POS_MONTHS_BALANCE_MAX',
#  'PREV_APP_CREDIT_PERC_MAX',
#  'PREV_CNT_PAYMENT_MEAN',
#  'PREV_DAYS_DECISION_MAX',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'SK_ID_CURR',
#  'WEEKDAY_APPR_PROCESS_START_ordered'}

# %%
#s3 = {'BURO_AMT_CREDIT_SUM_SUM', 'INS_AMT_PAYMENT_SUM', 'INS_AMT_PAYMENT_MIN', 'EXT_SOURCE_2', 'NAME_EDUCATION_TYPE_ordered', 'PREV_RATE_DOWN_PAYMENT_MIN', 'NEW_INC_BY_ORG', 'CNT_FAM_MEMBERS', 'PREV_HOUR_APPR_PROCESS_START_MIN', 'NEW_EXT_SOURCES_MEAN', 'OBS_30_CNT_SOCIAL_CIRCLE', 'NAME_FAMILY_STATUS_ordered', 'NAME_INCOME_TYPE_ordered'}
feat_common_rfe_step_fwd = list(s4)
feat_common_rfe_step_fwd.append('TARGET')
feat_common_rfe_step_fwd
# Out:
# ['CNT_FAM_MEMBERS',
#  'EXT_SOURCE_2',
#  'INS_AMT_PAYMENT_MIN',
#  'NAME_EDUCATION_TYPE_ordered',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'NEW_EXT_SOURCES_MEAN',
#  'INS_AMT_PAYMENT_SUM',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'NEW_INC_BY_ORG',
#  'NAME_INCOME_TYPE_ordered',
#  'PREV_HOUR_APPR_PROCESS_START_MIN',
#  'BURO_AMT_CREDIT_SUM_SUM',
#  'NAME_FAMILY_STATUS_ordered',
#  'TARGET']

# %%
step_bkwd_feat.remove('SK_ID_CURR')
step_bkwd_feat.append('TARGET')

# %%
step_fwd_feat.append('TARGET')

# %%
rfe_feat.append('TARGET')

# %% [markdown]
# # MODEL CREATION USING PYCARET & COMMON FEATURES FROM STEP FORWARD AND RFE

# %%
train_imbalanced = train_imbalanced_sm_tk

# %%
data = train_imbalanced[feat_common_rfe_step_fwd]

# %%
data.shape
# Out:
# (562710, 14)

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_07040_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_07040_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_07040_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_07040_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_07040_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_07040_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_07040_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_07040_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_07040_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_07040_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_07040_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_07040_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_07040_row4_col1" class="data row4 col1" >(562710, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_07040_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_07040_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_07040_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_07040_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_07040_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_07040_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_07040_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_07040_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_07040_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_07040_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_07040_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_07040_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_07040_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_07040_row11_col1" class="data row11 col1" >(393896, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_07040_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_07040_row12_col1" class="data row12 col1" >(168814, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_07040_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_07040_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_07040_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_07040_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_07040_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_07040_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_07040_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_07040_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_07040_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_07040_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_07040_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_07040_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_07040_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_07040_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_07040_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_07040_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_07040_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_07040_row21_col1" class="data row21 col1" >17d4</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_07040_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_07040_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_07040_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_07040_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_07040_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_07040_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_07040_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_07040_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_07040_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_07040_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_07040_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_07040_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_07040_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_07040_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_07040_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_07040_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_07040_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_07040_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_07040_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
best_model2 = compare_models()
# Out:
# <style type="text/css">
# #T_add6e_ th {
#   text-align: left;
# }
# #T_add6e_row0_col0, #T_add6e_row0_col2, #T_add6e_row0_col3, #T_add6e_row1_col0, #T_add6e_row1_col1, #T_add6e_row1_col4, #T_add6e_row1_col5, #T_add6e_row1_col6, #T_add6e_row1_col7, #T_add6e_row2_col0, #T_add6e_row2_col1, #T_add6e_row2_col2, #T_add6e_row2_col3, #T_add6e_row2_col4, #T_add6e_row2_col5, #T_add6e_row2_col6, #T_add6e_row2_col7, #T_add6e_row3_col0, #T_add6e_row3_col1, #T_add6e_row3_col2, #T_add6e_row3_col3, #T_add6e_row3_col4, #T_add6e_row3_col5, #T_add6e_row3_col6, #T_add6e_row3_col7, #T_add6e_row4_col0, #T_add6e_row4_col1, #T_add6e_row4_col2, #T_add6e_row4_col3, #T_add6e_row4_col4, #T_add6e_row4_col5, #T_add6e_row4_col6, #T_add6e_row4_col7, #T_add6e_row5_col0, #T_add6e_row5_col1, #T_add6e_row5_col2, #T_add6e_row5_col3, #T_add6e_row5_col4, #T_add6e_row5_col5, #T_add6e_row5_col6, #T_add6e_row5_col7, #T_add6e_row6_col0, #T_add6e_row6_col1, #T_add6e_row6_col2, #T_add6e_row6_col3, #T_add6e_row6_col4, #T_add6e_row6_col5, #T_add6e_row6_col6, #T_add6e_row6_col7, #T_add6e_row7_col0, #T_add6e_row7_col1, #T_add6e_row7_col2, #T_add6e_row7_col3, #T_add6e_row7_col4, #T_add6e_row7_col5, #T_add6e_row7_col6, #T_add6e_row7_col7, #T_add6e_row8_col0, #T_add6e_row8_col1, #T_add6e_row8_col2, #T_add6e_row8_col3, #T_add6e_row8_col4, #T_add6e_row8_col5, #T_add6e_row8_col6, #T_add6e_row8_col7, #T_add6e_row9_col0, #T_add6e_row9_col1, #T_add6e_row9_col2, #T_add6e_row9_col3, #T_add6e_row9_col4, #T_add6e_row9_col5, #T_add6e_row9_col6, #T_add6e_row9_col7, #T_add6e_row10_col0, #T_add6e_row10_col1, #T_add6e_row10_col2, #T_add6e_row10_col3, #T_add6e_row10_col4, #T_add6e_row10_col5, #T_add6e_row10_col6, #T_add6e_row10_col7, #T_add6e_row11_col0, #T_add6e_row11_col1, #T_add6e_row11_col2, #T_add6e_row11_col3, #T_add6e_row11_col4, #T_add6e_row11_col5, #T_add6e_row11_col6, #T_add6e_row11_col7, #T_add6e_row12_col0, #T_add6e_row12_col1, #T_add6e_row12_col2, #T_add6e_row12_col3, #T_add6e_row12_col4, #T_add6e_row12_col5, #T_add6e_row12_col6, #T_add6e_row12_col7 {
#   text-align: left;
# }
# #T_add6e_row0_col1, #T_add6e_row0_col4, #T_add6e_row0_col5, #T_add6e_row0_col6, #T_add6e_row0_col7, #T_add6e_row1_col2, #T_add6e_row1_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_add6e_row0_col8, #T_add6e_row1_col8, #T_add6e_row2_col8, #T_add6e_row3_col8, #T_add6e_row4_col8, #T_add6e_row5_col8, #T_add6e_row6_col8, #T_add6e_row7_col8, #T_add6e_row8_col8, #T_add6e_row9_col8, #T_add6e_row11_col8, #T_add6e_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_add6e_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_add6e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_add6e_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_add6e_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_add6e_row0_col1" class="data row0 col1" >0.9537</td>
#       <td id="T_add6e_row0_col2" class="data row0 col2" >0.9762</td>
#       <td id="T_add6e_row0_col3" class="data row0 col3" >0.9092</td>
#       <td id="T_add6e_row0_col4" class="data row0 col4" >0.9980</td>
#       <td id="T_add6e_row0_col5" class="data row0 col5" >0.9515</td>
#       <td id="T_add6e_row0_col6" class="data row0 col6" >0.9074</td>
#       <td id="T_add6e_row0_col7" class="data row0 col7" >0.9110</td>
#       <td id="T_add6e_row0_col8" class="data row0 col8" >4.4550</td>
#     </tr>
#     <tr>
#       <th id="T_add6e_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_add6e_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_add6e_row1_col1" class="data row1 col1" >0.9529</td>
#       <td id="T_add6e_row1_col2" class="data row1 col2" >0.9828</td>
#       <td id="T_add6e_row1_col3" class="data row1 col3" >0.9183</td>
#       <td id="T_add6e_row1_col4" class="data row1 col4" >0.9866</td>
#       <td id="T_add6e_row1_col5" class="data row1 col5" >0.9512</td>
#       <td id="T_add6e_row1_col6" class="data row1 col6" >0.9059</td>
#       <td id="T_add6e_row1_col7" class="data row1 col7" >0.9080</td>
#       <td id="T_add6e_row1_col8" class="data row1 col8" >84.2720</td>
#     </tr>
#     <tr>
#       <th id="T_add6e_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_add6e_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_add6e_row2_col1" class="data row2 col1" >0.9500</td>
#       <td id="T_add6e_row2_col2" class="data row2 col2" >0.9764</td>
#       <td id="T_add6e_row2_col3" class="data row2 col3" >0.9057</td>
#       <td id="T_add6e_row2_col4" class="data row2 col4" >0.9939</td>
#       <td id="T_add6e_row2_col5" class="data row2 col5" >0.9477</td>
#       <td id="T_add6e_row2_col6" class="data row2 col6" >0.9001</td>
#       <td id="T_add6e_row2_col7" class="data row2 col7" >0.9037</td>
#       <td id="T_add6e_row2_col8" class="data row2 col8" >50.0460</td>
#     </tr>
#     <tr>
#       <th id="T_add6e_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_add6e_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_add6e_row3_col1" class="data row3 col1" >0.9416</td>
#       <td id="T_add6e_row3_col2" class="data row3 col2" >0.9717</td>
#       <td id="T_add6e_row3_col3" class="data row3 col3" >0.8911</td>
#       <td id="T_add6e_row3_col4" class="data row3 col4" >0.9912</td>
#       <td id="T_add6e_row3_col5" class="data row3 col5" >0.9385</td>
#       <td id="T_add6e_row3_col6" class="data row3 col6" >0.8832</td>
#       <td id="T_add6e_row3_col7" class="data row3 col7" >0.8878</td>
#       <td id="T_add6e_row3_col8" class="data row3 col8" >73.2650</td>
#     </tr>
#     <tr>
#       <th id="T_add6e_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_add6e_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_add6e_row4_col1" class="data row4 col1" >0.9081</td>
#       <td id="T_add6e_row4_col2" class="data row4 col2" >0.9570</td>
#       <td id="T_add6e_row4_col3" class="data row4 col3" >0.8632</td>
#       <td id="T_add6e_row4_col4" class="data row4 col4" >0.9484</td>
#       <td id="T_add6e_row4_col5" class="data row4 col5" >0.9038</td>
#       <td id="T_add6e_row4_col6" class="data row4 col6" >0.8162</td>
#       <td id="T_add6e_row4_col7" class="data row4 col7" >0.8195</td>
#       <td id="T_add6e_row4_col8" class="data row4 col8" >16.6700</td>
#     </tr>
#     <tr>
#       <th id="T_add6e_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_add6e_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_add6e_row5_col1" class="data row5 col1" >0.9029</td>
#       <td id="T_add6e_row5_col2" class="data row5 col2" >0.9029</td>
#       <td id="T_add6e_row5_col3" class="data row5 col3" >0.9095</td>
#       <td id="T_add6e_row5_col4" class="data row5 col4" >0.8977</td>
#       <td id="T_add6e_row5_col5" class="data row5 col5" >0.9035</td>
#       <td id="T_add6e_row5_col6" class="data row5 col6" >0.8058</td>
#       <td id="T_add6e_row5_col7" class="data row5 col7" >0.8059</td>
#       <td id="T_add6e_row5_col8" class="data row5 col8" >2.9900</td>
#     </tr>
#     <tr>
#       <th id="T_add6e_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_add6e_row6_col0" class="data row6 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_add6e_row6_col1" class="data row6 col1" >0.7054</td>
#       <td id="T_add6e_row6_col2" class="data row6 col2" >0.7753</td>
#       <td id

# %%
print (best_model2)
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
pred_holdout_mod1 = predict_model(best_model2)
# Out:
# <style type="text/css">
# </style>
# <table id="T_71bcd_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71bcd_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71bcd_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_71bcd_row0_col1" class="data row0 col1" >0.9539</td>
#       <td id="T_71bcd_row0_col2" class="data row0 col2" >0.9767</td>
#       <td id="T_71bcd_row0_col3" class="data row0 col3" >0.9097</td>
#       <td id="T_71bcd_row0_col4" class="data row0 col4" >0.9978</td>
#       <td id="T_71bcd_row0_col5" class="data row0 col5" >0.9517</td>
#       <td id="T_71bcd_row0_col6" class="data row0 col6" >0.9078</td>
#       <td id="T_71bcd_row0_col7" class="data row0 col7" >0.9113</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model2)

# %%
evaluate_model(best_model2)
# Out:
#                   Parameters
# boosting_type           gbdt
# class_weight            None
# colsample_bytree         1.0
# importance_type        split
# learning_rate            0.1
# max_depth                 -1
# min_child_samples         20
# min_child_weight       0.001
# min_split_gain           0.0
# n_estimators             100
# n_jobs                    -1
# num_leaves                31
# objective               None
# random_state             123
# reg_alpha                0.0
# reg_lambda               0.0
# silent                  warn
# subsample                1.0
# subsample_for_bin     200000
# subsample_freq             0

# %%
pred_holdout_mod2 = predict_model(best_model2[1])

# %%
pred_holdout_mod3 = predict_model(best_model2[2])

# %% [markdown]
# # MODEL CREATION USING PYCARET &  COMMON FEATURES FROM STEP BACKWARD AND RFE

# %%
data = train_imbalanced[feat_common_stepbkwd_rfe]

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_34b68_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_34b68_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_34b68_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_34b68_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_34b68_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_34b68_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_34b68_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_34b68_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_34b68_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_34b68_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_34b68_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_34b68_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_34b68_row4_col1" class="data row4 col1" >(562710, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_34b68_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_34b68_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_34b68_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_34b68_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_34b68_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_34b68_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_34b68_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_34b68_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_34b68_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_34b68_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_34b68_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_34b68_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_34b68_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_34b68_row11_col1" class="data row11 col1" >(393896, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_34b68_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_34b68_row12_col1" class="data row12 col1" >(168814, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_34b68_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_34b68_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_34b68_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_34b68_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_34b68_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_34b68_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_34b68_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_34b68_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_34b68_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_34b68_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_34b68_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_34b68_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_34b68_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_34b68_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_34b68_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_34b68_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_34b68_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_34b68_row21_col1" class="data row21 col1" >52a4</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_34b68_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_34b68_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_34b68_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_34b68_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_34b68_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_34b68_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_34b68_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_34b68_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_34b68_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_34b68_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_34b68_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_34b68_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_34b68_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_34b68_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_34b68_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_34b68_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_34b68_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_34b68_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_34b68_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
best_model3 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_3f15a_ th {
#   text-align: left;
# }
# #T_3f15a_row0_col0, #T_3f15a_row0_col2, #T_3f15a_row0_col3, #T_3f15a_row0_col5, #T_3f15a_row1_col0, #T_3f15a_row1_col1, #T_3f15a_row1_col4, #T_3f15a_row1_col6, #T_3f15a_row1_col7, #T_3f15a_row2_col0, #T_3f15a_row2_col1, #T_3f15a_row2_col2, #T_3f15a_row2_col3, #T_3f15a_row2_col4, #T_3f15a_row2_col5, #T_3f15a_row2_col6, #T_3f15a_row2_col7, #T_3f15a_row3_col0, #T_3f15a_row3_col1, #T_3f15a_row3_col2, #T_3f15a_row3_col3, #T_3f15a_row3_col4, #T_3f15a_row3_col5, #T_3f15a_row3_col6, #T_3f15a_row3_col7, #T_3f15a_row4_col0, #T_3f15a_row4_col1, #T_3f15a_row4_col2, #T_3f15a_row4_col3, #T_3f15a_row4_col4, #T_3f15a_row4_col5, #T_3f15a_row4_col6, #T_3f15a_row4_col7, #T_3f15a_row5_col0, #T_3f15a_row5_col1, #T_3f15a_row5_col2, #T_3f15a_row5_col3, #T_3f15a_row5_col4, #T_3f15a_row5_col5, #T_3f15a_row5_col6, #T_3f15a_row5_col7, #T_3f15a_row6_col0, #T_3f15a_row6_col1, #T_3f15a_row6_col2, #T_3f15a_row6_col3, #T_3f15a_row6_col4, #T_3f15a_row6_col5, #T_3f15a_row6_col6, #T_3f15a_row6_col7, #T_3f15a_row7_col0, #T_3f15a_row7_col1, #T_3f15a_row7_col2, #T_3f15a_row7_col3, #T_3f15a_row7_col4, #T_3f15a_row7_col5, #T_3f15a_row7_col6, #T_3f15a_row7_col7, #T_3f15a_row8_col0, #T_3f15a_row8_col1, #T_3f15a_row8_col2, #T_3f15a_row8_col3, #T_3f15a_row8_col4, #T_3f15a_row8_col5, #T_3f15a_row8_col6, #T_3f15a_row8_col7, #T_3f15a_row9_col0, #T_3f15a_row9_col1, #T_3f15a_row9_col2, #T_3f15a_row9_col3, #T_3f15a_row9_col4, #T_3f15a_row9_col5, #T_3f15a_row9_col6, #T_3f15a_row9_col7, #T_3f15a_row10_col0, #T_3f15a_row10_col1, #T_3f15a_row10_col2, #T_3f15a_row10_col3, #T_3f15a_row10_col4, #T_3f15a_row10_col5, #T_3f15a_row10_col6, #T_3f15a_row10_col7, #T_3f15a_row11_col0, #T_3f15a_row11_col1, #T_3f15a_row11_col2, #T_3f15a_row11_col3, #T_3f15a_row11_col4, #T_3f15a_row11_col5, #T_3f15a_row11_col6, #T_3f15a_row11_col7, #T_3f15a_row12_col0, #T_3f15a_row12_col1, #T_3f15a_row12_col2, #T_3f15a_row12_col3, #T_3f15a_row12_col4, #T_3f15a_row12_col5, #T_3f15a_row12_col6, #T_3f15a_row12_col7 {
#   text-align: left;
# }
# #T_3f15a_row0_col1, #T_3f15a_row0_col4, #T_3f15a_row0_col6, #T_3f15a_row0_col7, #T_3f15a_row1_col2, #T_3f15a_row1_col3, #T_3f15a_row1_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_3f15a_row0_col8, #T_3f15a_row1_col8, #T_3f15a_row2_col8, #T_3f15a_row3_col8, #T_3f15a_row4_col8, #T_3f15a_row5_col8, #T_3f15a_row6_col8, #T_3f15a_row7_col8, #T_3f15a_row8_col8, #T_3f15a_row10_col8, #T_3f15a_row11_col8, #T_3f15a_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_3f15a_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_3f15a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3f15a_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_3f15a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_3f15a_row0_col1" class="data row0 col1" >0.9516</td>
#       <td id="T_3f15a_row0_col2" class="data row0 col2" >0.9753</td>
#       <td id="T_3f15a_row0_col3" class="data row0 col3" >0.9056</td>
#       <td id="T_3f15a_row0_col4" class="data row0 col4" >0.9973</td>
#       <td id="T_3f15a_row0_col5" class="data row0 col5" >0.9492</td>
#       <td id="T_3f15a_row0_col6" class="data row0 col6" >0.9031</td>
#       <td id="T_3f15a_row0_col7" class="data row0 col7" >0.9070</td>
#       <td id="T_3f15a_row0_col8" class="data row0 col8" >4.1350</td>
#     </tr>
#     <tr>
#       <th id="T_3f15a_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_3f15a_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_3f15a_row1_col1" class="data row1 col1" >0.9514</td>
#       <td id="T_3f15a_row1_col2" class="data row1 col2" >0.9823</td>
#       <td id="T_3f15a_row1_col3" class="data row1 col3" >0.9166</td>
#       <td id="T_3f15a_row1_col4" class="data row1 col4" >0.9851</td>
#       <td id="T_3f15a_row1_col5" class="data row1 col5" >0.9496</td>
#       <td id="T_3f15a_row1_col6" class="data row1 col6" >0.9027</td>
#       <td id="T_3f15a_row1_col7" class="data row1 col7" >0.9049</td>
#       <td id="T_3f15a_row1_col8" class="data row1 col8" >81.8520</td>
#     </tr>
#     <tr>
#       <th id="T_3f15a_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_3f15a_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_3f15a_row2_col1" class="data row2 col1" >0.9488</td>
#       <td id="T_3f15a_row2_col2" class="data row2 col2" >0.9755</td>
#       <td id="T_3f15a_row2_col3" class="data row2 col3" >0.9031</td>
#       <td id="T_3f15a_row2_col4" class="data row2 col4" >0.9940</td>
#       <td id="T_3f15a_row2_col5" class="data row2 col5" >0.9464</td>
#       <td id="T_3f15a_row2_col6" class="data row2 col6" >0.8977</td>
#       <td id="T_3f15a_row2_col7" class="data row2 col7" >0.9015</td>
#       <td id="T_3f15a_row2_col8" class="data row2 col8" >51.7450</td>
#     </tr>
#     <tr>
#       <th id="T_3f15a_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_3f15a_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_3f15a_row3_col1" class="data row3 col1" >0.9386</td>
#       <td id="T_3f15a_row3_col2" class="data row3 col2" >0.9706</td>
#       <td id="T_3f15a_row3_col3" class="data row3 col3" >0.8848</td>
#       <td id="T_3f15a_row3_col4" class="data row3 col4" >0.9914</td>
#       <td id="T_3f15a_row3_col5" class="data row3 col5" >0.9351</td>
#       <td id="T_3f15a_row3_col6" class="data row3 col6" >0.8771</td>
#       <td id="T_3f15a_row3_col7" class="data row3 col7" >0.8822</td>
#       <td id="T_3f15a_row3_col8" class="data row3 col8" >81.8230</td>
#     </tr>
#     <tr>
#       <th id="T_3f15a_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_3f15a_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_3f15a_row4_col1" class="data row4 col1" >0.9038</td>
#       <td id="T_3f15a_row4_col2" class="data row4 col2" >0.9565</td>
#       <td id="T_3f15a_row4_col3" class="data row4 col3" >0.8661</td>
#       <td id="T_3f15a_row4_col4" class="data row4 col4" >0.9367</td>
#       <td id="T_3f15a_row4_col5" class="data row4 col5" >0.9000</td>
#       <td id="T_3f15a_row4_col6" class="data row4 col6" >0.8075</td>
#       <td id="T_3f15a_row4_col7" class="data row4 col7" >0.8099</td>
#       <td id="T_3f15a_row4_col8" class="data row4 col8" >18.5080</td>
#     </tr>
#     <tr>
#       <th id="T_3f15a_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_3f15a_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_3f15a_row5_col1" class="data row5 col1" >0.9019</td>
#       <td id="T_3f15a_row5_col2" class="data row5 col2" >0.9019</td>
#       <td id="T_3f15a_row5_col3" class="data row5 col3" >0.9078</td>
#       <td id="T_3f15a_row5_col4" class="data row5 col4" >0.8971</td>
#       <td id="T_3f15a_row5_col5" class="data row5 col5" >0.9024</td>
#       <td id="T_3f15a_row5_col6" class="data row5 col6" >0.8037</td>
#       <td id="T_3f15a_row5_col7" class="data row5 col7" >0.8038</td>
#       <td id="T_3f15a_row5_col8" class="data row5 col8" >2.6090</td>
#     </tr>
#     <tr>
#       <th id="T_3f15a_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_3f15a_row6_col0" class="data row6 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_3f15a_row6_col1" class="data row6 col1" >0.7103</td>
#       <td id="T_3f15a_row6_col2" class="data row6 col2" >0.7764</td>
#       <td id

# %%
pred_holdout_mod21 = predict_model(best_model3[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_47ff6_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_47ff6_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_47ff6_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_47ff6_row0_col1" class="data row0 col1" >0.9514</td>
#       <td id="T_47ff6_row0_col2" class="data row0 col2" >0.9756</td>
#       <td id="T_47ff6_row0_col3" class="data row0 col3" >0.9054</td>
#       <td id="T_47ff6_row0_col4" class="data row0 col4" >0.9970</td>
#       <td id="T_47ff6_row0_col5" class="data row0 col5" >0.9490</td>
#       <td id="T_47ff6_row0_col6" class="data row0 col6" >0.9027</td>
#       <td id="T_47ff6_row0_col7" class="data row0 col7" >0.9065</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod22 = predict_model(best_model3[1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_ae451_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ae451_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ae451_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_ae451_row0_col1" class="data row0 col1" >0.9527</td>
#       <td id="T_ae451_row0_col2" class="data row0 col2" >0.9832</td>
#       <td id="T_ae451_row0_col3" class="data row0 col3" >0.9188</td>
#       <td id="T_ae451_row0_col4" class="data row0 col4" >0.9856</td>
#       <td id="T_ae451_row0_col5" class="data row0 col5" >0.9511</td>
#       <td id="T_ae451_row0_col6" class="data row0 col6" >0.9055</td>
#       <td id="T_ae451_row0_col7" class="data row0 col7" >0.9075</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod23 = predict_model(best_model3[2])
# Out:
# <style type="text/css">
# </style>
# <table id="T_9a70c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9a70c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9a70c_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_9a70c_row0_col1" class="data row0 col1" >0.9490</td>
#       <td id="T_9a70c_row0_col2" class="data row0 col2" >0.9765</td>
#       <td id="T_9a70c_row0_col3" class="data row0 col3" >0.9039</td>
#       <td id="T_9a70c_row0_col4" class="data row0 col4" >0.9935</td>
#       <td id="T_9a70c_row0_col5" class="data row0 col5" >0.9466</td>
#       <td id="T_9a70c_row0_col6" class="data row0 col6" >0.8980</td>
#       <td id="T_9a70c_row0_col7" class="data row0 col7" >0.9017</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model3[0])

# %%
plot_model(best_model3[1])

# %%
plot_model(best_model3[2])

# %%
evaluate_model(best_model3[0])
# Out:
#                   Parameters
# boosting_type           gbdt
# class_weight            None
# colsample_bytree         1.0
# importance_type        split
# learning_rate            0.1
# max_depth                 -1
# min_child_samples         20
# min_child_weight       0.001
# min_split_gain           0.0
# n_estimators             100
# n_jobs                    -1
# num_leaves                31
# objective               None
# random_state             123
# reg_alpha                0.0
# reg_lambda               0.0
# silent                  warn
# subsample                1.0
# subsample_for_bin     200000
# subsample_freq             0

# %% [markdown]
# # MODEL CREATION USING PYCARET &  COMMON FEATURES FROM  STEP BACKWARD AND STEP FORWARD

# %%
data = train_imbalanced[feat_common_stepbkwd_stepfwd]

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_d0fd4_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_d0fd4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d0fd4_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d0fd4_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_d0fd4_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d0fd4_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_d0fd4_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d0fd4_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_d0fd4_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d0fd4_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_d0fd4_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d0fd4_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_d0fd4_row4_col1" class="data row4 col1" >(562710, 16)</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d0fd4_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_d0fd4_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d0fd4_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_d0fd4_row6_col1" class="data row6 col1" >15</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d0fd4_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_d0fd4_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d0fd4_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_d0fd4_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d0fd4_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_d0fd4_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_d0fd4_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_d0fd4_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_d0fd4_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_d0fd4_row11_col1" class="data row11 col1" >(393896, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_d0fd4_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_d0fd4_row12_col1" class="data row12 col1" >(168814, 15)</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_d0fd4_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_d0fd4_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_d0fd4_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_d0fd4_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_d0fd4_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_d0fd4_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_d0fd4_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_d0fd4_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_d0fd4_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_d0fd4_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_d0fd4_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_d0fd4_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_d0fd4_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_d0fd4_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_d0fd4_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_d0fd4_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_d0fd4_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_d0fd4_row21_col1" class="data row21 col1" >cb8e</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_d0fd4_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_d0fd4_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_d0fd4_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_d0fd4_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_d0fd4_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_d0fd4_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_d0fd4_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_d0fd4_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_d0fd4_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_d0fd4_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_d0fd4_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_d0fd4_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_d0fd4_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_d0fd4_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_d0fd4_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_d0fd4_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_d0fd4_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_d0fd4_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_d0fd4_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
best_model4 = compare_models()
# Out:
# <style type="text/css">
# #T_26103_ th {
#   text-align: left;
# }
# #T_26103_row0_col0, #T_26103_row0_col3, #T_26103_row0_col4, #T_26103_row1_col0, #T_26103_row1_col1, #T_26103_row1_col2, #T_26103_row1_col3, #T_26103_row1_col5, #T_26103_row1_col6, #T_26103_row2_col0, #T_26103_row2_col1, #T_26103_row2_col2, #T_26103_row2_col3, #T_26103_row2_col4, #T_26103_row2_col5, #T_26103_row2_col6, #T_26103_row2_col7, #T_26103_row3_col0, #T_26103_row3_col1, #T_26103_row3_col2, #T_26103_row3_col3, #T_26103_row3_col4, #T_26103_row3_col5, #T_26103_row3_col6, #T_26103_row3_col7, #T_26103_row4_col0, #T_26103_row4_col1, #T_26103_row4_col2, #T_26103_row4_col3, #T_26103_row4_col4, #T_26103_row4_col5, #T_26103_row4_col6, #T_26103_row4_col7, #T_26103_row5_col0, #T_26103_row5_col1, #T_26103_row5_col2, #T_26103_row5_col4, #T_26103_row5_col5, #T_26103_row5_col6, #T_26103_row5_col7, #T_26103_row6_col0, #T_26103_row6_col1, #T_26103_row6_col2, #T_26103_row6_col3, #T_26103_row6_col4, #T_26103_row6_col5, #T_26103_row6_col6, #T_26103_row6_col7, #T_26103_row7_col0, #T_26103_row7_col1, #T_26103_row7_col2, #T_26103_row7_col3, #T_26103_row7_col4, #T_26103_row7_col5, #T_26103_row7_col6, #T_26103_row7_col7, #T_26103_row8_col0, #T_26103_row8_col1, #T_26103_row8_col2, #T_26103_row8_col3, #T_26103_row8_col4, #T_26103_row8_col5, #T_26103_row8_col6, #T_26103_row8_col7, #T_26103_row9_col0, #T_26103_row9_col1, #T_26103_row9_col2, #T_26103_row9_col3, #T_26103_row9_col4, #T_26103_row9_col5, #T_26103_row9_col6, #T_26103_row9_col7, #T_26103_row10_col0, #T_26103_row10_col1, #T_26103_row10_col2, #T_26103_row10_col3, #T_26103_row10_col4, #T_26103_row10_col5, #T_26103_row10_col6, #T_26103_row10_col7, #T_26103_row11_col0, #T_26103_row11_col1, #T_26103_row11_col2, #T_26103_row11_col3, #T_26103_row11_col4, #T_26103_row11_col5, #T_26103_row11_col6, #T_26103_row11_col7, #T_26103_row12_col0, #T_26103_row12_col1, #T_26103_row12_col2, #T_26103_row12_col3, #T_26103_row12_col4, #T_26103_row12_col5, #T_26103_row12_col6, #T_26103_row12_col7 {
#   text-align: left;
# }
# #T_26103_row0_col1, #T_26103_row0_col2, #T_26103_row0_col5, #T_26103_row0_col6, #T_26103_row0_col7, #T_26103_row1_col4, #T_26103_row1_col7, #T_26103_row5_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_26103_row0_col8, #T_26103_row1_col8, #T_26103_row2_col8, #T_26103_row3_col8, #T_26103_row4_col8, #T_26103_row5_col8, #T_26103_row6_col8, #T_26103_row7_col8, #T_26103_row9_col8, #T_26103_row10_col8, #T_26103_row11_col8, #T_26103_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_26103_row8_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_26103_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26103_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_26103_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_26103_row0_col1" class="data row0 col1" >0.9550</td>
#       <td id="T_26103_row0_col2" class="data row0 col2" >0.9807</td>
#       <td id="T_26103_row0_col3" class="data row0 col3" >0.9136</td>
#       <td id="T_26103_row0_col4" class="data row0 col4" >0.9961</td>
#       <td id="T_26103_row0_col5" class="data row0 col5" >0.9531</td>
#       <td id="T_26103_row0_col6" class="data row0 col6" >0.9100</td>
#       <td id="T_26103_row0_col7" class="data row0 col7" >0.9131</td>
#       <td id="T_26103_row0_col8" class="data row0 col8" >48.0770</td>
#     </tr>
#     <tr>
#       <th id="T_26103_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_26103_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_26103_row1_col1" class="data row1 col1" >0.9547</td>
#       <td id="T_26103_row1_col2" class="data row1 col2" >0.9689</td>
#       <td id="T_26103_row1_col3" class="data row1 col3" >0.9098</td>
#       <td id="T_26103_row1_col4" class="data row1 col4" >0.9995</td>
#       <td id="T_26103_row1_col5" class="data row1 col5" >0.9526</td>
#       <td id="T_26103_row1_col6" class="data row1 col6" >0.9094</td>
#       <td id="T_26103_row1_col7" class="data row1 col7" >0.9131</td>
#       <td id="T_26103_row1_col8" class="data row1 col8" >4.2920</td>
#     </tr>
#     <tr>
#       <th id="T_26103_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_26103_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_26103_row2_col1" class="data row2 col1" >0.9536</td>
#       <td id="T_26103_row2_col2" class="data row2 col2" >0.9687</td>
#       <td id="T_26103_row2_col3" class="data row2 col3" >0.9092</td>
#       <td id="T_26103_row2_col4" class="data row2 col4" >0.9977</td>
#       <td id="T_26103_row2_col5" class="data row2 col5" >0.9514</td>
#       <td id="T_26103_row2_col6" class="data row2 col6" >0.9071</td>
#       <td id="T_26103_row2_col7" class="data row2 col7" >0.9107</td>
#       <td id="T_26103_row2_col8" class="data row2 col8" >51.8710</td>
#     </tr>
#     <tr>
#       <th id="T_26103_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_26103_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_26103_row3_col1" class="data row3 col1" >0.9498</td>
#       <td id="T_26103_row3_col2" class="data row3 col2" >0.9649</td>
#       <td id="T_26103_row3_col3" class="data row3 col3" >0.9010</td>
#       <td id="T_26103_row3_col4" class="data row3 col4" >0.9985</td>
#       <td id="T_26103_row3_col5" class="data row3 col5" >0.9472</td>
#       <td id="T_26103_row3_col6" class="data row3 col6" >0.8996</td>
#       <td id="T_26103_row3_col7" class="data row3 col7" >0.9040</td>
#       <td id="T_26103_row3_col8" class="data row3 col8" >85.2010</td>
#     </tr>
#     <tr>
#       <th id="T_26103_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_26103_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_26103_row4_col1" class="data row4 col1" >0.9241</td>
#       <td id="T_26103_row4_col2" class="data row4 col2" >0.9552</td>
#       <td id="T_26103_row4_col3" class="data row4 col3" >0.8719</td>
#       <td id="T_26103_row4_col4" class="data row4 col4" >0.9736</td>
#       <td id="T_26103_row4_col5" class="data row4 col5" >0.9199</td>
#       <td id="T_26103_row4_col6" class="data row4 col6" >0.8482</td>
#       <td id="T_26103_row4_col7" class="data row4 col7" >0.8529</td>
#       <td id="T_26103_row4_col8" class="data row4 col8" >18.8160</td>
#     </tr>
#     <tr>
#       <th id="T_26103_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_26103_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_26103_row5_col1" class="data row5 col1" >0.9066</td>
#       <td id="T_26103_row5_col2" class="data row5 col2" >0.9066</td>
#       <td id="T_26103_row5_col3" class="data row5 col3" >0.9143</td>
#       <td id="T_26103_row5_col4" class="data row5 col4" >0.9004</td>
#       <td id="T_26103_row5_col5" class="data row5 col5" >0.9073</td>
#       <td id="T_26103_row5_col6" class="data row5 col6" >0.8132</td>
#       <td id="T_26103_row5_col7" class="data row5 col7" >0.8133</td>
#       <td id="T_26103_row5_col8" class="data row5 col8" >3.0650</td>
#     </tr>
#     <tr>
#       <th id="T_26103_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_26103_row6_col0" class="data row6 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_26103_row6_col1" class="data row6 col1" >0.6679</td>
#       <td id="T_26103_row6_col2" class="data row6 col2" >0.7246</td>
#       <td id

# %%
pred_holdout_mod31 = predict_model(best_model4[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_b7f7b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b7f7b_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b7f7b_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_b7f7b_row0_col1" class="data row0 col1" >0.8685</td>
#       <td id="T_b7f7b_row0_col2" class="data row0 col2" >0.8685</td>
#       <td id="T_b7f7b_row0_col3" class="data row0 col3" >0.8718</td>
#       <td id="T_b7f7b_row0_col4" class="data row0 col4" >0.8662</td>
#       <td id="T_b7f7b_row0_col5" class="data row0 col5" >0.8690</td>
#       <td id="T_b7f7b_row0_col6" class="data row0 col6" >0.7371</td>
#       <td id="T_b7f7b_row0_col7" class="data row0 col7" >0.7371</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod32 = predict_model(best_model4[1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_26812_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_26812_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_26812_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_26812_row0_col1" class="data row0 col1" >0.8815</td>
#       <td id="T_26812_row0_col2" class="data row0 col2" >0.8815</td>
#       <td id="T_26812_row0_col3" class="data row0 col3" >0.8831</td>
#       <td id="T_26812_row0_col4" class="data row0 col4" >0.8803</td>
#       <td id="T_26812_row0_col5" class="data row0 col5" >0.8817</td>
#       <td id="T_26812_row0_col6" class="data row0 col6" >0.7630</td>
#       <td id="T_26812_row0_col7" class="data row0 col7" >0.7630</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod33 = predict_model(best_model4[2])
# Out:
# <style type="text/css">
# </style>
# <table id="T_5ba62_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ba62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ba62_row0_col0" class="data row0 col0" >Decision Tree Classifier</td>
#       <td id="T_5ba62_row0_col1" class="data row0 col1" >0.8624</td>
#       <td id="T_5ba62_row0_col2" class="data row0 col2" >0.8624</td>
#       <td id="T_5ba62_row0_col3" class="data row0 col3" >0.8658</td>
#       <td id="T_5ba62_row0_col4" class="data row0 col4" >0.8599</td>
#       <td id="T_5ba62_row0_col5" class="data row0 col5" >0.8628</td>
#       <td id="T_5ba62_row0_col6" class="data row0 col6" >0.7247</td>
#       <td id="T_5ba62_row0_col7" class="data row0 col7" >0.7247</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model4[0])

# %%
plot_model(best_model4[1])

# %%
plot_model(best_model4[2])

# %%
evaluate_model(best_model4[0])
# Out:
#                          Parameters
# ccp_alpha                       0.0
# class_weight                   None
# criterion                      gini
# max_depth                      None
# max_features                   auto
# max_leaf_nodes                 None
# min_impurity_decrease           0.0
# min_impurity_split             None
# min_samples_leaf                  1
# min_samples_split                 2
# min_weight_fraction_leaf        0.0
# random_state              843828734
# splitter                     random

# %% [markdown]
# # MODEL CREATION USING PYCARET &  FEATURES FROM  STEP FORWARD SELECTION

# %%
step_fwd_feat
# Out:
# ['AMT_INCOME_TOTAL',
#  'AMT_ANNUITY',
#  'AMT_GOODS_PRICE',
#  'REGION_POPULATION_RELATIVE',
#  'CNT_FAM_MEMBERS',
#  'HOUR_APPR_PROCESS_START',
#  'EXT_SOURCE_2',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'DAYS_LAST_PHONE_CHANGE',
#  'NEW_INC_BY_ORG',
#  'NEW_EXT_SOURCES_MEAN',
#  'NAME_TYPE_SUITE_ordered',
#  'NAME_INCOME_TYPE_ordered',
#  'NAME_EDUCATION_TYPE_ordered',
#  'NAME_FAMILY_STATUS_ordered',
#  'WEEKDAY_APPR_PROCESS_START_ordered',
#  'BURO_DAYS_CREDIT_ENDDATE_MAX',
#  'BURO_AMT_CREDIT_SUM_MEAN',
#  'BURO_AMT_CREDIT_SUM_SUM',
#  'PREV_APP_CREDIT_PERC_MEAN',
#  'PREV_HOUR_APPR_PROCESS_START_MIN',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'INS_NUM_INSTALMENT_VERSION_NUNIQUE',
#  'INS_DBD_MAX',
#  'INS_DBD_SUM',
#  'INS_AMT_PAYMENT_MIN',
#  'INS_AMT_PAYMENT_MEAN',
#  'INS_AMT_PAYMENT_SUM',
#  'INS_DAYS_ENTRY_PAYMENT_MEAN',
#  'TARGET']

# %%
step_fwd_feat.append('TARGET')

# %%
#step_fwd_feat.append('TARGET')
data = train_imbalanced[step_fwd_feat]

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_f17eb_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_f17eb_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f17eb_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f17eb_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_f17eb_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_f17eb_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_f17eb_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_f17eb_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_f17eb_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_f17eb_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_f17eb_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_f17eb_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_f17eb_row4_col1" class="data row4 col1" >(562710, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_f17eb_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_f17eb_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_f17eb_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_f17eb_row6_col1" class="data row6 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_f17eb_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_f17eb_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_f17eb_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_f17eb_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_f17eb_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_f17eb_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_f17eb_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_f17eb_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_f17eb_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_f17eb_row11_col1" class="data row11 col1" >(393896, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_f17eb_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_f17eb_row12_col1" class="data row12 col1" >(168814, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_f17eb_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_f17eb_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_f17eb_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_f17eb_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_f17eb_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_f17eb_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_f17eb_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_f17eb_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_f17eb_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_f17eb_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_f17eb_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_f17eb_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_f17eb_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_f17eb_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_f17eb_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_f17eb_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_f17eb_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_f17eb_row21_col1" class="data row21 col1" >6e4c</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_f17eb_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_f17eb_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_f17eb_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_f17eb_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_f17eb_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_f17eb_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_f17eb_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_f17eb_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_f17eb_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_f17eb_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_f17eb_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_f17eb_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_f17eb_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_f17eb_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_f17eb_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_f17eb_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_f17eb_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_f17eb_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_f17eb_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
best_model5 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_6d953_ th {
#   text-align: left;
# }
# #T_6d953_row0_col0, #T_6d953_row0_col4, #T_6d953_row1_col0, #T_6d953_row1_col1, #T_6d953_row1_col2, #T_6d953_row1_col3, #T_6d953_row1_col5, #T_6d953_row1_col6, #T_6d953_row1_col7, #T_6d953_row2_col0, #T_6d953_row2_col1, #T_6d953_row2_col2, #T_6d953_row2_col3, #T_6d953_row2_col4, #T_6d953_row2_col5, #T_6d953_row2_col6, #T_6d953_row2_col7, #T_6d953_row3_col0, #T_6d953_row3_col1, #T_6d953_row3_col2, #T_6d953_row3_col3, #T_6d953_row3_col4, #T_6d953_row3_col5, #T_6d953_row3_col6, #T_6d953_row3_col7, #T_6d953_row4_col0, #T_6d953_row4_col1, #T_6d953_row4_col2, #T_6d953_row4_col3, #T_6d953_row4_col4, #T_6d953_row4_col5, #T_6d953_row4_col6, #T_6d953_row4_col7, #T_6d953_row5_col0, #T_6d953_row5_col1, #T_6d953_row5_col2, #T_6d953_row5_col3, #T_6d953_row5_col4, #T_6d953_row5_col5, #T_6d953_row5_col6, #T_6d953_row5_col7, #T_6d953_row6_col0, #T_6d953_row6_col1, #T_6d953_row6_col2, #T_6d953_row6_col3, #T_6d953_row6_col4, #T_6d953_row6_col5, #T_6d953_row6_col6, #T_6d953_row6_col7, #T_6d953_row7_col0, #T_6d953_row7_col1, #T_6d953_row7_col2, #T_6d953_row7_col3, #T_6d953_row7_col4, #T_6d953_row7_col5, #T_6d953_row7_col6, #T_6d953_row7_col7, #T_6d953_row8_col0, #T_6d953_row8_col1, #T_6d953_row8_col2, #T_6d953_row8_col3, #T_6d953_row8_col4, #T_6d953_row8_col5, #T_6d953_row8_col6, #T_6d953_row8_col7, #T_6d953_row9_col0, #T_6d953_row9_col1, #T_6d953_row9_col2, #T_6d953_row9_col3, #T_6d953_row9_col4, #T_6d953_row9_col5, #T_6d953_row9_col6, #T_6d953_row9_col7, #T_6d953_row10_col0, #T_6d953_row10_col1, #T_6d953_row10_col2, #T_6d953_row10_col3, #T_6d953_row10_col4, #T_6d953_row10_col5, #T_6d953_row10_col6, #T_6d953_row10_col7, #T_6d953_row11_col0, #T_6d953_row11_col1, #T_6d953_row11_col2, #T_6d953_row11_col3, #T_6d953_row11_col4, #T_6d953_row11_col5, #T_6d953_row11_col6, #T_6d953_row11_col7, #T_6d953_row12_col0, #T_6d953_row12_col1, #T_6d953_row12_col2, #T_6d953_row12_col3, #T_6d953_row12_col4, #T_6d953_row12_col5, #T_6d953_row12_col6, #T_6d953_row12_col7 {
#   text-align: left;
# }
# #T_6d953_row0_col1, #T_6d953_row0_col2, #T_6d953_row0_col3, #T_6d953_row0_col5, #T_6d953_row0_col6, #T_6d953_row0_col7, #T_6d953_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_6d953_row0_col8, #T_6d953_row1_col8, #T_6d953_row2_col8, #T_6d953_row3_col8, #T_6d953_row4_col8, #T_6d953_row5_col8, #T_6d953_row6_col8, #T_6d953_row7_col8, #T_6d953_row8_col8, #T_6d953_row9_col8, #T_6d953_row11_col8, #T_6d953_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_6d953_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_6d953_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6d953_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_6d953_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_6d953_row0_col1" class="data row0 col1" >0.9665</td>
#       <td id="T_6d953_row0_col2" class="data row0 col2" >0.9918</td>
#       <td id="T_6d953_row0_col3" class="data row0 col3" >0.9508</td>
#       <td id="T_6d953_row0_col4" class="data row0 col4" >0.9816</td>
#       <td id="T_6d953_row0_col5" class="data row0 col5" >0.9659</td>
#       <td id="T_6d953_row0_col6" class="data row0 col6" >0.9330</td>
#       <td id="T_6d953_row0_col7" class="data row0 col7" >0.9334</td>
#       <td id="T_6d953_row0_col8" class="data row0 col8" >91.8940</td>
#     </tr>
#     <tr>
#       <th id="T_6d953_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_6d953_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_6d953_row1_col1" class="data row1 col1" >0.9549</td>
#       <td id="T_6d953_row1_col2" class="data row1 col2" >0.9781</td>
#       <td id="T_6d953_row1_col3" class="data row1 col3" >0.9113</td>
#       <td id="T_6d953_row1_col4" class="data row1 col4" >0.9984</td>
#       <td id="T_6d953_row1_col5" class="data row1 col5" >0.9529</td>
#       <td id="T_6d953_row1_col6" class="data row1 col6" >0.9098</td>
#       <td id="T_6d953_row1_col7" class="data row1 col7" >0.9133</td>
#       <td id="T_6d953_row1_col8" class="data row1 col8" >8.3470</td>
#     </tr>
#     <tr>
#       <th id="T_6d953_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_6d953_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_6d953_row2_col1" class="data row2 col1" >0.9537</td>
#       <td id="T_6d953_row2_col2" class="data row2 col2" >0.9808</td>
#       <td id="T_6d953_row2_col3" class="data row2 col3" >0.9099</td>
#       <td id="T_6d953_row2_col4" class="data row2 col4" >0.9972</td>
#       <td id="T_6d953_row2_col5" class="data row2 col5" >0.9515</td>
#       <td id="T_6d953_row2_col6" class="data row2 col6" >0.9073</td>
#       <td id="T_6d953_row2_col7" class="data row2 col7" >0.9108</td>
#       <td id="T_6d953_row2_col8" class="data row2 col8" >85.3640</td>
#     </tr>
#     <tr>
#       <th id="T_6d953_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_6d953_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_6d953_row3_col1" class="data row3 col1" >0.9485</td>
#       <td id="T_6d953_row3_col2" class="data row3 col2" >0.9732</td>
#       <td id="T_6d953_row3_col3" class="data row3 col3" >0.9020</td>
#       <td id="T_6d953_row3_col4" class="data row3 col4" >0.9945</td>
#       <td id="T_6d953_row3_col5" class="data row3 col5" >0.9460</td>
#       <td id="T_6d953_row3_col6" class="data row3 col6" >0.8971</td>
#       <td id="T_6d953_row3_col7" class="data row3 col7" >0.9010</td>
#       <td id="T_6d953_row3_col8" class="data row3 col8" >152.3190</td>
#     </tr>
#     <tr>
#       <th id="T_6d953_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_6d953_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_6d953_row4_col1" class="data row4 col1" >0.9205</td>
#       <td id="T_6d953_row4_col2" class="data row4 col2" >0.9636</td>
#       <td id="T_6d953_row4_col3" class="data row4 col3" >0.8873</td>
#       <td id="T_6d953_row4_col4" class="data row4 col4" >0.9504</td>
#       <td id="T_6d953_row4_col5" class="data row4 col5" >0.9178</td>
#       <td id="T_6d953_row4_col6" class="data row4 col6" >0.8410</td>
#       <td id="T_6d953_row4_col7" class="data row4 col7" >0.8429</td>
#       <td id="T_6d953_row4_col8" class="data row4 col8" >30.0580</td>
#     </tr>
#     <tr>
#       <th id="T_6d953_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_6d953_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_6d953_row5_col1" class="data row5 col1" >0.9035</td>
#       <td id="T_6d953_row5_col2" class="data row5 col2" >0.9035</td>
#       <td id="T_6d953_row5_col3" class="data row5 col3" >0.9123</td>
#       <td id="T_6d953_row5_col4" class="data row5 col4" >0.8965</td>
#       <td id="T_6d953_row5_col5" class="data row5 col5" >0.9043</td>
#       <td id="T_6d953_row5_col6" class="data row5 col6" >0.8069</td>
#       <td id="T_6d953_row5_col7" class="data row5 col7" >0.8071</td>
#       <td id="T_6d953_row5_col8" class="data row5 col8" >6.8110</td>
#     </tr>
#     <tr>
#       <th id="T_6d953_level0_row6" class="row_heading level0 row6" >knn</th>
#       <td id="T_6d953_row6_col0" class="data row6 col0" >K Neighbors Classifier</td>
#       <td id="T_6d953_row6_col1" class="data row6 col1" >0.7845</td>
#       <td id="T_6d953_row6_col2" class="data row6 col2" >0.8802</td>
#       <td id="T_6d95

# %%
pred_holdout_mod41 = predict_model(best_model5[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_c1137_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c1137_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c1137_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_c1137_row0_col1" class="data row0 col1" >0.9692</td>
#       <td id="T_c1137_row0_col2" class="data row0 col2" >0.9929</td>
#       <td id="T_c1137_row0_col3" class="data row0 col3" >0.9542</td>
#       <td id="T_c1137_row0_col4" class="data row0 col4" >0.9837</td>
#       <td id="T_c1137_row0_col5" class="data row0 col5" >0.9687</td>
#       <td id="T_c1137_row0_col6" class="data row0 col6" >0.9384</td>
#       <td id="T_c1137_row0_col7" class="data row0 col7" >0.9388</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod42 = predict_model(best_model5[1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_89f6f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_89f6f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_89f6f_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_89f6f_row0_col1" class="data row0 col1" >0.9549</td>
#       <td id="T_89f6f_row0_col2" class="data row0 col2" >0.9785</td>
#       <td id="T_89f6f_row0_col3" class="data row0 col3" >0.9117</td>
#       <td id="T_89f6f_row0_col4" class="data row0 col4" >0.9979</td>
#       <td id="T_89f6f_row0_col5" class="data row0 col5" >0.9529</td>
#       <td id="T_89f6f_row0_col6" class="data row0 col6" >0.9098</td>
#       <td id="T_89f6f_row0_col7" class="data row0 col7" >0.9132</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod43 = predict_model(best_model5[2])
# Out:
# <style type="text/css">
# </style>
# <table id="T_0e973_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0e973_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_0e973_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_0e973_row0_col1" class="data row0 col1" >0.9541</td>
#       <td id="T_0e973_row0_col2" class="data row0 col2" >0.9816</td>
#       <td id="T_0e973_row0_col3" class="data row0 col3" >0.9106</td>
#       <td id="T_0e973_row0_col4" class="data row0 col4" >0.9973</td>
#       <td id="T_0e973_row0_col5" class="data row0 col5" >0.9520</td>
#       <td id="T_0e973_row0_col6" class="data row0 col6" >0.9082</td>
#       <td id="T_0e973_row0_col7" class="data row0 col7" >0.9116</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model5[0])

# %%
plot_model(best_model5[1])

# %%
plot_model(best_model5[2])

# %%
evaluate_model(best_model5[0])
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(best_model5[1])
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
evaluate_model(best_model5[2])
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
best_model5[0]
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100, n_jobs=-1,
#                      oob_score=False, random_state=123, verbose=0,
#                      warm_start=False)

# %%
best_model5[1]
# Out:
# LGBMClassifier(boosting_type='gbdt', class_weight=None, colsample_bytree=1.0,
#                importance_type='split', learning_rate=0.1, max_depth=-1,
#                min_child_samples=20, min_child_weight=0.001, min_split_gain=0.0,
#                n_estimators=100, n_jobs=-1, num_leaves=31, objective=None,
#                random_state=123, reg_alpha=0.0, reg_lambda=0.0, silent='warn',
#                subsample=1.0, subsample_for_bin=200000, subsample_freq=0)

# %%
best_model5[2]
# Out:
# RandomForestClassifier(bootstrap=True, ccp_alpha=0.0, class_weight=None,
#                        criterion='gini', max_depth=None, max_features='auto',
#                        max_leaf_nodes=None, max_samples=None,
#                        min_impurity_decrease=0.0, min_impurity_split=None,
#                        min_samples_leaf=1, min_samples_split=2,
#                        min_weight_fraction_leaf=0.0, n_estimators=100,
#                        n_jobs=-1, oob_score=False, random_state=123, verbose=0,
#                        warm_start=False)

# %% [markdown]
# # AFTER APPLYING TUNING

# %%
tuned_model_ETC = tune_model(best_model5[0])
# Out:
# <style type="text/css">
# #T_3e1de_row10_col0, #T_3e1de_row10_col1, #T_3e1de_row10_col2, #T_3e1de_row10_col3, #T_3e1de_row10_col4, #T_3e1de_row10_col5, #T_3e1de_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_3e1de_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3e1de_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3e1de_row0_col0" class="data row0 col0" >0.7933</td>
#       <td id="T_3e1de_row0_col1" class="data row0 col1" >0.8881</td>
#       <td id="T_3e1de_row0_col2" class="data row0 col2" >0.8335</td>
#       <td id="T_3e1de_row0_col3" class="data row0 col3" >0.7715</td>
#       <td id="T_3e1de_row0_col4" class="data row0 col4" >0.8013</td>
#       <td id="T_3e1de_row0_col5" class="data row0 col5" >0.5866</td>
#       <td id="T_3e1de_row0_col6" class="data row0 col6" >0.5886</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3e1de_row1_col0" class="data row1 col0" >0.7939</td>
#       <td id="T_3e1de_row1_col1" class="data row1 col1" >0.8903</td>
#       <td id="T_3e1de_row1_col2" class="data row1 col2" >0.8344</td>
#       <td id="T_3e1de_row1_col3" class="data row1 col3" >0.7718</td>
#       <td id="T_3e1de_row1_col4" class="data row1 col4" >0.8019</td>
#       <td id="T_3e1de_row1_col5" class="data row1 col5" >0.5877</td>
#       <td id="T_3e1de_row1_col6" class="data row1 col6" >0.5897</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3e1de_row2_col0" class="data row2 col0" >0.7914</td>
#       <td id="T_3e1de_row2_col1" class="data row2 col1" >0.8890</td>
#       <td id="T_3e1de_row2_col2" class="data row2 col2" >0.8324</td>
#       <td id="T_3e1de_row2_col3" class="data row2 col3" >0.7692</td>
#       <td id="T_3e1de_row2_col4" class="data row2 col4" >0.7996</td>
#       <td id="T_3e1de_row2_col5" class="data row2 col5" >0.5827</td>
#       <td id="T_3e1de_row2_col6" class="data row2 col6" >0.5847</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3e1de_row3_col0" class="data row3 col0" >0.7897</td>
#       <td id="T_3e1de_row3_col1" class="data row3 col1" >0.8862</td>
#       <td id="T_3e1de_row3_col2" class="data row3 col2" >0.8251</td>
#       <td id="T_3e1de_row3_col3" class="data row3 col3" >0.7705</td>
#       <td id="T_3e1de_row3_col4" class="data row3 col4" >0.7969</td>
#       <td id="T_3e1de_row3_col5" class="data row3 col5" >0.5793</td>
#       <td id="T_3e1de_row3_col6" class="data row3 col6" >0.5808</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3e1de_row4_col0" class="data row4 col0" >0.7863</td>
#       <td id="T_3e1de_row4_col1" class="data row4 col1" >0.8851</td>
#       <td id="T_3e1de_row4_col2" class="data row4 col2" >0.8262</td>
#       <td id="T_3e1de_row4_col3" class="data row4 col3" >0.7652</td>
#       <td id="T_3e1de_row4_col4" class="data row4 col4" >0.7945</td>
#       <td id="T_3e1de_row4_col5" class="data row4 col5" >0.5727</td>
#       <td id="T_3e1de_row4_col6" class="data row4 col6" >0.5745</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3e1de_row5_col0" class="data row5 col0" >0.7898</td>
#       <td id="T_3e1de_row5_col1" class="data row5 col1" >0.8861</td>
#       <td id="T_3e1de_row5_col2" class="data row5 col2" >0.8287</td>
#       <td id="T_3e1de_row5_col3" class="data row5 col3" >0.7689</td>
#       <td id="T_3e1de_row5_col4" class="data row5 col4" >0.7977</td>
#       <td id="T_3e1de_row5_col5" class="data row5 col5" >0.5796</td>
#       <td id="T_3e1de_row5_col6" class="data row5 col6" >0.5814</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3e1de_row6_col0" class="data row6 col0" >0.7911</td>
#       <td id="T_3e1de_row6_col1" class="data row6 col1" >0.8875</td>
#       <td id="T_3e1de_row6_col2" class="data row6 col2" >0.8323</td>
#       <td id="T_3e1de_row6_col3" class="data row6 col3" >0.7689</td>
#       <td id="T_3e1de_row6_col4" class="data row6 col4" >0.7994</td>
#       <td id="T_3e1de_row6_col5" class="data row6 col5" >0.5822</td>
#       <td id="T_3e1de_row6_col6" class="data row6 col6" >0.5842</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3e1de_row7_col0" class="data row7 col0" >0.7922</td>
#       <td id="T_3e1de_row7_col1" class="data row7 col1" >0.8885</td>
#       <td id="T_3e1de_row7_col2" class="data row7 col2" >0.8339</td>
#       <td id="T_3e1de_row7_col3" class="data row7 col3" >0.7697</td>
#       <td id="T_3e1de_row7_col4" class="data row7 col4" >0.8005</td>
#       <td id="T_3e1de_row7_col5" class="data row7 col5" >0.5845</td>
#       <td id="T_3e1de_row7_col6" class="data row7 col6" >0.5865</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3e1de_row8_col0" class="data row8 col0" >0.7938</td>
#       <td id="T_3e1de_row8_col1" class="data row8 col1" >0.8898</td>
#       <td id="T_3e1de_row8_col2" class="data row8 col2" >0.8382</td>
#       <td id="T_3e1de_row8_col3" class="data row8 col3" >0.7698</td>
#       <td id="T_3e1de_row8_col4" class="data row8 col4" >0.8025</td>
#       <td id="T_3e1de_row8_col5" class="data row8 col5" >0.5875</td>
#       <td id="T_3e1de_row8_col6" class="data row8 col6" >0.5899</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3e1de_row9_col0" class="data row9 col0" >0.7925</td>
#       <td id="T_3e1de_row9_col1" class="data row9 col1" >0.8873</td>
#       <td id="T_3e1de_row9_col2" class="data row9 col2" >0.8338</td>
#       <td id="T_3e1de_row9_col3" class="data row9 col3" >0.7702</td>
#       <td id="T_3e1de_row9_col4" class="data row9 col4" >0.8007</td>
#       <td id="T_3e1de_row9_col5" class="data row9 col5" >0.5850</td>
#       <td id="T_3e1de_row9_col6" class="data row9 col6" >0.5870</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_3e1de_row10_col0" class="data row10 col0" >0.7914</td>
#       <td id="T_3e1de_row10_col1" class="data row10 col1" >0.8878</td>
#       <td id="T_3e1de_row10_col2" class="data row10 col2" >0.8319</td>
#       <td id="T_3e1de_row10_col3" class="data row10 col3" >0.7696</td>
#       <td id="T_3e1de_row10_col4" class="data row10 col4" >0.7995</td>
#       <td id="T_3e1de_row10_col5" class="data row10 col5" >0.5828</td>
#       <td id="T_3e1de_row10_col6" class="data row10 col6" >0.5847</td>
#     </tr>
#     <tr>
#       <th id="T_3e1de_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_3e1de_row11_col0" class="data row11 col0" >0.0022</td>
#       <td id="T_3e1de_row11_col1" class="data row11 col1" >0.0016</td>
#       <td id="T_3e1de_row11_col2" class="data row11 col2" >0.0038</td>
#       <td id="T_3e1de_row11_col3" class="data row11 col3" >0.0017</td>
#       <td id="T_3e1de_row11_col4" class="data row11 col4" >0.0024</td>
#       <td id="T_3e1de_row11_col5" class="data row11 col5" >0.0044</td>
#       <td id="T_3e1de_row11_col6" class="data row11 col6" >0.0045</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate_model(tuned_model_ETC)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
tuned_model_LGBM = tune_model(best_model5[1])
# Out:
# <style type="text/css">
# #T_6fe64_row10_col0, #T_6fe64_row10_col1, #T_6fe64_row10_col2, #T_6fe64_row10_col3, #T_6fe64_row10_col4, #T_6fe64_row10_col5, #T_6fe64_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_6fe64_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_6fe64_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_6fe64_row0_col0" class="data row0 col0" >0.9554</td>
#       <td id="T_6fe64_row0_col1" class="data row0 col1" >0.9783</td>
#       <td id="T_6fe64_row0_col2" class="data row0 col2" >0.9134</td>
#       <td id="T_6fe64_row0_col3" class="data row0 col3" >0.9971</td>
#       <td id="T_6fe64_row0_col4" class="data row0 col4" >0.9534</td>
#       <td id="T_6fe64_row0_col5" class="data row0 col5" >0.9107</td>
#       <td id="T_6fe64_row0_col6" class="data row0 col6" >0.9140</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_6fe64_row1_col0" class="data row1 col0" >0.9576</td>
#       <td id="T_6fe64_row1_col1" class="data row1 col1" >0.9794</td>
#       <td id="T_6fe64_row1_col2" class="data row1 col2" >0.9174</td>
#       <td id="T_6fe64_row1_col3" class="data row1 col3" >0.9976</td>
#       <td id="T_6fe64_row1_col4" class="data row1 col4" >0.9558</td>
#       <td id="T_6fe64_row1_col5" class="data row1 col5" >0.9152</td>
#       <td id="T_6fe64_row1_col6" class="data row1 col6" >0.9182</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_6fe64_row2_col0" class="data row2 col0" >0.9550</td>
#       <td id="T_6fe64_row2_col1" class="data row2 col1" >0.9784</td>
#       <td id="T_6fe64_row2_col2" class="data row2 col2" >0.9125</td>
#       <td id="T_6fe64_row2_col3" class="data row2 col3" >0.9972</td>
#       <td id="T_6fe64_row2_col4" class="data row2 col4" >0.9530</td>
#       <td id="T_6fe64_row2_col5" class="data row2 col5" >0.9100</td>
#       <td id="T_6fe64_row2_col6" class="data row2 col6" >0.9133</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_6fe64_row3_col0" class="data row3 col0" >0.9544</td>
#       <td id="T_6fe64_row3_col1" class="data row3 col1" >0.9778</td>
#       <td id="T_6fe64_row3_col2" class="data row3 col2" >0.9121</td>
#       <td id="T_6fe64_row3_col3" class="data row3 col3" >0.9964</td>
#       <td id="T_6fe64_row3_col4" class="data row3 col4" >0.9524</td>
#       <td id="T_6fe64_row3_col5" class="data row3 col5" >0.9088</td>
#       <td id="T_6fe64_row3_col6" class="data row3 col6" >0.9121</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_6fe64_row4_col0" class="data row4 col0" >0.9560</td>
#       <td id="T_6fe64_row4_col1" class="data row4 col1" >0.9780</td>
#       <td id="T_6fe64_row4_col2" class="data row4 col2" >0.9153</td>
#       <td id="T_6fe64_row4_col3" class="data row4 col3" >0.9964</td>
#       <td id="T_6fe64_row4_col4" class="data row4 col4" >0.9541</td>
#       <td id="T_6fe64_row4_col5" class="data row4 col5" >0.9120</td>
#       <td id="T_6fe64_row4_col6" class="data row4 col6" >0.9150</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_6fe64_row5_col0" class="data row5 col0" >0.9552</td>
#       <td id="T_6fe64_row5_col1" class="data row5 col1" >0.9780</td>
#       <td id="T_6fe64_row5_col2" class="data row5 col2" >0.9129</td>
#       <td id="T_6fe64_row5_col3" class="data row5 col3" >0.9972</td>
#       <td id="T_6fe64_row5_col4" class="data row5 col4" >0.9532</td>
#       <td id="T_6fe64_row5_col5" class="data row5 col5" >0.9103</td>
#       <td id="T_6fe64_row5_col6" class="data row5 col6" >0.9136</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_6fe64_row6_col0" class="data row6 col0" >0.9549</td>
#       <td id="T_6fe64_row6_col1" class="data row6 col1" >0.9788</td>
#       <td id="T_6fe64_row6_col2" class="data row6 col2" >0.9129</td>
#       <td id="T_6fe64_row6_col3" class="data row6 col3" >0.9966</td>
#       <td id="T_6fe64_row6_col4" class="data row6 col4" >0.9529</td>
#       <td id="T_6fe64_row6_col5" class="data row6 col5" >0.9098</td>
#       <td id="T_6fe64_row6_col6" class="data row6 col6" >0.9130</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_6fe64_row7_col0" class="data row7 col0" >0.9553</td>
#       <td id="T_6fe64_row7_col1" class="data row7 col1" >0.9782</td>
#       <td id="T_6fe64_row7_col2" class="data row7 col2" >0.9132</td>
#       <td id="T_6fe64_row7_col3" class="data row7 col3" >0.9971</td>
#       <td id="T_6fe64_row7_col4" class="data row7 col4" >0.9533</td>
#       <td id="T_6fe64_row7_col5" class="data row7 col5" >0.9106</td>
#       <td id="T_6fe64_row7_col6" class="data row7 col6" >0.9138</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_6fe64_row8_col0" class="data row8 col0" >0.9555</td>
#       <td id="T_6fe64_row8_col1" class="data row8 col1" >0.9784</td>
#       <td id="T_6fe64_row8_col2" class="data row8 col2" >0.9138</td>
#       <td id="T_6fe64_row8_col3" class="data row8 col3" >0.9970</td>
#       <td id="T_6fe64_row8_col4" class="data row8 col4" >0.9536</td>
#       <td id="T_6fe64_row8_col5" class="data row8 col5" >0.9110</td>
#       <td id="T_6fe64_row8_col6" class="data row8 col6" >0.9142</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_6fe64_row9_col0" class="data row9 col0" >0.9560</td>
#       <td id="T_6fe64_row9_col1" class="data row9 col1" >0.9777</td>
#       <td id="T_6fe64_row9_col2" class="data row9 col2" >0.9140</td>
#       <td id="T_6fe64_row9_col3" class="data row9 col3" >0.9977</td>
#       <td id="T_6fe64_row9_col4" class="data row9 col4" >0.9540</td>
#       <td id="T_6fe64_row9_col5" class="data row9 col5" >0.9119</td>
#       <td id="T_6fe64_row9_col6" class="data row9 col6" >0.9151</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_6fe64_row10_col0" class="data row10 col0" >0.9555</td>
#       <td id="T_6fe64_row10_col1" class="data row10 col1" >0.9783</td>
#       <td id="T_6fe64_row10_col2" class="data row10 col2" >0.9138</td>
#       <td id="T_6fe64_row10_col3" class="data row10 col3" >0.9970</td>
#       <td id="T_6fe64_row10_col4" class="data row10 col4" >0.9536</td>
#       <td id="T_6fe64_row10_col5" class="data row10 col5" >0.9110</td>
#       <td id="T_6fe64_row10_col6" class="data row10 col6" >0.9142</td>
#     </tr>
#     <tr>
#       <th id="T_6fe64_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_6fe64_row11_col0" class="data row11 col0" >0.0008</td>
#       <td id="T_6fe64_row11_col1" class="data row11 col1" >0.0005</td>
#       <td id="T_6fe64_row11_col2" class="data row11 col2" >0.0015</td>
#       <td id="T_6fe64_row11_col3" class="data row11 col3" >0.0004</td>
#       <td id="T_6fe64_row11_col4" class="data row11 col4" >0.0009</td>
#       <td id="T_6fe64_row11_col5" class="data row11 col5" >0.0017</td>
#       <td id="T_6fe64_row11_col6" class="data row11 col6" >0.0016</td>
#     </tr>
#   </tbody>
# </table>

# %%
evaluate_model(tuned_model_LGBM)
# Out:
# interactive(children=(ToggleButtons(description='Plot Type:', icons=('',), options=(('Hyperparameters', 'param…

# %%
tuned_model_RFC = tune_model(best_model5[2])
# Out:
# IntProgress(value=0, description='Processing: ', max=7)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   21:45:18
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .   Random Forest Classifier
# Empty DataFrame
# Columns: [Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []
# Fitting 10 folds for each of 10 candidates, totalling 100 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  42 tasks      | elapsed: 20.0min

# %%
evaluate_model(tuned_model_RFC)

# %% [markdown]
# ### CREATING ETC, LGBM AND RFC MODELS

# %%
etc_model = create_model('et')

# %%
lgbm = create_model('lgbm')

# %%
rf_model = create_model('rf' )
# Out:
# IntProgress(value=0, description='Processing: ', max=4)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                  00:57:28
# Status     . . . . . . . . . . . . . . . . . .          Fitting 10 Folds
# Estimator  . . . . . . . . . . . . . . . . . .  Random Forest Classifier
# Empty DataFrame
# Columns: [Accuracy, AUC, Recall, Prec., F1, Kappa, MCC]
# Index: []

# %%
tuned_model_et = tune_model(tuned_model_et)

# %%
tuned_model_lgm =

# %%
tuned_model_rf =

# %% [markdown]
# ### CREATING BAGGING ENSEMBLE

# %%
tuned_model_top3 =[tuned_model_et,tuned_model_rf,tuned_model_lgm]

# %% [markdown]
# # MODEL CREATION USING PYCARET &  FEATURES FROM  RFE SELECTION

# %%
rfe_feat.append('TARGET')
data = train_imbalanced[rfe_feat]

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_cc826_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_cc826_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_cc826_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_cc826_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_cc826_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_cc826_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_cc826_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_cc826_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_cc826_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_cc826_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_cc826_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_cc826_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_cc826_row4_col1" class="data row4 col1" >(562710, 31)</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_cc826_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_cc826_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_cc826_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_cc826_row6_col1" class="data row6 col1" >30</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_cc826_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_cc826_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_cc826_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_cc826_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_cc826_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_cc826_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_cc826_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_cc826_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_cc826_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_cc826_row11_col1" class="data row11 col1" >(393896, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_cc826_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_cc826_row12_col1" class="data row12 col1" >(168814, 30)</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_cc826_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_cc826_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_cc826_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_cc826_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_cc826_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_cc826_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_cc826_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_cc826_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_cc826_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_cc826_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_cc826_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_cc826_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_cc826_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_cc826_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_cc826_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_cc826_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_cc826_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_cc826_row21_col1" class="data row21 col1" >3d7b</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_cc826_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_cc826_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_cc826_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_cc826_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_cc826_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_cc826_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_cc826_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_cc826_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_cc826_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_cc826_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_cc826_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_cc826_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_cc826_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_cc826_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_cc826_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_cc826_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_cc826_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_cc826_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_cc826_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
best_model6 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_c8c34_ th {
#   text-align: left;
# }
# #T_c8c34_row0_col0, #T_c8c34_row0_col4, #T_c8c34_row1_col0, #T_c8c34_row1_col1, #T_c8c34_row1_col2, #T_c8c34_row1_col3, #T_c8c34_row1_col5, #T_c8c34_row1_col6, #T_c8c34_row1_col7, #T_c8c34_row2_col0, #T_c8c34_row2_col1, #T_c8c34_row2_col2, #T_c8c34_row2_col3, #T_c8c34_row2_col4, #T_c8c34_row2_col5, #T_c8c34_row2_col6, #T_c8c34_row2_col7, #T_c8c34_row3_col0, #T_c8c34_row3_col1, #T_c8c34_row3_col2, #T_c8c34_row3_col3, #T_c8c34_row3_col4, #T_c8c34_row3_col5, #T_c8c34_row3_col6, #T_c8c34_row3_col7, #T_c8c34_row4_col0, #T_c8c34_row4_col1, #T_c8c34_row4_col2, #T_c8c34_row4_col3, #T_c8c34_row4_col4, #T_c8c34_row4_col5, #T_c8c34_row4_col6, #T_c8c34_row4_col7, #T_c8c34_row5_col0, #T_c8c34_row5_col1, #T_c8c34_row5_col2, #T_c8c34_row5_col3, #T_c8c34_row5_col4, #T_c8c34_row5_col5, #T_c8c34_row5_col6, #T_c8c34_row5_col7, #T_c8c34_row6_col0, #T_c8c34_row6_col1, #T_c8c34_row6_col2, #T_c8c34_row6_col3, #T_c8c34_row6_col4, #T_c8c34_row6_col5, #T_c8c34_row6_col6, #T_c8c34_row6_col7, #T_c8c34_row7_col0, #T_c8c34_row7_col1, #T_c8c34_row7_col2, #T_c8c34_row7_col3, #T_c8c34_row7_col4, #T_c8c34_row7_col5, #T_c8c34_row7_col6, #T_c8c34_row7_col7, #T_c8c34_row8_col0, #T_c8c34_row8_col1, #T_c8c34_row8_col2, #T_c8c34_row8_col3, #T_c8c34_row8_col4, #T_c8c34_row8_col5, #T_c8c34_row8_col6, #T_c8c34_row8_col7, #T_c8c34_row9_col0, #T_c8c34_row9_col1, #T_c8c34_row9_col2, #T_c8c34_row9_col3, #T_c8c34_row9_col4, #T_c8c34_row9_col5, #T_c8c34_row9_col6, #T_c8c34_row9_col7, #T_c8c34_row10_col0, #T_c8c34_row10_col1, #T_c8c34_row10_col2, #T_c8c34_row10_col3, #T_c8c34_row10_col4, #T_c8c34_row10_col5, #T_c8c34_row10_col6, #T_c8c34_row10_col7, #T_c8c34_row11_col0, #T_c8c34_row11_col1, #T_c8c34_row11_col2, #T_c8c34_row11_col3, #T_c8c34_row11_col4, #T_c8c34_row11_col5, #T_c8c34_row11_col6, #T_c8c34_row11_col7, #T_c8c34_row12_col0, #T_c8c34_row12_col1, #T_c8c34_row12_col2, #T_c8c34_row12_col3, #T_c8c34_row12_col4, #T_c8c34_row12_col5, #T_c8c34_row12_col6, #T_c8c34_row12_col7 {
#   text-align: left;
# }
# #T_c8c34_row0_col1, #T_c8c34_row0_col2, #T_c8c34_row0_col3, #T_c8c34_row0_col5, #T_c8c34_row0_col6, #T_c8c34_row0_col7, #T_c8c34_row1_col4 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_c8c34_row0_col8, #T_c8c34_row1_col8, #T_c8c34_row2_col8, #T_c8c34_row3_col8, #T_c8c34_row4_col8, #T_c8c34_row5_col8, #T_c8c34_row6_col8, #T_c8c34_row7_col8, #T_c8c34_row8_col8, #T_c8c34_row10_col8, #T_c8c34_row11_col8, #T_c8c34_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_c8c34_row9_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_c8c34_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8c34_level0_row0" class="row_heading level0 row0" >et</th>
#       <td id="T_c8c34_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_c8c34_row0_col1" class="data row0 col1" >0.9607</td>
#       <td id="T_c8c34_row0_col2" class="data row0 col2" >0.9895</td>
#       <td id="T_c8c34_row0_col3" class="data row0 col3" >0.9487</td>
#       <td id="T_c8c34_row0_col4" class="data row0 col4" >0.9721</td>
#       <td id="T_c8c34_row0_col5" class="data row0 col5" >0.9602</td>
#       <td id="T_c8c34_row0_col6" class="data row0 col6" >0.9214</td>
#       <td id="T_c8c34_row0_col7" class="data row0 col7" >0.9217</td>
#       <td id="T_c8c34_row0_col8" class="data row0 col8" >68.8250</td>
#     </tr>
#     <tr>
#       <th id="T_c8c34_level0_row1" class="row_heading level0 row1" >lightgbm</th>
#       <td id="T_c8c34_row1_col0" class="data row1 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_c8c34_row1_col1" class="data row1 col1" >0.9543</td>
#       <td id="T_c8c34_row1_col2" class="data row1 col2" >0.9782</td>
#       <td id="T_c8c34_row1_col3" class="data row1 col3" >0.9122</td>
#       <td id="T_c8c34_row1_col4" class="data row1 col4" >0.9961</td>
#       <td id="T_c8c34_row1_col5" class="data row1 col5" >0.9523</td>
#       <td id="T_c8c34_row1_col6" class="data row1 col6" >0.9086</td>
#       <td id="T_c8c34_row1_col7" class="data row1 col7" >0.9119</td>
#       <td id="T_c8c34_row1_col8" class="data row1 col8" >6.5460</td>
#     </tr>
#     <tr>
#       <th id="T_c8c34_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_c8c34_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_c8c34_row2_col1" class="data row2 col1" >0.9510</td>
#       <td id="T_c8c34_row2_col2" class="data row2 col2" >0.9804</td>
#       <td id="T_c8c34_row2_col3" class="data row2 col3" >0.9120</td>
#       <td id="T_c8c34_row2_col4" class="data row2 col4" >0.9892</td>
#       <td id="T_c8c34_row2_col5" class="data row2 col5" >0.9490</td>
#       <td id="T_c8c34_row2_col6" class="data row2 col6" >0.9020</td>
#       <td id="T_c8c34_row2_col7" class="data row2 col7" >0.9048</td>
#       <td id="T_c8c34_row2_col8" class="data row2 col8" >96.1890</td>
#     </tr>
#     <tr>
#       <th id="T_c8c34_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_c8c34_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_c8c34_row3_col1" class="data row3 col1" >0.9455</td>
#       <td id="T_c8c34_row3_col2" class="data row3 col2" >0.9741</td>
#       <td id="T_c8c34_row3_col3" class="data row3 col3" >0.9046</td>
#       <td id="T_c8c34_row3_col4" class="data row3 col4" >0.9853</td>
#       <td id="T_c8c34_row3_col5" class="data row3 col5" >0.9432</td>
#       <td id="T_c8c34_row3_col6" class="data row3 col6" >0.8910</td>
#       <td id="T_c8c34_row3_col7" class="data row3 col7" >0.8940</td>
#       <td id="T_c8c34_row3_col8" class="data row3 col8" >164.2980</td>
#     </tr>
#     <tr>
#       <th id="T_c8c34_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_c8c34_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_c8c34_row4_col1" class="data row4 col1" >0.9143</td>
#       <td id="T_c8c34_row4_col2" class="data row4 col2" >0.9647</td>
#       <td id="T_c8c34_row4_col3" class="data row4 col3" >0.9018</td>
#       <td id="T_c8c34_row4_col4" class="data row4 col4" >0.9250</td>
#       <td id="T_c8c34_row4_col5" class="data row4 col5" >0.9133</td>
#       <td id="T_c8c34_row4_col6" class="data row4 col6" >0.8287</td>
#       <td id="T_c8c34_row4_col7" class="data row4 col7" >0.8290</td>
#       <td id="T_c8c34_row4_col8" class="data row4 col8" >32.9680</td>
#     </tr>
#     <tr>
#       <th id="T_c8c34_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_c8c34_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_c8c34_row5_col1" class="data row5 col1" >0.8946</td>
#       <td id="T_c8c34_row5_col2" class="data row5 col2" >0.8946</td>
#       <td id="T_c8c34_row5_col3" class="data row5 col3" >0.9027</td>
#       <td id="T_c8c34_row5_col4" class="data row5 col4" >0.8883</td>
#       <td id="T_c8c34_row5_col5" class="data row5 col5" >0.8954</td>
#       <td id="T_c8c34_row5_col6" class="data row5 col6" >0.7892</td>
#       <td id="T_c8c34_row5_col7" class="data row5 col7" >0.7893</td>
#       <td id="T_c8c34_row5_col8" class="data row5 col8" >8.0860</td>
#     </tr>
#     <tr>
#       <th id="T_c8c34_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_c8c34_row6_col0" class="data row6 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_c8c34_row6_col1" class="data row6 col1" >0.7180</td>
#       <td id="T_c8c34_row6_col2" class="data row6 col2" >0.8033</td>
#       <td i

# %%
pred_holdout_mod41 = predict_model(best_model6[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_bae37_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bae37_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bae37_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_bae37_row0_col1" class="data row0 col1" >0.9640</td>
#       <td id="T_bae37_row0_col2" class="data row0 col2" >0.9905</td>
#       <td id="T_bae37_row0_col3" class="data row0 col3" >0.9526</td>
#       <td id="T_bae37_row0_col4" class="data row0 col4" >0.9748</td>
#       <td id="T_bae37_row0_col5" class="data row0 col5" >0.9636</td>
#       <td id="T_bae37_row0_col6" class="data row0 col6" >0.9279</td>
#       <td id="T_bae37_row0_col7" class="data row0 col7" >0.9282</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod42 = predict_model(best_model6[1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_5e5db_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5e5db_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5e5db_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_5e5db_row0_col1" class="data row0 col1" >0.9542</td>
#       <td id="T_5e5db_row0_col2" class="data row0 col2" >0.9783</td>
#       <td id="T_5e5db_row0_col3" class="data row0 col3" >0.9124</td>
#       <td id="T_5e5db_row0_col4" class="data row0 col4" >0.9956</td>
#       <td id="T_5e5db_row0_col5" class="data row0 col5" >0.9522</td>
#       <td id="T_5e5db_row0_col6" class="data row0 col6" >0.9084</td>
#       <td id="T_5e5db_row0_col7" class="data row0 col7" >0.9116</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod43 = predict_model(best_model6[2])
# Out:
# <style type="text/css">
# </style>
# <table id="T_9397c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9397c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_9397c_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_9397c_row0_col1" class="data row0 col1" >0.9520</td>
#       <td id="T_9397c_row0_col2" class="data row0 col2" >0.9808</td>
#       <td id="T_9397c_row0_col3" class="data row0 col3" >0.9131</td>
#       <td id="T_9397c_row0_col4" class="data row0 col4" >0.9900</td>
#       <td id="T_9397c_row0_col5" class="data row0 col5" >0.9500</td>
#       <td id="T_9397c_row0_col6" class="data row0 col6" >0.9039</td>
#       <td id="T_9397c_row0_col7" class="data row0 col7" >0.9067</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model6[0])

# %%
plot_model(best_model6[1])

# %%
plot_model(best_model6[2])

# %%
evaluate_model(best_model6[0])
# Out:
#                          Parameters
# bootstrap                     False
# ccp_alpha                       0.0
# class_weight                   None
# criterion                      gini
# max_depth                      None
# max_features                   auto
# max_leaf_nodes                 None
# max_samples                    None
# min_impurity_decrease           0.0
# min_impurity_split             None
# min_samples_leaf                  1
# min_samples_split                 2
# min_weight_fraction_leaf        0.0
# n_estimators                    100
# n_jobs                           -1
# oob_score                     False
# random_state                    123
# verbose                           0
# warm_start                    False

# %% [markdown]
# # MODEL CREATION USING PYCARET &  FEATURES FROM  STEP BACKWARD SELECTION

# %%
train_imbalanced.dtypes
# Out:
# Unnamed: 0                                        int64
# Unnamed: 0.1                                      int64
# Unnamed: 0.1.1                                    int64
# SK_ID_CURR                                        int64
# AMT_INCOME_TOTAL                                float64
# AMT_CREDIT                                      float64
# AMT_ANNUITY                                     float64
# AMT_GOODS_PRICE                                 float64
# REGION_POPULATION_RELATIVE                      float64
# DAYS_BIRTH                                      float64
# DAYS_EMPLOYED                                   float64
# DAYS_REGISTRATION                               float64
# DAYS_ID_PUBLISH                                 float64
# CNT_FAM_MEMBERS                                 float64
# HOUR_APPR_PROCESS_START                           int64
# EXT_SOURCE_1                                    float64
# EXT_SOURCE_2                                    float64
# EXT_SOURCE_3                                    float64
# OBS_30_CNT_SOCIAL_CIRCLE                        float64
# DEF_30_CNT_SOCIAL_CIRCLE                        float64
# DAYS_LAST_PHONE_CHANGE                          float64
# NEW_ANNUITY_TO_INCOME_RATIO                     float64
# NEW_CREDIT_TO_ANNUITY_RATIO                     float64
# NEW_CREDIT_TO_INCOME_RATIO                      float64
# NEW_CREDIT_TO_GOODS_RATIO                       float64
# NEW_INC_PER_CHLD                                float64
# NEW_INC_BY_ORG                                  float64
# NEW_EMPLOY_TO_BIRTH_RATIO                       float64
# NEW_SOURCES_PROD                                float64
# NEW_EXT_SOURCES_MEAN                            float64
# NEW_SCORES_STD                                  float64
# NAME_TYPE_SUITE_ordered                         float64
# NAME_INCOME_TYPE_ordered                        float64
# NAME_EDUCATION_TYPE_ordered                     float64
# NAME_FAMILY_STATUS_ordered                      float64
# OCCUPATION_TYPE_ordered                         float64
# WEEKDAY_APPR_PROCESS_START_ordered              float64
# ORGANIZATION_TYPE_ordered                       float64
# BURO_DAYS_CREDIT_MAX                            float64
# BURO_DAYS_CREDIT_ENDDATE_MAX                    float64
# BURO_DAYS_CREDIT_ENDDATE_MEAN                   float64
# BURO_AMT_CREDIT_SUM_MEAN                        float64
# BURO_AMT_CREDIT_SUM_SUM                         float64
# BURO_DAYS_CREDIT_UPDATE_MAX                     float64
# BURO_CREDIT_TYPE_ordered_MEAN                   float64
# PREV_APP_CREDIT_PERC_MAX                        float64
# PREV_APP_CREDIT_PERC_MEAN                       float64
# PREV_APP_CREDIT_PERC_VAR                        float64
# PREV_HOUR_APPR_PROCESS_START_MIN                float64
# PREV_HOUR_APPR_PROCESS_START_MAX                float64
# PREV_RATE_DOWN_PAYMENT_MIN                      float64
# PREV_RATE_DOWN_PAYMENT_MAX                      float64
# PREV_RATE_DOWN_PAYMENT_MEAN                     float64
# PREV_DAYS_DECISION_MAX                          float64
# PREV_CNT_PAYMENT_MEAN                           float64
# PREV_WEEKDAY_APPR_PROCESS_START_ordered_MEAN    float64
# PREV_NAME_CONTRACT_STATUS_ordered_MEAN          float64
# PREV_CODE_REJECT_REASON_ordered_MEAN            float64
# PREV_NAME_SELLER_INDUSTRY_ordered_MEAN          float64
# PREV_NAME_YIELD_GROUP_ordered_MEAN              float64
# PREV_PRODUCT_COMBINATION_ordered_MEAN           float64
# POS_MONTHS_BALANCE_MAX                          float64
# POS_NAME_CONTRACT_STATUS_ordered_MEAN           float64
# INS_NUM_INSTALMENT_VERSION_NUNIQUE              float64
# INS_DPD_MAX                                     float64
# INS_DPD_MEAN                                    float64
# INS_DBD_MAX                                     float64
# INS_DBD_MEAN                                    float64
# INS_DBD_SUM                                     float64
# INS_AMT_PAYMENT_MIN                             float64
# INS_AMT_PAYMENT_MEAN                            float64
# INS_AMT_PAYMENT_SUM                             float64
# INS_DAYS_ENTRY_PAYMENT_MAX                      float64
# INS_DAYS_ENTRY_PAYMENT_MEAN                     float64
# TARGET                                            int64
# dtype: object

# %%
step_bkwd_feat.remove('SK_ID_CURR')
step_bkwd_feat
# Out:
# ['AMT_CREDIT',
#  'AMT_ANNUITY',
#  'DAYS_BIRTH',
#  'DAYS_ID_PUBLISH',
#  'CNT_FAM_MEMBERS',
#  'EXT_SOURCE_3',
#  'OBS_30_CNT_SOCIAL_CIRCLE',
#  'DEF_30_CNT_SOCIAL_CIRCLE',
#  'NEW_CREDIT_TO_INCOME_RATIO',
#  'NEW_SOURCES_PROD',
#  'NEW_SCORES_STD',
#  'NAME_TYPE_SUITE_ordered',
#  'NAME_INCOME_TYPE_ordered',
#  'NAME_EDUCATION_TYPE_ordered',
#  'NAME_FAMILY_STATUS_ordered',
#  'WEEKDAY_APPR_PROCESS_START_ordered',
#  'ORGANIZATION_TYPE_ordered',
#  'BURO_AMT_CREDIT_SUM_MEAN',
#  'BURO_DAYS_CREDIT_UPDATE_MAX',
#  'PREV_APP_CREDIT_PERC_MAX',
#  'PREV_RATE_DOWN_PAYMENT_MIN',
#  'PREV_DAYS_DECISION_MAX',
#  'PREV_CNT_PAYMENT_MEAN',
#  'POS_MONTHS_BALANCE_MAX',
#  'INS_NUM_INSTALMENT_VERSION_NUNIQUE',
#  'INS_DPD_MAX',
#  'INS_AMT_PAYMENT_MEAN',
#  'INS_AMT_PAYMENT_SUM',
#  'INS_DAYS_ENTRY_PAYMENT_MEAN']

# %%
train_imbalanced = train_imbalanced_sm_tk

# %%
step_bkwd_feat.append('TARGET')
data = train_imbalanced[step_bkwd_feat]

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# IntProgress(value=0, description='Processing: ', max=3)
#
#
# Initiated  . . . . . . . . . . . . . . . . . .                   21:45:18
# Status     . . . . . . . . . . . . . . . . . .  Searching Hyperparameters
# Estimator  . . . . . . . . . . . . . . . . . .   Random Forest Classifier
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# C:\Users\SUDHIR~1\AppData\Local\Temp/ipykernel_3240/501140409.py in <module>
# ----> 1 data = setup(data = data, target = 'TARGET', session_id=123)
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\pycaret\classification.py in setup(data, target, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs)
#     579         log_plots = ["auc", "confusion_matrix", "feature"]
#     580
# --> 581     return pycaret.internal.tabular.setup(
#     582         ml_usecase="classification",
#     583         available_plots=available_plots,
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\pycaret\internal\tabular.py in setup(data, target, ml_usecase, available_plots, train_size, test_data, preprocess, imputation_type, iterative_imputation_iters, categorical_features, categorical_imputation, categorical_iterative_imputer, ordinal_features, high_cardinality_features, high_cardinality_method, numeric_features, numeric_imputation, numeric_iterative_imputer, date_features, ignore_features, normalize, normalize_method, transformation, transformation_method, handle_unknown_categorical, unknown_categorical_method, pca, pca_method, pca_components, ignore_low_variance, combine_rare_levels, rare_level_threshold, bin_numeric_features, remove_outliers, outliers_threshold, remove_multicollinearity, multicollinearity_threshold, remove_perfect_collinearity, create_clusters, cluster_iter, polynomial_features, polynomial_degree, trigonometry_features, polynomial_threshold, group_features, group_names, feature_selection, feature_selection_threshold, feature_selection_method, feature_interaction, feature_ratio, interaction_threshold, fix_imbalance, fix_imbalance_method, transform_target, transform_target_method, data_split_shuffle, data_split_stratify, fold_strategy, fold, fold_shuffle, fold_groups, n_jobs, use_gpu, custom_pipeline, html, session_id, log_experiment, experiment_name, log_plots, log_profile, log_data, silent, verbose, profile, profile_kwargs, display)
#    1116     logger.info("Creating preprocessing pipeline")
#    1117
# -> 1118     prep_pipe = pycaret.internal.preprocess.Preprocess_Path_One(
#    1119         train_data=train_data,
#    1120         ml_usecase="classification"
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\pycaret\internal\preprocess.py in Preprocess_Path_One(train_data, target_variable, ml_usecase, test_data, categorical_features, numerical_features, time_features, features_todrop, display_types, imputation_type, numeric_imputation_strategy, categorical_imputation_strategy, imputation_classifier, imputation_regressor, imputation_max_iter, imputation_warm_start, imputation_order, apply_zero_nearZero_variance, club_rare_levels, rara_level_threshold_percentage, apply_untrained_levels_treatment, untrained_levels_treatment_method, apply_ordinal_encoding, ordinal_columns_and_categories, apply_cardinality_reduction, cardinal_method, cardinal_features, apply_binning, features_to_binn, apply_grouping, group_name, features_to_group_ListofList, apply_polynomial_trigonometry_features, max_polynomial, trigonometry_calculations, top_poly_trig_features_to_select_percentage, scale_data, scaling_method, Power_transform_data, Power_transform_method, remove_outliers, outlier_contamination_percentage, outlier_methods, dummify_categoricals, apply_feature_selection, feature_selection_top_features_percentage, feature_selection_method, remove_multicollinearity, maximum_correlation_between_features, remove_perfect_collinearity, apply_feature_interactions, feature_interactions_to_apply, feature_interactions_top_features_to_select_percentage, cluster_entire_data, range_of_clusters_to_try, apply_pca, pca_method, pca_variance_retained_or_number_of_components, random_state, n_jobs)
#    3326     else:
#    3327         # WE NEED TO AUTO INFER the ml use case
# -> 3328         inferred_ml_usecase, subcase = infer_ml_usecase(train_data[target_variable])
#    3329         if ml_usecase is None:
#    3330             ml_usecase = inferred_ml_usecase
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\pycaret\internal\utils.py in infer_ml_usecase(y)
#     649
#     650 def infer_ml_usecase(y: pd.Series) -> Tuple[str, str]:
# --> 651     c1 = "int" in y.dtype.name
#     652     c2 = y.nunique() <= 20
#     653     c3 = y.dtype.name in ["object", "bool", "category"]
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'dtype'

# %%
best_model6 = compare_models(n_select = 3)

# %%
pred_holdout_mod41 = predict_model(best_model6[0])

# %%
pred_holdout_mod42 = predict_model(best_model6[1])

# %%
pred_holdout_mod43 = predict_model(best_model6[2])

# %%
plot_model(best_model6[0])

# %%
plot_model(best_model6[1])

# %%
plot_model(best_model6[2])

# %%
evaluate_model(best_model6[0])

# %% [markdown]
# #### FROM THE FEATURE SELECTION EXERCISE, A COMPAIRSON OF THE 5 DATASETS SHOW THAT THE DATASET IWTH THE HIGHEST MODELPERFOCMANCE IS THE DATASET COMPRISED OF FEATURES FROM STEP FORWARD SELECTION AND RFE EMBEDDED METHODS.

# %% [markdown]
# # CLASS IMBALANCE TECHNIQUE AND MODEL PERFORMANCE COMPARISON

# %% [markdown]
# #### DATASET WITHOUT CLASS IMBALANCE

# %%
dataset_path = 'train_df_wo_imbalance_74_feat.csv'
train_df_wo_imbalance = pd.read_csv(dataset_path, parse_dates=True, keep_date_col=True)
print(' Train data shape: ', train_df_wo_imbalance.shape)
# Out:
#  Train data shape:  (307511, 75)

# %%
data = train_df_wo_imbalance[feat_common_rfe_step_fwd]

# %%
print(' Train data shape: ', data.shape)
# Out:
#  Train data shape:  (307511, 14)

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_1e798_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1e798_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1e798_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1e798_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1e798_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1e798_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1e798_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1e798_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_1e798_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1e798_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_1e798_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1e798_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_1e798_row4_col1" class="data row4 col1" >(307511, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1e798_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_1e798_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1e798_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_1e798_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1e798_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_1e798_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1e798_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_1e798_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1e798_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_1e798_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1e798_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_1e798_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1e798_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_1e798_row11_col1" class="data row11 col1" >(215257, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1e798_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_1e798_row12_col1" class="data row12 col1" >(92254, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1e798_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_1e798_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1e798_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_1e798_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1e798_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_1e798_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1e798_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_1e798_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1e798_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_1e798_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1e798_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_1e798_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1e798_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_1e798_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1e798_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_1e798_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1e798_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_1e798_row21_col1" class="data row21 col1" >ca04</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1e798_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_1e798_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1e798_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_1e798_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1e798_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_1e798_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1e798_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_1e798_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_1e798_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_1e798_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_1e798_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_1e798_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_1e798_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_1e798_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_1e798_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_1e798_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1e798_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_1e798_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_1e798_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <

# %%
best_model6 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_9370a_ th {
#   text-align: left;
# }
# #T_9370a_row0_col0, #T_9370a_row0_col2, #T_9370a_row0_col3, #T_9370a_row0_col4, #T_9370a_row0_col5, #T_9370a_row0_col6, #T_9370a_row0_col7, #T_9370a_row1_col0, #T_9370a_row1_col2, #T_9370a_row1_col3, #T_9370a_row1_col4, #T_9370a_row1_col5, #T_9370a_row1_col6, #T_9370a_row1_col7, #T_9370a_row2_col0, #T_9370a_row2_col1, #T_9370a_row2_col2, #T_9370a_row2_col3, #T_9370a_row2_col4, #T_9370a_row2_col5, #T_9370a_row2_col6, #T_9370a_row2_col7, #T_9370a_row3_col0, #T_9370a_row3_col1, #T_9370a_row3_col2, #T_9370a_row3_col3, #T_9370a_row3_col5, #T_9370a_row3_col6, #T_9370a_row3_col7, #T_9370a_row4_col0, #T_9370a_row4_col1, #T_9370a_row4_col3, #T_9370a_row4_col4, #T_9370a_row4_col5, #T_9370a_row4_col6, #T_9370a_row4_col7, #T_9370a_row5_col0, #T_9370a_row5_col1, #T_9370a_row5_col2, #T_9370a_row5_col3, #T_9370a_row5_col4, #T_9370a_row5_col5, #T_9370a_row5_col6, #T_9370a_row5_col7, #T_9370a_row6_col0, #T_9370a_row6_col1, #T_9370a_row6_col2, #T_9370a_row6_col3, #T_9370a_row6_col4, #T_9370a_row6_col5, #T_9370a_row6_col6, #T_9370a_row6_col7, #T_9370a_row7_col0, #T_9370a_row7_col1, #T_9370a_row7_col2, #T_9370a_row7_col3, #T_9370a_row7_col4, #T_9370a_row7_col5, #T_9370a_row7_col6, #T_9370a_row7_col7, #T_9370a_row8_col0, #T_9370a_row8_col1, #T_9370a_row8_col2, #T_9370a_row8_col3, #T_9370a_row8_col4, #T_9370a_row8_col5, #T_9370a_row8_col6, #T_9370a_row8_col7, #T_9370a_row9_col0, #T_9370a_row9_col1, #T_9370a_row9_col2, #T_9370a_row9_col3, #T_9370a_row9_col4, #T_9370a_row9_col5, #T_9370a_row10_col0, #T_9370a_row10_col1, #T_9370a_row10_col2, #T_9370a_row10_col3, #T_9370a_row10_col4, #T_9370a_row10_col5, #T_9370a_row10_col6, #T_9370a_row10_col7, #T_9370a_row11_col0, #T_9370a_row11_col1, #T_9370a_row11_col2, #T_9370a_row11_col4, #T_9370a_row11_col6, #T_9370a_row11_col7, #T_9370a_row12_col0, #T_9370a_row12_col1, #T_9370a_row12_col2, #T_9370a_row12_col3, #T_9370a_row12_col4, #T_9370a_row12_col5, #T_9370a_row12_col6, #T_9370a_row12_col7 {
#   text-align: left;
# }
# #T_9370a_row0_col1, #T_9370a_row1_col1, #T_9370a_row3_col4, #T_9370a_row4_col2, #T_9370a_row9_col6, #T_9370a_row9_col7, #T_9370a_row11_col3, #T_9370a_row11_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9370a_row0_col8, #T_9370a_row2_col8, #T_9370a_row3_col8, #T_9370a_row4_col8, #T_9370a_row5_col8, #T_9370a_row6_col8, #T_9370a_row7_col8, #T_9370a_row8_col8, #T_9370a_row9_col8, #T_9370a_row10_col8, #T_9370a_row11_col8, #T_9370a_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9370a_row1_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9370a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9370a_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_9370a_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_9370a_row0_col1" class="data row0 col1" >0.9197</td>
#       <td id="T_9370a_row0_col2" class="data row0 col2" >0.5293</td>
#       <td id="T_9370a_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_9370a_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_9370a_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_9370a_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_9370a_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_9370a_row0_col8" class="data row0 col8" >0.7430</td>
#     </tr>
#     <tr>
#       <th id="T_9370a_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_9370a_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_9370a_row1_col1" class="data row1 col1" >0.9197</td>
#       <td id="T_9370a_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_9370a_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_9370a_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_9370a_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_9370a_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_9370a_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_9370a_row1_col8" class="data row1 col8" >0.1270</td>
#     </tr>
#     <tr>
#       <th id="T_9370a_level0_row2" class="row_heading level0 row2" >nb</th>
#       <td id="T_9370a_row2_col0" class="data row2 col0" >Naive Bayes</td>
#       <td id="T_9370a_row2_col1" class="data row2 col1" >0.9196</td>
#       <td id="T_9370a_row2_col2" class="data row2 col2" >0.5801</td>
#       <td id="T_9370a_row2_col3" class="data row2 col3" >0.0001</td>
#       <td id="T_9370a_row2_col4" class="data row2 col4" >0.0833</td>
#       <td id="T_9370a_row2_col5" class="data row2 col5" >0.0002</td>
#       <td id="T_9370a_row2_col6" class="data row2 col6" >0.0000</td>
#       <td id="T_9370a_row2_col7" class="data row2 col7" >0.0004</td>
#       <td id="T_9370a_row2_col8" class="data row2 col8" >0.1300</td>
#     </tr>
#     <tr>
#       <th id="T_9370a_level0_row3" class="row_heading level0 row3" >ada</th>
#       <td id="T_9370a_row3_col0" class="data row3 col0" >Ada Boost Classifier</td>
#       <td id="T_9370a_row3_col1" class="data row3 col1" >0.9196</td>
#       <td id="T_9370a_row3_col2" class="data row3 col2" >0.7359</td>
#       <td id="T_9370a_row3_col3" class="data row3 col3" >0.0065</td>
#       <td id="T_9370a_row3_col4" class="data row3 col4" >0.4821</td>
#       <td id="T_9370a_row3_col5" class="data row3 col5" >0.0129</td>
#       <td id="T_9370a_row3_col6" class="data row3 col6" >0.0107</td>
#       <td id="T_9370a_row3_col7" class="data row3 col7" >0.0484</td>
#       <td id="T_9370a_row3_col8" class="data row3 col8" >5.8760</td>
#     </tr>
#     <tr>
#       <th id="T_9370a_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_9370a_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_9370a_row4_col1" class="data row4 col1" >0.9196</td>
#       <td id="T_9370a_row4_col2" class="data row4 col2" >0.7383</td>
#       <td id="T_9370a_row4_col3" class="data row4 col3" >0.0046</td>
#       <td id="T_9370a_row4_col4" class="data row4 col4" >0.4796</td>
#       <td id="T_9370a_row4_col5" class="data row4 col5" >0.0090</td>
#       <td id="T_9370a_row4_col6" class="data row4 col6" >0.0075</td>
#       <td id="T_9370a_row4_col7" class="data row4 col7" >0.0403</td>
#       <td id="T_9370a_row4_col8" class="data row4 col8" >25.9590</td>
#     </tr>
#     <tr>
#       <th id="T_9370a_level0_row5" class="row_heading level0 row5" >lightgbm</th>
#       <td id="T_9370a_row5_col0" class="data row5 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9370a_row5_col1" class="data row5 col1" >0.9196</td>
#       <td id="T_9370a_row5_col2" class="data row5 col2" >0.7370</td>
#       <td id="T_9370a_row5_col3" class="data row5 col3" >0.0031</td>
#       <td id="T_9370a_row5_col4" class="data row5 col4" >0.4779</td>
#       <td id="T_9370a_row5_col5" class="data row5 col5" >0.0062</td>
#       <td id="T_9370a_row5_col6" class="data row5 col6" >0.0051</td>
#       <td id="T_9370a_row5_col7" class="data row5 col7" >0.0332</td>
#       <td id="T_9370a_row5_col8" class="data row5 col8" >1.2650</td>
#     </tr>
#     <tr>
#       <th id="T_9370a_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_9370a_row6_col0" class="data row6 col0" >Random Forest Classifier</td>
#       <td id="T_9370a_row6_col1" class="data row6 col1" >0.9195</td>
#       <td id="T_9370a_row6_col2" class="data row6 col2" >0.7085</td>
#       <td id="T_9370a_row6_col3" class="data

# %%
pred_holdout_mod41 = predict_model(best_model6[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_488b7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_488b7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_488b7_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_488b7_row0_col1" class="data row0 col1" >0.9183</td>
#       <td id="T_488b7_row0_col2" class="data row0 col2" >0.5231</td>
#       <td id="T_488b7_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_488b7_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_488b7_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_488b7_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_488b7_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod42 = predict_model(best_model6[1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_427bf_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_427bf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_427bf_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_427bf_row0_col1" class="data row0 col1" >0.9183</td>
#       <td id="T_427bf_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_427bf_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_427bf_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_427bf_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_427bf_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_427bf_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod43 = predict_model(best_model6[2])
# Out:
# <style type="text/css">
# </style>
# <table id="T_660ae_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_660ae_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_660ae_row0_col0" class="data row0 col0" >Naive Bayes</td>
#       <td id="T_660ae_row0_col1" class="data row0 col1" >0.9182</td>
#       <td id="T_660ae_row0_col2" class="data row0 col2" >0.5799</td>
#       <td id="T_660ae_row0_col3" class="data row0 col3" >0.0003</td>
#       <td id="T_660ae_row0_col4" class="data row0 col4" >0.1333</td>
#       <td id="T_660ae_row0_col5" class="data row0 col5" >0.0005</td>
#       <td id="T_660ae_row0_col6" class="data row0 col6" >0.0002</td>
#       <td id="T_660ae_row0_col7" class="data row0 col7" >0.0024</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model6[0])

# %%
plot_model(best_model6[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SUDHIR~1\AppData\Local\Temp/ipykernel_8396/1512282060.py in <module>
# ----> 1 plot_model(best_model6[1])
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\pycaret\classification.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, use_train_data, verbose, display_format)
#    1538     """
#    1539
# -> 1540     return pycaret.internal.tabular.plot_model(
#    1541         estimator=estimator,
#    1542         plot=plot,
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\pycaret\internal\tabular.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format, is_in_evaluate)
#    5827     # checking for auc plot
#    5828     if not hasattr(estimator, "predict_proba") and plot == "auc":
# -> 5829         raise TypeError(
#    5830             "AUC plot not available for estimators with no predict_proba attribute."
#    5831         )
#
# TypeError: AUC plot not available for estimators with no predict_proba attribute.

# %%
plot_model(best_model6[2])

# %%
evaluate_model(best_model6[0])
# Out:
#                   Parameters
# C                        1.0
# class_weight            None
# dual                   False
# fit_intercept           True
# intercept_scaling          1
# l1_ratio                None
# max_iter                1000
# multi_class             auto
# n_jobs                  None
# penalty                   l2
# random_state             123
# solver                 lbfgs
# tol                   0.0001
# verbose                    0
# warm_start             False

# %% [markdown]
# #### DATASET WITH SMOTE

# %%
dataset_path = '4NOVtrain_sm_balanced.csv'
train_df_w_SMOTE = pd.read_csv(dataset_path, parse_dates=True, keep_date_col=True)
print(' Train data shape: ', train_df_w_SMOTE.shape)
# Out:
#  Train data shape:  (564832, 75)

# %%
data = train_df_w_SMOTE[feat_common_rfe_step_fwd]

# %%
print(' Train data shape: ', data.shape)
# Out:
#  Train data shape:  (564832, 14)

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_1b791_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_1b791_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1b791_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1b791_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_1b791_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_1b791_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_1b791_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_1b791_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_1b791_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_1b791_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_1b791_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_1b791_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_1b791_row4_col1" class="data row4 col1" >(564832, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_1b791_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_1b791_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_1b791_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_1b791_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_1b791_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_1b791_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_1b791_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_1b791_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_1b791_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_1b791_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_1b791_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_1b791_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_1b791_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_1b791_row11_col1" class="data row11 col1" >(395382, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_1b791_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_1b791_row12_col1" class="data row12 col1" >(169450, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_1b791_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_1b791_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_1b791_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_1b791_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_1b791_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_1b791_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_1b791_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_1b791_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_1b791_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_1b791_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_1b791_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_1b791_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_1b791_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_1b791_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_1b791_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_1b791_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_1b791_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_1b791_row21_col1" class="data row21 col1" >8f56</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_1b791_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_1b791_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_1b791_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_1b791_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_1b791_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_1b791_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_1b791_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_1b791_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_1b791_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_1b791_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_1b791_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_1b791_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_1b791_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_1b791_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_1b791_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_1b791_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_1b791_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_1b791_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_1b791_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
best_model6 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_9e43b_ th {
#   text-align: left;
# }
# #T_9e43b_row0_col0, #T_9e43b_row0_col2, #T_9e43b_row0_col3, #T_9e43b_row1_col0, #T_9e43b_row1_col1, #T_9e43b_row1_col4, #T_9e43b_row1_col5, #T_9e43b_row1_col6, #T_9e43b_row1_col7, #T_9e43b_row2_col0, #T_9e43b_row2_col1, #T_9e43b_row2_col2, #T_9e43b_row2_col3, #T_9e43b_row2_col4, #T_9e43b_row2_col5, #T_9e43b_row2_col6, #T_9e43b_row2_col7, #T_9e43b_row3_col0, #T_9e43b_row3_col1, #T_9e43b_row3_col2, #T_9e43b_row3_col3, #T_9e43b_row3_col4, #T_9e43b_row3_col5, #T_9e43b_row3_col6, #T_9e43b_row3_col7, #T_9e43b_row4_col0, #T_9e43b_row4_col1, #T_9e43b_row4_col2, #T_9e43b_row4_col3, #T_9e43b_row4_col4, #T_9e43b_row4_col5, #T_9e43b_row4_col6, #T_9e43b_row4_col7, #T_9e43b_row5_col0, #T_9e43b_row5_col1, #T_9e43b_row5_col2, #T_9e43b_row5_col3, #T_9e43b_row5_col4, #T_9e43b_row5_col5, #T_9e43b_row5_col6, #T_9e43b_row5_col7, #T_9e43b_row6_col0, #T_9e43b_row6_col1, #T_9e43b_row6_col2, #T_9e43b_row6_col3, #T_9e43b_row6_col4, #T_9e43b_row6_col5, #T_9e43b_row6_col6, #T_9e43b_row6_col7, #T_9e43b_row7_col0, #T_9e43b_row7_col1, #T_9e43b_row7_col2, #T_9e43b_row7_col3, #T_9e43b_row7_col4, #T_9e43b_row7_col5, #T_9e43b_row7_col6, #T_9e43b_row7_col7, #T_9e43b_row8_col0, #T_9e43b_row8_col1, #T_9e43b_row8_col2, #T_9e43b_row8_col3, #T_9e43b_row8_col4, #T_9e43b_row8_col5, #T_9e43b_row8_col6, #T_9e43b_row8_col7, #T_9e43b_row9_col0, #T_9e43b_row9_col1, #T_9e43b_row9_col2, #T_9e43b_row9_col3, #T_9e43b_row9_col4, #T_9e43b_row9_col5, #T_9e43b_row9_col6, #T_9e43b_row9_col7, #T_9e43b_row10_col0, #T_9e43b_row10_col1, #T_9e43b_row10_col2, #T_9e43b_row10_col3, #T_9e43b_row10_col4, #T_9e43b_row10_col5, #T_9e43b_row10_col6, #T_9e43b_row10_col7, #T_9e43b_row11_col0, #T_9e43b_row11_col1, #T_9e43b_row11_col2, #T_9e43b_row11_col3, #T_9e43b_row11_col4, #T_9e43b_row11_col5, #T_9e43b_row11_col6, #T_9e43b_row11_col7, #T_9e43b_row12_col0, #T_9e43b_row12_col1, #T_9e43b_row12_col2, #T_9e43b_row12_col3, #T_9e43b_row12_col4, #T_9e43b_row12_col5, #T_9e43b_row12_col6, #T_9e43b_row12_col7 {
#   text-align: left;
# }
# #T_9e43b_row0_col1, #T_9e43b_row0_col4, #T_9e43b_row0_col5, #T_9e43b_row0_col6, #T_9e43b_row0_col7, #T_9e43b_row1_col2, #T_9e43b_row1_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_9e43b_row0_col8, #T_9e43b_row1_col8, #T_9e43b_row2_col8, #T_9e43b_row3_col8, #T_9e43b_row4_col8, #T_9e43b_row5_col8, #T_9e43b_row6_col8, #T_9e43b_row7_col8, #T_9e43b_row8_col8, #T_9e43b_row9_col8, #T_9e43b_row11_col8, #T_9e43b_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_9e43b_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_9e43b_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9e43b_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_9e43b_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_9e43b_row0_col1" class="data row0 col1" >0.9537</td>
#       <td id="T_9e43b_row0_col2" class="data row0 col2" >0.9763</td>
#       <td id="T_9e43b_row0_col3" class="data row0 col3" >0.9092</td>
#       <td id="T_9e43b_row0_col4" class="data row0 col4" >0.9979</td>
#       <td id="T_9e43b_row0_col5" class="data row0 col5" >0.9515</td>
#       <td id="T_9e43b_row0_col6" class="data row0 col6" >0.9073</td>
#       <td id="T_9e43b_row0_col7" class="data row0 col7" >0.9109</td>
#       <td id="T_9e43b_row0_col8" class="data row0 col8" >6.6960</td>
#     </tr>
#     <tr>
#       <th id="T_9e43b_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_9e43b_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_9e43b_row1_col1" class="data row1 col1" >0.9527</td>
#       <td id="T_9e43b_row1_col2" class="data row1 col2" >0.9828</td>
#       <td id="T_9e43b_row1_col3" class="data row1 col3" >0.9182</td>
#       <td id="T_9e43b_row1_col4" class="data row1 col4" >0.9863</td>
#       <td id="T_9e43b_row1_col5" class="data row1 col5" >0.9510</td>
#       <td id="T_9e43b_row1_col6" class="data row1 col6" >0.9054</td>
#       <td id="T_9e43b_row1_col7" class="data row1 col7" >0.9076</td>
#       <td id="T_9e43b_row1_col8" class="data row1 col8" >75.5680</td>
#     </tr>
#     <tr>
#       <th id="T_9e43b_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_9e43b_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_9e43b_row2_col1" class="data row2 col1" >0.9504</td>
#       <td id="T_9e43b_row2_col2" class="data row2 col2" >0.9767</td>
#       <td id="T_9e43b_row2_col3" class="data row2 col3" >0.9064</td>
#       <td id="T_9e43b_row2_col4" class="data row2 col4" >0.9938</td>
#       <td id="T_9e43b_row2_col5" class="data row2 col5" >0.9481</td>
#       <td id="T_9e43b_row2_col6" class="data row2 col6" >0.9008</td>
#       <td id="T_9e43b_row2_col7" class="data row2 col7" >0.9043</td>
#       <td id="T_9e43b_row2_col8" class="data row2 col8" >47.5060</td>
#     </tr>
#     <tr>
#       <th id="T_9e43b_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_9e43b_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_9e43b_row3_col1" class="data row3 col1" >0.9420</td>
#       <td id="T_9e43b_row3_col2" class="data row3 col2" >0.9721</td>
#       <td id="T_9e43b_row3_col3" class="data row3 col3" >0.8915</td>
#       <td id="T_9e43b_row3_col4" class="data row3 col4" >0.9916</td>
#       <td id="T_9e43b_row3_col5" class="data row3 col5" >0.9389</td>
#       <td id="T_9e43b_row3_col6" class="data row3 col6" >0.8840</td>
#       <td id="T_9e43b_row3_col7" class="data row3 col7" >0.8886</td>
#       <td id="T_9e43b_row3_col8" class="data row3 col8" >68.1000</td>
#     </tr>
#     <tr>
#       <th id="T_9e43b_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_9e43b_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_9e43b_row4_col1" class="data row4 col1" >0.9088</td>
#       <td id="T_9e43b_row4_col2" class="data row4 col2" >0.9575</td>
#       <td id="T_9e43b_row4_col3" class="data row4 col3" >0.8677</td>
#       <td id="T_9e43b_row4_col4" class="data row4 col4" >0.9453</td>
#       <td id="T_9e43b_row4_col5" class="data row4 col5" >0.9048</td>
#       <td id="T_9e43b_row4_col6" class="data row4 col6" >0.8175</td>
#       <td id="T_9e43b_row4_col7" class="data row4 col7" >0.8203</td>
#       <td id="T_9e43b_row4_col8" class="data row4 col8" >15.0620</td>
#     </tr>
#     <tr>
#       <th id="T_9e43b_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_9e43b_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_9e43b_row5_col1" class="data row5 col1" >0.9036</td>
#       <td id="T_9e43b_row5_col2" class="data row5 col2" >0.9036</td>
#       <td id="T_9e43b_row5_col3" class="data row5 col3" >0.9100</td>
#       <td id="T_9e43b_row5_col4" class="data row5 col4" >0.8984</td>
#       <td id="T_9e43b_row5_col5" class="data row5 col5" >0.9041</td>
#       <td id="T_9e43b_row5_col6" class="data row5 col6" >0.8071</td>
#       <td id="T_9e43b_row5_col7" class="data row5 col7" >0.8072</td>
#       <td id="T_9e43b_row5_col8" class="data row5 col8" >2.6230</td>
#     </tr>
#     <tr>
#       <th id="T_9e43b_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_9e43b_row6_col0" class="data row6 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_9e43b_row6_col1" class="data row6 col1" >0.7054</td>
#       <td id="T_9e43b_row6_col2" class="data row6 col2" >0.7747</td>
#       <td id

# %%
pred_holdout_mod41 = predict_model(best_model6[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_e2b3f_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_e2b3f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_e2b3f_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_e2b3f_row0_col1" class="data row0 col1" >0.9541</td>
#       <td id="T_e2b3f_row0_col2" class="data row0 col2" >0.9763</td>
#       <td id="T_e2b3f_row0_col3" class="data row0 col3" >0.9100</td>
#       <td id="T_e2b3f_row0_col4" class="data row0 col4" >0.9980</td>
#       <td id="T_e2b3f_row0_col5" class="data row0 col5" >0.9520</td>
#       <td id="T_e2b3f_row0_col6" class="data row0 col6" >0.9081</td>
#       <td id="T_e2b3f_row0_col7" class="data row0 col7" >0.9117</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod42 = predict_model(best_model6[1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_db57e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_db57e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_db57e_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_db57e_row0_col1" class="data row0 col1" >0.9547</td>
#       <td id="T_db57e_row0_col2" class="data row0 col2" >0.9838</td>
#       <td id="T_db57e_row0_col3" class="data row0 col3" >0.9217</td>
#       <td id="T_db57e_row0_col4" class="data row0 col4" >0.9868</td>
#       <td id="T_db57e_row0_col5" class="data row0 col5" >0.9532</td>
#       <td id="T_db57e_row0_col6" class="data row0 col6" >0.9093</td>
#       <td id="T_db57e_row0_col7" class="data row0 col7" >0.9113</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod43 = predict_model(best_model6[2])
# Out:
# <style type="text/css">
# </style>
# <table id="T_71e6a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_71e6a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_71e6a_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_71e6a_row0_col1" class="data row0 col1" >0.9513</td>
#       <td id="T_71e6a_row0_col2" class="data row0 col2" >0.9767</td>
#       <td id="T_71e6a_row0_col3" class="data row0 col3" >0.9083</td>
#       <td id="T_71e6a_row0_col4" class="data row0 col4" >0.9940</td>
#       <td id="T_71e6a_row0_col5" class="data row0 col5" >0.9492</td>
#       <td id="T_71e6a_row0_col6" class="data row0 col6" >0.9027</td>
#       <td id="T_71e6a_row0_col7" class="data row0 col7" >0.9061</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model6[0])

# %%
plot_model(best_model6[1])

# %%
plot_model(best_model6[2])

# %%
evaluate_model(best_model6[0])
# Out:
#                   Parameters
# boosting_type           gbdt
# class_weight            None
# colsample_bytree         1.0
# importance_type        split
# learning_rate            0.1
# max_depth                 -1
# min_child_samples         20
# min_child_weight       0.001
# min_split_gain           0.0
# n_estimators             100
# n_jobs                    -1
# num_leaves                31
# objective               None
# random_state             123
# reg_alpha                0.0
# reg_lambda               0.0
# silent                  warn
# subsample                1.0
# subsample_for_bin     200000
# subsample_freq             0

# %% [markdown]
# #### DATASET WITH ADASYN

# %%
dataset_path = '4NOVtrain_adasyn_balanced.csv'
train_df_w_ADASYN = pd.read_csv(dataset_path, parse_dates=True, keep_date_col=True)
print(' Train data shape: ', train_df_w_ADASYN.shape)
# Out:
#  Train data shape:  (556895, 75)

# %%
data = train_df_w_ADASYN[feat_common_rfe_step_fwd]

# %%
print(' Train data shape: ', data.shape)
# Out:
#  Train data shape:  (556895, 14)

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_ad279_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_ad279_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ad279_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_ad279_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_ad279_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_ad279_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_ad279_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_ad279_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_ad279_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_ad279_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_ad279_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_ad279_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_ad279_row4_col1" class="data row4 col1" >(556895, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_ad279_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_ad279_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_ad279_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_ad279_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_ad279_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_ad279_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_ad279_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_ad279_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_ad279_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_ad279_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_ad279_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_ad279_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_ad279_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_ad279_row11_col1" class="data row11 col1" >(389826, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_ad279_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_ad279_row12_col1" class="data row12 col1" >(167069, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_ad279_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_ad279_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_ad279_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_ad279_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_ad279_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_ad279_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_ad279_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_ad279_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_ad279_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_ad279_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_ad279_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_ad279_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_ad279_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_ad279_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_ad279_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_ad279_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_ad279_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_ad279_row21_col1" class="data row21 col1" >be82</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_ad279_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_ad279_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_ad279_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_ad279_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_ad279_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_ad279_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_ad279_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_ad279_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_ad279_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_ad279_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_ad279_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_ad279_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_ad279_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_ad279_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_ad279_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_ad279_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_ad279_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_ad279_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_ad279_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
best_model6 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_02bd5_ th {
#   text-align: left;
# }
# #T_02bd5_row0_col0, #T_02bd5_row0_col2, #T_02bd5_row0_col3, #T_02bd5_row1_col0, #T_02bd5_row1_col1, #T_02bd5_row1_col4, #T_02bd5_row1_col5, #T_02bd5_row1_col6, #T_02bd5_row1_col7, #T_02bd5_row2_col0, #T_02bd5_row2_col1, #T_02bd5_row2_col2, #T_02bd5_row2_col3, #T_02bd5_row2_col4, #T_02bd5_row2_col5, #T_02bd5_row2_col6, #T_02bd5_row2_col7, #T_02bd5_row3_col0, #T_02bd5_row3_col1, #T_02bd5_row3_col2, #T_02bd5_row3_col3, #T_02bd5_row3_col4, #T_02bd5_row3_col5, #T_02bd5_row3_col6, #T_02bd5_row3_col7, #T_02bd5_row4_col0, #T_02bd5_row4_col1, #T_02bd5_row4_col2, #T_02bd5_row4_col3, #T_02bd5_row4_col4, #T_02bd5_row4_col5, #T_02bd5_row4_col6, #T_02bd5_row4_col7, #T_02bd5_row5_col0, #T_02bd5_row5_col1, #T_02bd5_row5_col2, #T_02bd5_row5_col3, #T_02bd5_row5_col4, #T_02bd5_row5_col5, #T_02bd5_row5_col6, #T_02bd5_row5_col7, #T_02bd5_row6_col0, #T_02bd5_row6_col1, #T_02bd5_row6_col2, #T_02bd5_row6_col3, #T_02bd5_row6_col4, #T_02bd5_row6_col5, #T_02bd5_row6_col6, #T_02bd5_row6_col7, #T_02bd5_row7_col0, #T_02bd5_row7_col1, #T_02bd5_row7_col2, #T_02bd5_row7_col3, #T_02bd5_row7_col4, #T_02bd5_row7_col5, #T_02bd5_row7_col6, #T_02bd5_row7_col7, #T_02bd5_row8_col0, #T_02bd5_row8_col1, #T_02bd5_row8_col2, #T_02bd5_row8_col3, #T_02bd5_row8_col4, #T_02bd5_row8_col5, #T_02bd5_row8_col6, #T_02bd5_row8_col7, #T_02bd5_row9_col0, #T_02bd5_row9_col1, #T_02bd5_row9_col2, #T_02bd5_row9_col3, #T_02bd5_row9_col4, #T_02bd5_row9_col5, #T_02bd5_row9_col6, #T_02bd5_row9_col7, #T_02bd5_row10_col0, #T_02bd5_row10_col1, #T_02bd5_row10_col2, #T_02bd5_row10_col3, #T_02bd5_row10_col4, #T_02bd5_row10_col5, #T_02bd5_row10_col6, #T_02bd5_row10_col7, #T_02bd5_row11_col0, #T_02bd5_row11_col1, #T_02bd5_row11_col2, #T_02bd5_row11_col3, #T_02bd5_row11_col4, #T_02bd5_row11_col5, #T_02bd5_row11_col6, #T_02bd5_row11_col7, #T_02bd5_row12_col0, #T_02bd5_row12_col1, #T_02bd5_row12_col2, #T_02bd5_row12_col3, #T_02bd5_row12_col4, #T_02bd5_row12_col5, #T_02bd5_row12_col6, #T_02bd5_row12_col7 {
#   text-align: left;
# }
# #T_02bd5_row0_col1, #T_02bd5_row0_col4, #T_02bd5_row0_col5, #T_02bd5_row0_col6, #T_02bd5_row0_col7, #T_02bd5_row1_col2, #T_02bd5_row1_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_02bd5_row0_col8, #T_02bd5_row1_col8, #T_02bd5_row2_col8, #T_02bd5_row3_col8, #T_02bd5_row4_col8, #T_02bd5_row5_col8, #T_02bd5_row6_col8, #T_02bd5_row7_col8, #T_02bd5_row8_col8, #T_02bd5_row9_col8, #T_02bd5_row11_col8, #T_02bd5_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_02bd5_row10_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_02bd5_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_02bd5_level0_row0" class="row_heading level0 row0" >lightgbm</th>
#       <td id="T_02bd5_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_02bd5_row0_col1" class="data row0 col1" >0.9533</td>
#       <td id="T_02bd5_row0_col2" class="data row0 col2" >0.9758</td>
#       <td id="T_02bd5_row0_col3" class="data row0 col3" >0.9071</td>
#       <td id="T_02bd5_row0_col4" class="data row0 col4" >0.9980</td>
#       <td id="T_02bd5_row0_col5" class="data row0 col5" >0.9504</td>
#       <td id="T_02bd5_row0_col6" class="data row0 col6" >0.9065</td>
#       <td id="T_02bd5_row0_col7" class="data row0 col7" >0.9102</td>
#       <td id="T_02bd5_row0_col8" class="data row0 col8" >5.5440</td>
#     </tr>
#     <tr>
#       <th id="T_02bd5_level0_row1" class="row_heading level0 row1" >et</th>
#       <td id="T_02bd5_row1_col0" class="data row1 col0" >Extra Trees Classifier</td>
#       <td id="T_02bd5_row1_col1" class="data row1 col1" >0.9520</td>
#       <td id="T_02bd5_row1_col2" class="data row1 col2" >0.9822</td>
#       <td id="T_02bd5_row1_col3" class="data row1 col3" >0.9148</td>
#       <td id="T_02bd5_row1_col4" class="data row1 col4" >0.9869</td>
#       <td id="T_02bd5_row1_col5" class="data row1 col5" >0.9495</td>
#       <td id="T_02bd5_row1_col6" class="data row1 col6" >0.9039</td>
#       <td id="T_02bd5_row1_col7" class="data row1 col7" >0.9063</td>
#       <td id="T_02bd5_row1_col8" class="data row1 col8" >123.3790</td>
#     </tr>
#     <tr>
#       <th id="T_02bd5_level0_row2" class="row_heading level0 row2" >rf</th>
#       <td id="T_02bd5_row2_col0" class="data row2 col0" >Random Forest Classifier</td>
#       <td id="T_02bd5_row2_col1" class="data row2 col1" >0.9498</td>
#       <td id="T_02bd5_row2_col2" class="data row2 col2" >0.9761</td>
#       <td id="T_02bd5_row2_col3" class="data row2 col3" >0.9036</td>
#       <td id="T_02bd5_row2_col4" class="data row2 col4" >0.9939</td>
#       <td id="T_02bd5_row2_col5" class="data row2 col5" >0.9466</td>
#       <td id="T_02bd5_row2_col6" class="data row2 col6" >0.8994</td>
#       <td id="T_02bd5_row2_col7" class="data row2 col7" >0.9030</td>
#       <td id="T_02bd5_row2_col8" class="data row2 col8" >50.5040</td>
#     </tr>
#     <tr>
#       <th id="T_02bd5_level0_row3" class="row_heading level0 row3" >gbc</th>
#       <td id="T_02bd5_row3_col0" class="data row3 col0" >Gradient Boosting Classifier</td>
#       <td id="T_02bd5_row3_col1" class="data row3 col1" >0.9417</td>
#       <td id="T_02bd5_row3_col2" class="data row3 col2" >0.9715</td>
#       <td id="T_02bd5_row3_col3" class="data row3 col3" >0.8894</td>
#       <td id="T_02bd5_row3_col4" class="data row3 col4" >0.9914</td>
#       <td id="T_02bd5_row3_col5" class="data row3 col5" >0.9376</td>
#       <td id="T_02bd5_row3_col6" class="data row3 col6" >0.8832</td>
#       <td id="T_02bd5_row3_col7" class="data row3 col7" >0.8878</td>
#       <td id="T_02bd5_row3_col8" class="data row3 col8" >68.9140</td>
#     </tr>
#     <tr>
#       <th id="T_02bd5_level0_row4" class="row_heading level0 row4" >ada</th>
#       <td id="T_02bd5_row4_col0" class="data row4 col0" >Ada Boost Classifier</td>
#       <td id="T_02bd5_row4_col1" class="data row4 col1" >0.9088</td>
#       <td id="T_02bd5_row4_col2" class="data row4 col2" >0.9569</td>
#       <td id="T_02bd5_row4_col3" class="data row4 col3" >0.8648</td>
#       <td id="T_02bd5_row4_col4" class="data row4 col4" >0.9454</td>
#       <td id="T_02bd5_row4_col5" class="data row4 col5" >0.9033</td>
#       <td id="T_02bd5_row4_col6" class="data row4 col6" >0.8173</td>
#       <td id="T_02bd5_row4_col7" class="data row4 col7" >0.8203</td>
#       <td id="T_02bd5_row4_col8" class="data row4 col8" >15.2560</td>
#     </tr>
#     <tr>
#       <th id="T_02bd5_level0_row5" class="row_heading level0 row5" >dt</th>
#       <td id="T_02bd5_row5_col0" class="data row5 col0" >Decision Tree Classifier</td>
#       <td id="T_02bd5_row5_col1" class="data row5 col1" >0.9030</td>
#       <td id="T_02bd5_row5_col2" class="data row5 col2" >0.9031</td>
#       <td id="T_02bd5_row5_col3" class="data row5 col3" >0.9090</td>
#       <td id="T_02bd5_row5_col4" class="data row5 col4" >0.8957</td>
#       <td id="T_02bd5_row5_col5" class="data row5 col5" >0.9023</td>
#       <td id="T_02bd5_row5_col6" class="data row5 col6" >0.8061</td>
#       <td id="T_02bd5_row5_col7" class="data row5 col7" >0.8062</td>
#       <td id="T_02bd5_row5_col8" class="data row5 col8" >2.8740</td>
#     </tr>
#     <tr>
#       <th id="T_02bd5_level0_row6" class="row_heading level0 row6" >qda</th>
#       <td id="T_02bd5_row6_col0" class="data row6 col0" >Quadratic Discriminant Analysis</td>
#       <td id="T_02bd5_row6_col1" class="data row6 col1" >0.7061</td>
#       <td id="T_02bd5_row6_col2" class="data row6 col2" >0.7751</td>
#       <td i

# %%
pred_holdout_mod41 = predict_model(best_model6[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_f777c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_f777c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_f777c_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_f777c_row0_col1" class="data row0 col1" >0.9528</td>
#       <td id="T_f777c_row0_col2" class="data row0 col2" >0.9755</td>
#       <td id="T_f777c_row0_col3" class="data row0 col3" >0.9061</td>
#       <td id="T_f777c_row0_col4" class="data row0 col4" >0.9981</td>
#       <td id="T_f777c_row0_col5" class="data row0 col5" >0.9499</td>
#       <td id="T_f777c_row0_col6" class="data row0 col6" >0.9055</td>
#       <td id="T_f777c_row0_col7" class="data row0 col7" >0.9093</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod42 = predict_model(best_model6[1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_c8e62_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_c8e62_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_c8e62_row0_col0" class="data row0 col0" >Extra Trees Classifier</td>
#       <td id="T_c8e62_row0_col1" class="data row0 col1" >0.9526</td>
#       <td id="T_c8e62_row0_col2" class="data row0 col2" >0.9828</td>
#       <td id="T_c8e62_row0_col3" class="data row0 col3" >0.9163</td>
#       <td id="T_c8e62_row0_col4" class="data row0 col4" >0.9866</td>
#       <td id="T_c8e62_row0_col5" class="data row0 col5" >0.9501</td>
#       <td id="T_c8e62_row0_col6" class="data row0 col6" >0.9050</td>
#       <td id="T_c8e62_row0_col7" class="data row0 col7" >0.9073</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod43 = predict_model(best_model6[2])
# Out:
# <style type="text/css">
# </style>
# <table id="T_5ead7_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_5ead7_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_5ead7_row0_col0" class="data row0 col0" >Random Forest Classifier</td>
#       <td id="T_5ead7_row0_col1" class="data row0 col1" >0.9494</td>
#       <td id="T_5ead7_row0_col2" class="data row0 col2" >0.9761</td>
#       <td id="T_5ead7_row0_col3" class="data row0 col3" >0.9031</td>
#       <td id="T_5ead7_row0_col4" class="data row0 col4" >0.9938</td>
#       <td id="T_5ead7_row0_col5" class="data row0 col5" >0.9463</td>
#       <td id="T_5ead7_row0_col6" class="data row0 col6" >0.8986</td>
#       <td id="T_5ead7_row0_col7" class="data row0 col7" >0.9023</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model6[0])

# %%
plot_model(best_model6[1])

# %%
plot_model(best_model6[2])

# %%
evaluate_model(best_model6[0])
# Out:
#                   Parameters
# boosting_type           gbdt
# class_weight            None
# colsample_bytree         1.0
# importance_type        split
# learning_rate            0.1
# max_depth                 -1
# min_child_samples         20
# min_child_weight       0.001
# min_split_gain           0.0
# n_estimators             100
# n_jobs                    -1
# num_leaves                31
# objective               None
# random_state             123
# reg_alpha                0.0
# reg_lambda               0.0
# silent                  warn
# subsample                1.0
# subsample_for_bin     200000
# subsample_freq             0

# %% [markdown]
# #### DATASET WITH TOMEK

# %%
dataset_path = '4NOVtrain_tomek_balanced.csv'
train_df_w_TOMEK = pd.read_csv(dataset_path, parse_dates=True, keep_date_col=True)
print(' Train data shape: ', train_df_w_TOMEK.shape)
# Out:
#  Train data shape:  (296127, 75)

# %%
data = train_df_w_TOMEK[feat_common_rfe_step_fwd]

# %%
print(' Train data shape: ', data.shape)
# Out:
#  Train data shape:  (296127, 14)

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_68651_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_68651_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_68651_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_68651_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_68651_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_68651_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_68651_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_68651_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_68651_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_68651_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_68651_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_68651_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_68651_row4_col1" class="data row4 col1" >(296127, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_68651_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_68651_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_68651_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_68651_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_68651_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_68651_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_68651_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_68651_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_68651_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_68651_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_68651_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_68651_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_68651_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_68651_row11_col1" class="data row11 col1" >(207288, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_68651_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_68651_row12_col1" class="data row12 col1" >(88839, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_68651_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_68651_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_68651_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_68651_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_68651_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_68651_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_68651_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_68651_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_68651_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_68651_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_68651_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_68651_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_68651_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_68651_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_68651_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_68651_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_68651_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_68651_row21_col1" class="data row21 col1" >b7b1</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_68651_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_68651_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_68651_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_68651_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_68651_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_68651_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_68651_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_68651_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_68651_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_68651_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_68651_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_68651_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_68651_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_68651_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_68651_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_68651_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_68651_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_68651_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_68651_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <

# %%
best_model6 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_dc5db_ th {
#   text-align: left;
# }
# #T_dc5db_row0_col0, #T_dc5db_row0_col2, #T_dc5db_row0_col3, #T_dc5db_row0_col4, #T_dc5db_row0_col5, #T_dc5db_row0_col6, #T_dc5db_row0_col7, #T_dc5db_row1_col0, #T_dc5db_row1_col2, #T_dc5db_row1_col3, #T_dc5db_row1_col4, #T_dc5db_row1_col5, #T_dc5db_row1_col6, #T_dc5db_row1_col7, #T_dc5db_row2_col0, #T_dc5db_row2_col2, #T_dc5db_row2_col3, #T_dc5db_row2_col4, #T_dc5db_row2_col5, #T_dc5db_row2_col6, #T_dc5db_row2_col7, #T_dc5db_row3_col0, #T_dc5db_row3_col2, #T_dc5db_row3_col3, #T_dc5db_row3_col5, #T_dc5db_row3_col6, #T_dc5db_row3_col7, #T_dc5db_row4_col0, #T_dc5db_row4_col1, #T_dc5db_row4_col3, #T_dc5db_row4_col4, #T_dc5db_row4_col5, #T_dc5db_row4_col6, #T_dc5db_row4_col7, #T_dc5db_row5_col0, #T_dc5db_row5_col1, #T_dc5db_row5_col2, #T_dc5db_row5_col3, #T_dc5db_row5_col4, #T_dc5db_row5_col5, #T_dc5db_row5_col6, #T_dc5db_row5_col7, #T_dc5db_row6_col0, #T_dc5db_row6_col1, #T_dc5db_row6_col2, #T_dc5db_row6_col3, #T_dc5db_row6_col4, #T_dc5db_row6_col5, #T_dc5db_row6_col6, #T_dc5db_row6_col7, #T_dc5db_row7_col0, #T_dc5db_row7_col1, #T_dc5db_row7_col2, #T_dc5db_row7_col3, #T_dc5db_row7_col4, #T_dc5db_row7_col5, #T_dc5db_row7_col6, #T_dc5db_row7_col7, #T_dc5db_row8_col0, #T_dc5db_row8_col1, #T_dc5db_row8_col2, #T_dc5db_row8_col3, #T_dc5db_row8_col4, #T_dc5db_row8_col5, #T_dc5db_row8_col6, #T_dc5db_row8_col7, #T_dc5db_row9_col0, #T_dc5db_row9_col1, #T_dc5db_row9_col2, #T_dc5db_row9_col3, #T_dc5db_row9_col4, #T_dc5db_row9_col5, #T_dc5db_row10_col0, #T_dc5db_row10_col1, #T_dc5db_row10_col2, #T_dc5db_row10_col3, #T_dc5db_row10_col4, #T_dc5db_row10_col5, #T_dc5db_row10_col6, #T_dc5db_row10_col7, #T_dc5db_row11_col0, #T_dc5db_row11_col1, #T_dc5db_row11_col2, #T_dc5db_row11_col3, #T_dc5db_row11_col4, #T_dc5db_row11_col5, #T_dc5db_row11_col6, #T_dc5db_row11_col7, #T_dc5db_row12_col0, #T_dc5db_row12_col1, #T_dc5db_row12_col2, #T_dc5db_row12_col4, #T_dc5db_row12_col6, #T_dc5db_row12_col7 {
#   text-align: left;
# }
# #T_dc5db_row0_col1, #T_dc5db_row1_col1, #T_dc5db_row2_col1, #T_dc5db_row3_col1, #T_dc5db_row3_col4, #T_dc5db_row4_col2, #T_dc5db_row9_col6, #T_dc5db_row9_col7, #T_dc5db_row12_col3, #T_dc5db_row12_col5 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_dc5db_row0_col8, #T_dc5db_row1_col8, #T_dc5db_row2_col8, #T_dc5db_row3_col8, #T_dc5db_row4_col8, #T_dc5db_row6_col8, #T_dc5db_row7_col8, #T_dc5db_row8_col8, #T_dc5db_row9_col8, #T_dc5db_row10_col8, #T_dc5db_row11_col8, #T_dc5db_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_dc5db_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_dc5db_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dc5db_level0_row0" class="row_heading level0 row0" >lr</th>
#       <td id="T_dc5db_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_dc5db_row0_col1" class="data row0 col1" >0.9160</td>
#       <td id="T_dc5db_row0_col2" class="data row0 col2" >0.5260</td>
#       <td id="T_dc5db_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_dc5db_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_dc5db_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_dc5db_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_dc5db_row0_col7" class="data row0 col7" >0.0000</td>
#       <td id="T_dc5db_row0_col8" class="data row0 col8" >9.0510</td>
#     </tr>
#     <tr>
#       <th id="T_dc5db_level0_row1" class="row_heading level0 row1" >ridge</th>
#       <td id="T_dc5db_row1_col0" class="data row1 col0" >Ridge Classifier</td>
#       <td id="T_dc5db_row1_col1" class="data row1 col1" >0.9160</td>
#       <td id="T_dc5db_row1_col2" class="data row1 col2" >0.0000</td>
#       <td id="T_dc5db_row1_col3" class="data row1 col3" >0.0000</td>
#       <td id="T_dc5db_row1_col4" class="data row1 col4" >0.0000</td>
#       <td id="T_dc5db_row1_col5" class="data row1 col5" >0.0000</td>
#       <td id="T_dc5db_row1_col6" class="data row1 col6" >0.0000</td>
#       <td id="T_dc5db_row1_col7" class="data row1 col7" >0.0000</td>
#       <td id="T_dc5db_row1_col8" class="data row1 col8" >0.3200</td>
#     </tr>
#     <tr>
#       <th id="T_dc5db_level0_row2" class="row_heading level0 row2" >ada</th>
#       <td id="T_dc5db_row2_col0" class="data row2 col0" >Ada Boost Classifier</td>
#       <td id="T_dc5db_row2_col1" class="data row2 col1" >0.9160</td>
#       <td id="T_dc5db_row2_col2" class="data row2 col2" >0.7351</td>
#       <td id="T_dc5db_row2_col3" class="data row2 col3" >0.0090</td>
#       <td id="T_dc5db_row2_col4" class="data row2 col4" >0.4950</td>
#       <td id="T_dc5db_row2_col5" class="data row2 col5" >0.0177</td>
#       <td id="T_dc5db_row2_col6" class="data row2 col6" >0.0147</td>
#       <td id="T_dc5db_row2_col7" class="data row2 col7" >0.0575</td>
#       <td id="T_dc5db_row2_col8" class="data row2 col8" >5.6470</td>
#     </tr>
#     <tr>
#       <th id="T_dc5db_level0_row3" class="row_heading level0 row3" >lightgbm</th>
#       <td id="T_dc5db_row3_col0" class="data row3 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_dc5db_row3_col1" class="data row3 col1" >0.9160</td>
#       <td id="T_dc5db_row3_col2" class="data row3 col2" >0.7374</td>
#       <td id="T_dc5db_row3_col3" class="data row3 col3" >0.0061</td>
#       <td id="T_dc5db_row3_col4" class="data row3 col4" >0.4974</td>
#       <td id="T_dc5db_row3_col5" class="data row3 col5" >0.0120</td>
#       <td id="T_dc5db_row3_col6" class="data row3 col6" >0.0100</td>
#       <td id="T_dc5db_row3_col7" class="data row3 col7" >0.0473</td>
#       <td id="T_dc5db_row3_col8" class="data row3 col8" >1.3960</td>
#     </tr>
#     <tr>
#       <th id="T_dc5db_level0_row4" class="row_heading level0 row4" >gbc</th>
#       <td id="T_dc5db_row4_col0" class="data row4 col0" >Gradient Boosting Classifier</td>
#       <td id="T_dc5db_row4_col1" class="data row4 col1" >0.9159</td>
#       <td id="T_dc5db_row4_col2" class="data row4 col2" >0.7375</td>
#       <td id="T_dc5db_row4_col3" class="data row4 col3" >0.0066</td>
#       <td id="T_dc5db_row4_col4" class="data row4 col4" >0.4788</td>
#       <td id="T_dc5db_row4_col5" class="data row4 col5" >0.0130</td>
#       <td id="T_dc5db_row4_col6" class="data row4 col6" >0.0108</td>
#       <td id="T_dc5db_row4_col7" class="data row4 col7" >0.0482</td>
#       <td id="T_dc5db_row4_col8" class="data row4 col8" >25.6850</td>
#     </tr>
#     <tr>
#       <th id="T_dc5db_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_dc5db_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_dc5db_row5_col1" class="data row5 col1" >0.9158</td>
#       <td id="T_dc5db_row5_col2" class="data row5 col2" >0.5786</td>
#       <td id="T_dc5db_row5_col3" class="data row5 col3" >0.0003</td>
#       <td id="T_dc5db_row5_col4" class="data row5 col4" >0.1250</td>
#       <td id="T_dc5db_row5_col5" class="data row5 col5" >0.0006</td>
#       <td id="T_dc5db_row5_col6" class="data row5 col6" >0.0001</td>
#       <td id="T_dc5db_row5_col7" class="data row5 col7" >0.0017</td>
#       <td id="T_dc5db_row5_col8" class="data row5 col8" >0.1950</td>
#     </tr>
#     <tr>
#       <th id="T_dc5db_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_dc5db_row6_col0" class="data row6 col0" >Random Forest Classifier</td>
#       <td id="T_dc5db_row6_col1" class="data row6 col1" >0.9158</td>
#       <td id="T_dc5db_row6_col2" class="data row6 col2" >0.7097</td>
#       <td id="T_dc5db_row6_col3" class="data

# %%
pred_holdout_mod41 = predict_model(best_model6[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_df4b3_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_df4b3_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_df4b3_row0_col0" class="data row0 col0" >Logistic Regression</td>
#       <td id="T_df4b3_row0_col1" class="data row0 col1" >0.9168</td>
#       <td id="T_df4b3_row0_col2" class="data row0 col2" >0.5280</td>
#       <td id="T_df4b3_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_df4b3_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_df4b3_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_df4b3_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_df4b3_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod42 = predict_model(best_model6[1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_dbc3c_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dbc3c_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dbc3c_row0_col0" class="data row0 col0" >Ridge Classifier</td>
#       <td id="T_dbc3c_row0_col1" class="data row0 col1" >0.9168</td>
#       <td id="T_dbc3c_row0_col2" class="data row0 col2" >0.5000</td>
#       <td id="T_dbc3c_row0_col3" class="data row0 col3" >0.0000</td>
#       <td id="T_dbc3c_row0_col4" class="data row0 col4" >0.0000</td>
#       <td id="T_dbc3c_row0_col5" class="data row0 col5" >0.0000</td>
#       <td id="T_dbc3c_row0_col6" class="data row0 col6" >0.0000</td>
#       <td id="T_dbc3c_row0_col7" class="data row0 col7" >0.0000</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod43 = predict_model(best_model6[2])
# Out:
# <style type="text/css">
# </style>
# <table id="T_3170e_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3170e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3170e_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_3170e_row0_col1" class="data row0 col1" >0.9169</td>
#       <td id="T_3170e_row0_col2" class="data row0 col2" >0.7381</td>
#       <td id="T_3170e_row0_col3" class="data row0 col3" >0.0097</td>
#       <td id="T_3170e_row0_col4" class="data row0 col4" >0.5255</td>
#       <td id="T_3170e_row0_col5" class="data row0 col5" >0.0191</td>
#       <td id="T_3170e_row0_col6" class="data row0 col6" >0.0162</td>
#       <td id="T_3170e_row0_col7" class="data row0 col7" >0.0630</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model6[0])

# %%
plot_model(best_model6[1])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\SUDHIR~1\AppData\Local\Temp/ipykernel_8396/1512282060.py in <module>
# ----> 1 plot_model(best_model6[1])
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\pycaret\classification.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, use_train_data, verbose, display_format)
#    1538     """
#    1539
# -> 1540     return pycaret.internal.tabular.plot_model(
#    1541         estimator=estimator,
#    1542         plot=plot,
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\pycaret\internal\tabular.py in plot_model(estimator, plot, scale, save, fold, fit_kwargs, groups, feature_name, label, use_train_data, verbose, system, display, display_format, is_in_evaluate)
#    5827     # checking for auc plot
#    5828     if not hasattr(estimator, "predict_proba") and plot == "auc":
# -> 5829         raise TypeError(
#    5830             "AUC plot not available for estimators with no predict_proba attribute."
#    5831         )
#
# TypeError: AUC plot not available for estimators with no predict_proba attribute.

# %%
plot_model(best_model6[2])

# %%
evaluate_model(best_model6[0])
# Out:
#                   Parameters
# C                        1.0
# class_weight            None
# dual                   False
# fit_intercept           True
# intercept_scaling          1
# l1_ratio                None
# max_iter                1000
# multi_class             auto
# n_jobs                  None
# penalty                   l2
# random_state             123
# solver                 lbfgs
# tol                   0.0001
# verbose                    0
# warm_start             False

# %%
best_model6[0].get_params
# Out:
# <bound method BaseEstimator.get_params of LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='auto', n_jobs=None, penalty='l2',
#                    random_state=123, solver='lbfgs', tol=0.0001, verbose=0,
#                    warm_start=False)>

# %% [markdown]
# #### DATASET WITH ENN

# %%
dataset_path = '4NOVtrain_enn_balanced.csv'
train_df_w_ENN = pd.read_csv(dataset_path, parse_dates=True, keep_date_col=True)
print(' Train data shape: ', train_df_w_ENN.shape)
# Out:
#  Train data shape:  (245802, 75)

# %%
data = train_df_w_ENN[feat_common_rfe_step_fwd]

# %%
print(' Train data shape: ', data.shape)
# Out:
#  Train data shape:  (245802, 14)

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_b1b1d_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_b1b1d_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b1b1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b1b1d_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_b1b1d_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b1b1d_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_b1b1d_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_b1b1d_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_b1b1d_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_b1b1d_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_b1b1d_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_b1b1d_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_b1b1d_row4_col1" class="data row4 col1" >(245802, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_b1b1d_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_b1b1d_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_b1b1d_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_b1b1d_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_b1b1d_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_b1b1d_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_b1b1d_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_b1b1d_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_b1b1d_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_b1b1d_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_b1b1d_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_b1b1d_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_b1b1d_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_b1b1d_row11_col1" class="data row11 col1" >(172061, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_b1b1d_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_b1b1d_row12_col1" class="data row12 col1" >(73741, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_b1b1d_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_b1b1d_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_b1b1d_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_b1b1d_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_b1b1d_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_b1b1d_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_b1b1d_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_b1b1d_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_b1b1d_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_b1b1d_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_b1b1d_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_b1b1d_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_b1b1d_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_b1b1d_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_b1b1d_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_b1b1d_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_b1b1d_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_b1b1d_row21_col1" class="data row21 col1" >7f76</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_b1b1d_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_b1b1d_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_b1b1d_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_b1b1d_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_b1b1d_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_b1b1d_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_b1b1d_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_b1b1d_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_b1b1d_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_b1b1d_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_b1b1d_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_b1b1d_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_b1b1d_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_b1b1d_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_b1b1d_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_b1b1d_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_b1b1d_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_b1b1d_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_b1b1d_row30_col1" class="data row30 col1" >None</td>
#     </tr>
#     <

# %%
best_model6 = compare_models(n_select = 3)
# Out:
# <style type="text/css">
# #T_100b4_ th {
#   text-align: left;
# }
# #T_100b4_row0_col0, #T_100b4_row0_col2, #T_100b4_row0_col3, #T_100b4_row0_col5, #T_100b4_row0_col6, #T_100b4_row0_col7, #T_100b4_row1_col0, #T_100b4_row1_col3, #T_100b4_row1_col4, #T_100b4_row1_col5, #T_100b4_row1_col6, #T_100b4_row1_col7, #T_100b4_row2_col0, #T_100b4_row2_col1, #T_100b4_row2_col2, #T_100b4_row2_col3, #T_100b4_row2_col4, #T_100b4_row2_col5, #T_100b4_row2_col6, #T_100b4_row2_col7, #T_100b4_row3_col0, #T_100b4_row3_col1, #T_100b4_row3_col2, #T_100b4_row3_col3, #T_100b4_row3_col4, #T_100b4_row3_col5, #T_100b4_row3_col6, #T_100b4_row3_col7, #T_100b4_row4_col0, #T_100b4_row4_col1, #T_100b4_row4_col2, #T_100b4_row4_col3, #T_100b4_row4_col4, #T_100b4_row4_col5, #T_100b4_row4_col6, #T_100b4_row4_col7, #T_100b4_row5_col0, #T_100b4_row5_col1, #T_100b4_row5_col2, #T_100b4_row5_col3, #T_100b4_row5_col4, #T_100b4_row5_col5, #T_100b4_row5_col6, #T_100b4_row5_col7, #T_100b4_row6_col0, #T_100b4_row6_col1, #T_100b4_row6_col2, #T_100b4_row6_col3, #T_100b4_row6_col4, #T_100b4_row6_col5, #T_100b4_row6_col6, #T_100b4_row6_col7, #T_100b4_row7_col0, #T_100b4_row7_col1, #T_100b4_row7_col2, #T_100b4_row7_col3, #T_100b4_row7_col4, #T_100b4_row7_col5, #T_100b4_row7_col6, #T_100b4_row7_col7, #T_100b4_row8_col0, #T_100b4_row8_col1, #T_100b4_row8_col2, #T_100b4_row8_col3, #T_100b4_row8_col4, #T_100b4_row8_col5, #T_100b4_row8_col6, #T_100b4_row8_col7, #T_100b4_row9_col0, #T_100b4_row9_col1, #T_100b4_row9_col2, #T_100b4_row9_col3, #T_100b4_row9_col4, #T_100b4_row9_col5, #T_100b4_row10_col0, #T_100b4_row10_col1, #T_100b4_row10_col2, #T_100b4_row10_col3, #T_100b4_row10_col4, #T_100b4_row10_col5, #T_100b4_row10_col6, #T_100b4_row10_col7, #T_100b4_row11_col0, #T_100b4_row11_col1, #T_100b4_row11_col2, #T_100b4_row11_col3, #T_100b4_row11_col4, #T_100b4_row11_col6, #T_100b4_row11_col7, #T_100b4_row12_col0, #T_100b4_row12_col1, #T_100b4_row12_col2, #T_100b4_row12_col4, #T_100b4_row12_col5, #T_100b4_row12_col6, #T_100b4_row12_col7 {
#   text-align: left;
# }
# #T_100b4_row0_col1, #T_100b4_row0_col4, #T_100b4_row1_col1, #T_100b4_row1_col2, #T_100b4_row9_col6, #T_100b4_row9_col7, #T_100b4_row11_col5, #T_100b4_row12_col3 {
#   text-align: left;
#   background-color: yellow;
# }
# #T_100b4_row0_col8, #T_100b4_row1_col8, #T_100b4_row2_col8, #T_100b4_row3_col8, #T_100b4_row4_col8, #T_100b4_row6_col8, #T_100b4_row7_col8, #T_100b4_row8_col8, #T_100b4_row9_col8, #T_100b4_row10_col8, #T_100b4_row11_col8, #T_100b4_row12_col8 {
#   text-align: left;
#   background-color: lightgrey;
# }
# #T_100b4_row5_col8 {
#   text-align: left;
#   background-color: yellow;
#   background-color: lightgrey;
# }
# </style>
# <table id="T_100b4_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#       <th class="col_heading level0 col8" >TT (Sec)</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_100b4_level0_row0" class="row_heading level0 row0" >ada</th>
#       <td id="T_100b4_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_100b4_row0_col1" class="data row0 col1" >0.8993</td>
#       <td id="T_100b4_row0_col2" class="data row0 col2" >0.7422</td>
#       <td id="T_100b4_row0_col3" class="data row0 col3" >0.0206</td>
#       <td id="T_100b4_row0_col4" class="data row0 col4" >0.5364</td>
#       <td id="T_100b4_row0_col5" class="data row0 col5" >0.0396</td>
#       <td id="T_100b4_row0_col6" class="data row0 col6" >0.0324</td>
#       <td id="T_100b4_row0_col7" class="data row0 col7" >0.0898</td>
#       <td id="T_100b4_row0_col8" class="data row0 col8" >4.6140</td>
#     </tr>
#     <tr>
#       <th id="T_100b4_level0_row1" class="row_heading level0 row1" >gbc</th>
#       <td id="T_100b4_row1_col0" class="data row1 col0" >Gradient Boosting Classifier</td>
#       <td id="T_100b4_row1_col1" class="data row1 col1" >0.8993</td>
#       <td id="T_100b4_row1_col2" class="data row1 col2" >0.7460</td>
#       <td id="T_100b4_row1_col3" class="data row1 col3" >0.0193</td>
#       <td id="T_100b4_row1_col4" class="data row1 col4" >0.5359</td>
#       <td id="T_100b4_row1_col5" class="data row1 col5" >0.0372</td>
#       <td id="T_100b4_row1_col6" class="data row1 col6" >0.0304</td>
#       <td id="T_100b4_row1_col7" class="data row1 col7" >0.0869</td>
#       <td id="T_100b4_row1_col8" class="data row1 col8" >20.4850</td>
#     </tr>
#     <tr>
#       <th id="T_100b4_level0_row2" class="row_heading level0 row2" >lightgbm</th>
#       <td id="T_100b4_row2_col0" class="data row2 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_100b4_row2_col1" class="data row2 col1" >0.8991</td>
#       <td id="T_100b4_row2_col2" class="data row2 col2" >0.7458</td>
#       <td id="T_100b4_row2_col3" class="data row2 col3" >0.0193</td>
#       <td id="T_100b4_row2_col4" class="data row2 col4" >0.5131</td>
#       <td id="T_100b4_row2_col5" class="data row2 col5" >0.0371</td>
#       <td id="T_100b4_row2_col6" class="data row2 col6" >0.0301</td>
#       <td id="T_100b4_row2_col7" class="data row2 col7" >0.0843</td>
#       <td id="T_100b4_row2_col8" class="data row2 col8" >1.0510</td>
#     </tr>
#     <tr>
#       <th id="T_100b4_level0_row3" class="row_heading level0 row3" >lr</th>
#       <td id="T_100b4_row3_col0" class="data row3 col0" >Logistic Regression</td>
#       <td id="T_100b4_row3_col1" class="data row3 col1" >0.8990</td>
#       <td id="T_100b4_row3_col2" class="data row3 col2" >0.5350</td>
#       <td id="T_100b4_row3_col3" class="data row3 col3" >0.0000</td>
#       <td id="T_100b4_row3_col4" class="data row3 col4" >0.0000</td>
#       <td id="T_100b4_row3_col5" class="data row3 col5" >0.0000</td>
#       <td id="T_100b4_row3_col6" class="data row3 col6" >0.0000</td>
#       <td id="T_100b4_row3_col7" class="data row3 col7" >0.0000</td>
#       <td id="T_100b4_row3_col8" class="data row3 col8" >0.6510</td>
#     </tr>
#     <tr>
#       <th id="T_100b4_level0_row4" class="row_heading level0 row4" >ridge</th>
#       <td id="T_100b4_row4_col0" class="data row4 col0" >Ridge Classifier</td>
#       <td id="T_100b4_row4_col1" class="data row4 col1" >0.8990</td>
#       <td id="T_100b4_row4_col2" class="data row4 col2" >0.0000</td>
#       <td id="T_100b4_row4_col3" class="data row4 col3" >0.0000</td>
#       <td id="T_100b4_row4_col4" class="data row4 col4" >0.0000</td>
#       <td id="T_100b4_row4_col5" class="data row4 col5" >0.0000</td>
#       <td id="T_100b4_row4_col6" class="data row4 col6" >0.0000</td>
#       <td id="T_100b4_row4_col7" class="data row4 col7" >0.0000</td>
#       <td id="T_100b4_row4_col8" class="data row4 col8" >0.1350</td>
#     </tr>
#     <tr>
#       <th id="T_100b4_level0_row5" class="row_heading level0 row5" >nb</th>
#       <td id="T_100b4_row5_col0" class="data row5 col0" >Naive Bayes</td>
#       <td id="T_100b4_row5_col1" class="data row5 col1" >0.8989</td>
#       <td id="T_100b4_row5_col2" class="data row5 col2" >0.5880</td>
#       <td id="T_100b4_row5_col3" class="data row5 col3" >0.0003</td>
#       <td id="T_100b4_row5_col4" class="data row5 col4" >0.1429</td>
#       <td id="T_100b4_row5_col5" class="data row5 col5" >0.0007</td>
#       <td id="T_100b4_row5_col6" class="data row5 col6" >0.0002</td>
#       <td id="T_100b4_row5_col7" class="data row5 col7" >0.0026</td>
#       <td id="T_100b4_row5_col8" class="data row5 col8" >0.1230</td>
#     </tr>
#     <tr>
#       <th id="T_100b4_level0_row6" class="row_heading level0 row6" >rf</th>
#       <td id="T_100b4_row6_col0" class="data row6 col0" >Random Forest Classifier</td>
#       <td id="T_100b4_row6_col1" class="data row6 col1" >0.8988</td>
#       <td id="T_100b4_row6_col2" class="data row6 col2" >0.7230</td>
#       <td id="T_100b4_row6_col3" class="data

# %%
pred_holdout_mod41 = predict_model(best_model6[0])
# Out:
# <style type="text/css">
# </style>
# <table id="T_15bec_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15bec_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15bec_row0_col0" class="data row0 col0" >Ada Boost Classifier</td>
#       <td id="T_15bec_row0_col1" class="data row0 col1" >0.8993</td>
#       <td id="T_15bec_row0_col2" class="data row0 col2" >0.7399</td>
#       <td id="T_15bec_row0_col3" class="data row0 col3" >0.0205</td>
#       <td id="T_15bec_row0_col4" class="data row0 col4" >0.5067</td>
#       <td id="T_15bec_row0_col5" class="data row0 col5" >0.0393</td>
#       <td id="T_15bec_row0_col6" class="data row0 col6" >0.0317</td>
#       <td id="T_15bec_row0_col7" class="data row0 col7" >0.0862</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod42 = predict_model(best_model6[1])
# Out:
# <style type="text/css">
# </style>
# <table id="T_03bba_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_03bba_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_03bba_row0_col0" class="data row0 col0" >Gradient Boosting Classifier</td>
#       <td id="T_03bba_row0_col1" class="data row0 col1" >0.8993</td>
#       <td id="T_03bba_row0_col2" class="data row0 col2" >0.7440</td>
#       <td id="T_03bba_row0_col3" class="data row0 col3" >0.0172</td>
#       <td id="T_03bba_row0_col4" class="data row0 col4" >0.5120</td>
#       <td id="T_03bba_row0_col5" class="data row0 col5" >0.0333</td>
#       <td id="T_03bba_row0_col6" class="data row0 col6" >0.0269</td>
#       <td id="T_03bba_row0_col7" class="data row0 col7" >0.0797</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_holdout_mod43 = predict_model(best_model6[2])
# Out:
# <style type="text/css">
# </style>
# <table id="T_70f3a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70f3a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70f3a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_70f3a_row0_col1" class="data row0 col1" >0.8993</td>
#       <td id="T_70f3a_row0_col2" class="data row0 col2" >0.7428</td>
#       <td id="T_70f3a_row0_col3" class="data row0 col3" >0.0192</td>
#       <td id="T_70f3a_row0_col4" class="data row0 col4" >0.5144</td>
#       <td id="T_70f3a_row0_col5" class="data row0 col5" >0.0371</td>
#       <td id="T_70f3a_row0_col6" class="data row0 col6" >0.0300</td>
#       <td id="T_70f3a_row0_col7" class="data row0 col7" >0.0845</td>
#     </tr>
#   </tbody>
# </table>

# %%
plot_model(best_model6[0])

# %%
plot_model(best_model6[1])

# %%
plot_model(best_model6[2])

# %%
evaluate_model(best_model6[0])
# Out:
#                Parameters
# algorithm         SAMME.R
# base_estimator       None
# learning_rate         1.0
# n_estimators           50
# random_state          123

# %% [markdown]
# # Model Explanability

# %%
dataset_path = '4NOVtrain_sm_tomek_balanced.csv'
train_imbalanced_sm_tk = pd.read_csv(dataset_path, parse_dates=True, keep_date_col=True)
print(' Train data shape: ', train_imbalanced_sm_tk.shape)
# Out:
#  Train data shape:  (562710, 75)

# %%
train_imbalanced = train_imbalanced_sm_tk

# %%
data = train_imbalanced[feat_common_rfe_step_fwd]

# %%
data.shape
# Out:
# (562710, 14)

# %%
data = setup(data = data, target = 'TARGET', session_id=123)
# Out:
# <style type="text/css">
# #T_eeff9_row44_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_eeff9_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Description</th>
#       <th class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_eeff9_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_eeff9_row0_col0" class="data row0 col0" >session_id</td>
#       <td id="T_eeff9_row0_col1" class="data row0 col1" >123</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_eeff9_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_eeff9_row1_col1" class="data row1 col1" >TARGET</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_eeff9_row2_col0" class="data row2 col0" >Target Type</td>
#       <td id="T_eeff9_row2_col1" class="data row2 col1" >Binary</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_eeff9_row3_col0" class="data row3 col0" >Label Encoded</td>
#       <td id="T_eeff9_row3_col1" class="data row3 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_eeff9_row4_col0" class="data row4 col0" >Original Data</td>
#       <td id="T_eeff9_row4_col1" class="data row4 col1" >(562710, 14)</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_eeff9_row5_col0" class="data row5 col0" >Missing Values</td>
#       <td id="T_eeff9_row5_col1" class="data row5 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_eeff9_row6_col0" class="data row6 col0" >Numeric Features</td>
#       <td id="T_eeff9_row6_col1" class="data row6 col1" >13</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_eeff9_row7_col0" class="data row7 col0" >Categorical Features</td>
#       <td id="T_eeff9_row7_col1" class="data row7 col1" >0</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_eeff9_row8_col0" class="data row8 col0" >Ordinal Features</td>
#       <td id="T_eeff9_row8_col1" class="data row8 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_eeff9_row9_col0" class="data row9 col0" >High Cardinality Features</td>
#       <td id="T_eeff9_row9_col1" class="data row9 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_eeff9_row10_col0" class="data row10 col0" >High Cardinality Method</td>
#       <td id="T_eeff9_row10_col1" class="data row10 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_eeff9_row11_col0" class="data row11 col0" >Transformed Train Set</td>
#       <td id="T_eeff9_row11_col1" class="data row11 col1" >(393896, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_eeff9_row12_col0" class="data row12 col0" >Transformed Test Set</td>
#       <td id="T_eeff9_row12_col1" class="data row12 col1" >(168814, 13)</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_eeff9_row13_col0" class="data row13 col0" >Shuffle Train-Test</td>
#       <td id="T_eeff9_row13_col1" class="data row13 col1" >True</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_eeff9_row14_col0" class="data row14 col0" >Stratify Train-Test</td>
#       <td id="T_eeff9_row14_col1" class="data row14 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_eeff9_row15_col0" class="data row15 col0" >Fold Generator</td>
#       <td id="T_eeff9_row15_col1" class="data row15 col1" >StratifiedKFold</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_eeff9_row16_col0" class="data row16 col0" >Fold Number</td>
#       <td id="T_eeff9_row16_col1" class="data row16 col1" >10</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_eeff9_row17_col0" class="data row17 col0" >CPU Jobs</td>
#       <td id="T_eeff9_row17_col1" class="data row17 col1" >-1</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_eeff9_row18_col0" class="data row18 col0" >Use GPU</td>
#       <td id="T_eeff9_row18_col1" class="data row18 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_eeff9_row19_col0" class="data row19 col0" >Log Experiment</td>
#       <td id="T_eeff9_row19_col1" class="data row19 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row20" class="row_heading level0 row20" >20</th>
#       <td id="T_eeff9_row20_col0" class="data row20 col0" >Experiment Name</td>
#       <td id="T_eeff9_row20_col1" class="data row20 col1" >clf-default-name</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row21" class="row_heading level0 row21" >21</th>
#       <td id="T_eeff9_row21_col0" class="data row21 col0" >USI</td>
#       <td id="T_eeff9_row21_col1" class="data row21 col1" >aafd</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row22" class="row_heading level0 row22" >22</th>
#       <td id="T_eeff9_row22_col0" class="data row22 col0" >Imputation Type</td>
#       <td id="T_eeff9_row22_col1" class="data row22 col1" >simple</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row23" class="row_heading level0 row23" >23</th>
#       <td id="T_eeff9_row23_col0" class="data row23 col0" >Iterative Imputation Iteration</td>
#       <td id="T_eeff9_row23_col1" class="data row23 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row24" class="row_heading level0 row24" >24</th>
#       <td id="T_eeff9_row24_col0" class="data row24 col0" >Numeric Imputer</td>
#       <td id="T_eeff9_row24_col1" class="data row24 col1" >mean</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row25" class="row_heading level0 row25" >25</th>
#       <td id="T_eeff9_row25_col0" class="data row25 col0" >Iterative Imputation Numeric Model</td>
#       <td id="T_eeff9_row25_col1" class="data row25 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row26" class="row_heading level0 row26" >26</th>
#       <td id="T_eeff9_row26_col0" class="data row26 col0" >Categorical Imputer</td>
#       <td id="T_eeff9_row26_col1" class="data row26 col1" >constant</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row27" class="row_heading level0 row27" >27</th>
#       <td id="T_eeff9_row27_col0" class="data row27 col0" >Iterative Imputation Categorical Model</td>
#       <td id="T_eeff9_row27_col1" class="data row27 col1" >None</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row28" class="row_heading level0 row28" >28</th>
#       <td id="T_eeff9_row28_col0" class="data row28 col0" >Unknown Categoricals Handling</td>
#       <td id="T_eeff9_row28_col1" class="data row28 col1" >least_frequent</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row29" class="row_heading level0 row29" >29</th>
#       <td id="T_eeff9_row29_col0" class="data row29 col0" >Normalize</td>
#       <td id="T_eeff9_row29_col1" class="data row29 col1" >False</td>
#     </tr>
#     <tr>
#       <th id="T_eeff9_level0_row30" class="row_heading level0 row30" >30</th>
#       <td id="T_eeff9_row30_col0" class="data row30 col0" >Normalize Method</td>
#       <td id="T_eeff9_row30_col1" class="data row30 col1" >None</td>
#     </tr>

# %%
lgm = create_model('lightgbm')
# Out:
# <style type="text/css">
# #T_d9911_row10_col0, #T_d9911_row10_col1, #T_d9911_row10_col2, #T_d9911_row10_col3, #T_d9911_row10_col4, #T_d9911_row10_col5, #T_d9911_row10_col6 {
#   background: yellow;
# }
# </style>
# <table id="T_d9911_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Accuracy</th>
#       <th class="col_heading level0 col1" >AUC</th>
#       <th class="col_heading level0 col2" >Recall</th>
#       <th class="col_heading level0 col3" >Prec.</th>
#       <th class="col_heading level0 col4" >F1</th>
#       <th class="col_heading level0 col5" >Kappa</th>
#       <th class="col_heading level0 col6" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d9911_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_d9911_row0_col0" class="data row0 col0" >0.9539</td>
#       <td id="T_d9911_row0_col1" class="data row0 col1" >0.9764</td>
#       <td id="T_d9911_row0_col2" class="data row0 col2" >0.9092</td>
#       <td id="T_d9911_row0_col3" class="data row0 col3" >0.9986</td>
#       <td id="T_d9911_row0_col4" class="data row0 col4" >0.9518</td>
#       <td id="T_d9911_row0_col5" class="data row0 col5" >0.9079</td>
#       <td id="T_d9911_row0_col6" class="data row0 col6" >0.9116</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_d9911_row1_col0" class="data row1 col0" >0.9555</td>
#       <td id="T_d9911_row1_col1" class="data row1 col1" >0.9773</td>
#       <td id="T_d9911_row1_col2" class="data row1 col2" >0.9130</td>
#       <td id="T_d9911_row1_col3" class="data row1 col3" >0.9978</td>
#       <td id="T_d9911_row1_col4" class="data row1 col4" >0.9535</td>
#       <td id="T_d9911_row1_col5" class="data row1 col5" >0.9109</td>
#       <td id="T_d9911_row1_col6" class="data row1 col6" >0.9143</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_d9911_row2_col0" class="data row2 col0" >0.9534</td>
#       <td id="T_d9911_row2_col1" class="data row2 col1" >0.9765</td>
#       <td id="T_d9911_row2_col2" class="data row2 col2" >0.9086</td>
#       <td id="T_d9911_row2_col3" class="data row2 col3" >0.9980</td>
#       <td id="T_d9911_row2_col4" class="data row2 col4" >0.9512</td>
#       <td id="T_d9911_row2_col5" class="data row2 col5" >0.9068</td>
#       <td id="T_d9911_row2_col6" class="data row2 col6" >0.9105</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_d9911_row3_col0" class="data row3 col0" >0.9527</td>
#       <td id="T_d9911_row3_col1" class="data row3 col1" >0.9755</td>
#       <td id="T_d9911_row3_col2" class="data row3 col2" >0.9072</td>
#       <td id="T_d9911_row3_col3" class="data row3 col3" >0.9980</td>
#       <td id="T_d9911_row3_col4" class="data row3 col4" >0.9505</td>
#       <td id="T_d9911_row3_col5" class="data row3 col5" >0.9055</td>
#       <td id="T_d9911_row3_col6" class="data row3 col6" >0.9092</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_d9911_row4_col0" class="data row4 col0" >0.9549</td>
#       <td id="T_d9911_row4_col1" class="data row4 col1" >0.9763</td>
#       <td id="T_d9911_row4_col2" class="data row4 col2" >0.9119</td>
#       <td id="T_d9911_row4_col3" class="data row4 col3" >0.9978</td>
#       <td id="T_d9911_row4_col4" class="data row4 col4" >0.9529</td>
#       <td id="T_d9911_row4_col5" class="data row4 col5" >0.9098</td>
#       <td id="T_d9911_row4_col6" class="data row4 col6" >0.9132</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_d9911_row5_col0" class="data row5 col0" >0.9530</td>
#       <td id="T_d9911_row5_col1" class="data row5 col1" >0.9752</td>
#       <td id="T_d9911_row5_col2" class="data row5 col2" >0.9080</td>
#       <td id="T_d9911_row5_col3" class="data row5 col3" >0.9979</td>
#       <td id="T_d9911_row5_col4" class="data row5 col4" >0.9508</td>
#       <td id="T_d9911_row5_col5" class="data row5 col5" >0.9061</td>
#       <td id="T_d9911_row5_col6" class="data row5 col6" >0.9098</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_d9911_row6_col0" class="data row6 col0" >0.9524</td>
#       <td id="T_d9911_row6_col1" class="data row6 col1" >0.9759</td>
#       <td id="T_d9911_row6_col2" class="data row6 col2" >0.9074</td>
#       <td id="T_d9911_row6_col3" class="data row6 col3" >0.9972</td>
#       <td id="T_d9911_row6_col4" class="data row6 col4" >0.9502</td>
#       <td id="T_d9911_row6_col5" class="data row6 col5" >0.9048</td>
#       <td id="T_d9911_row6_col6" class="data row6 col6" >0.9085</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_d9911_row7_col0" class="data row7 col0" >0.9537</td>
#       <td id="T_d9911_row7_col1" class="data row7 col1" >0.9760</td>
#       <td id="T_d9911_row7_col2" class="data row7 col2" >0.9087</td>
#       <td id="T_d9911_row7_col3" class="data row7 col3" >0.9985</td>
#       <td id="T_d9911_row7_col4" class="data row7 col4" >0.9515</td>
#       <td id="T_d9911_row7_col5" class="data row7 col5" >0.9074</td>
#       <td id="T_d9911_row7_col6" class="data row7 col6" >0.9111</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_d9911_row8_col0" class="data row8 col0" >0.9534</td>
#       <td id="T_d9911_row8_col1" class="data row8 col1" >0.9765</td>
#       <td id="T_d9911_row8_col2" class="data row8 col2" >0.9089</td>
#       <td id="T_d9911_row8_col3" class="data row8 col3" >0.9976</td>
#       <td id="T_d9911_row8_col4" class="data row8 col4" >0.9512</td>
#       <td id="T_d9911_row8_col5" class="data row8 col5" >0.9067</td>
#       <td id="T_d9911_row8_col6" class="data row8 col6" >0.9103</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_d9911_row9_col0" class="data row9 col0" >0.9539</td>
#       <td id="T_d9911_row9_col1" class="data row9 col1" >0.9757</td>
#       <td id="T_d9911_row9_col2" class="data row9 col2" >0.9095</td>
#       <td id="T_d9911_row9_col3" class="data row9 col3" >0.9982</td>
#       <td id="T_d9911_row9_col4" class="data row9 col4" >0.9518</td>
#       <td id="T_d9911_row9_col5" class="data row9 col5" >0.9078</td>
#       <td id="T_d9911_row9_col6" class="data row9 col6" >0.9115</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row10" class="row_heading level0 row10" >Mean</th>
#       <td id="T_d9911_row10_col0" class="data row10 col0" >0.9537</td>
#       <td id="T_d9911_row10_col1" class="data row10 col1" >0.9762</td>
#       <td id="T_d9911_row10_col2" class="data row10 col2" >0.9092</td>
#       <td id="T_d9911_row10_col3" class="data row10 col3" >0.9980</td>
#       <td id="T_d9911_row10_col4" class="data row10 col4" >0.9515</td>
#       <td id="T_d9911_row10_col5" class="data row10 col5" >0.9074</td>
#       <td id="T_d9911_row10_col6" class="data row10 col6" >0.9110</td>
#     </tr>
#     <tr>
#       <th id="T_d9911_level0_row11" class="row_heading level0 row11" >SD</th>
#       <td id="T_d9911_row11_col0" class="data row11 col0" >0.0009</td>
#       <td id="T_d9911_row11_col1" class="data row11 col1" >0.0006</td>
#       <td id="T_d9911_row11_col2" class="data row11 col2" >0.0017</td>
#       <td id="T_d9911_row11_col3" class="data row11 col3" >0.0004</td>
#       <td id="T_d9911_row11_col4" class="data row11 col4" >0.0010</td>
#       <td id="T_d9911_row11_col5" class="data row11 col5" >0.0018</td>
#       <td id="T_d9911_row11_col6" class="data row11 col6" >0.0017</td>
#     </tr>
#   </tbody>
# </table>

# %%
pred_label = predict_model(lgm)
# Out:
# <style type="text/css">
# </style>
# <table id="T_8813a_">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th class="col_heading level0 col0" >Model</th>
#       <th class="col_heading level0 col1" >Accuracy</th>
#       <th class="col_heading level0 col2" >AUC</th>
#       <th class="col_heading level0 col3" >Recall</th>
#       <th class="col_heading level0 col4" >Prec.</th>
#       <th class="col_heading level0 col5" >F1</th>
#       <th class="col_heading level0 col6" >Kappa</th>
#       <th class="col_heading level0 col7" >MCC</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_8813a_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_8813a_row0_col0" class="data row0 col0" >Light Gradient Boosting Machine</td>
#       <td id="T_8813a_row0_col1" class="data row0 col1" >0.9539</td>
#       <td id="T_8813a_row0_col2" class="data row0 col2" >0.9767</td>
#       <td id="T_8813a_row0_col3" class="data row0 col3" >0.9097</td>
#       <td id="T_8813a_row0_col4" class="data row0 col4" >0.9978</td>
#       <td id="T_8813a_row0_col5" class="data row0 col5" >0.9517</td>
#       <td id="T_8813a_row0_col6" class="data row0 col6" >0.9078</td>
#       <td id="T_8813a_row0_col7" class="data row0 col7" >0.9113</td>
#     </tr>
#   </tbody>
# </table>

# %%
interpret_model(lgm)

# %%
# https://github.com/jentseng/CreditRiskClassification_FATML/blob/master/4_Top20_RF_XG_SHAP.ipynb

# %%
import shap
explainer = shap.Explainer(lgm)

# %%
# shap_values = explainer(data, check_additivity=False)

# %%
sample = train_imbalanced[feat_common_rfe_step_fwd].head(10000)
sample.dtypes
# Out:
# BURO_AMT_CREDIT_SUM_SUM             float64
# PREV_HOUR_APPR_PROCESS_START_MIN    float64
# EXT_SOURCE_2                        float64
# INS_AMT_PAYMENT_MIN                 float64
# NEW_EXT_SOURCES_MEAN                float64
# OBS_30_CNT_SOCIAL_CIRCLE            float64
# CNT_FAM_MEMBERS                     float64
# INS_AMT_PAYMENT_SUM                 float64
# PREV_RATE_DOWN_PAYMENT_MIN          float64
# NAME_FAMILY_STATUS_ordered          float64
# NAME_INCOME_TYPE_ordered            float64
# NAME_EDUCATION_TYPE_ordered         float64
# NEW_INC_BY_ORG                      float64
# TARGET                                int64
# dtype: object

# %%
sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column                            Non-Null Count  Dtype
# ---  ------                            --------------  -----
#  0   BURO_AMT_CREDIT_SUM_SUM           10000 non-null  float64
#  1   PREV_HOUR_APPR_PROCESS_START_MIN  10000 non-null  float64
#  2   EXT_SOURCE_2                      10000 non-null  float64
#  3   INS_AMT_PAYMENT_MIN               10000 non-null  float64
#  4   NEW_EXT_SOURCES_MEAN              10000 non-null  float64
#  5   OBS_30_CNT_SOCIAL_CIRCLE          10000 non-null  float64
#  6   CNT_FAM_MEMBERS                   10000 non-null  float64
#  7   INS_AMT_PAYMENT_SUM               10000 non-null  float64
#  8   PREV_RATE_DOWN_PAYMENT_MIN        10000 non-null  float64
#  9   NAME_FAMILY_STATUS_ordered        10000 non-null  float64
#  10  NAME_INCOME_TYPE_ordered          10000 non-null  float64
#  11  NAME_EDUCATION_TYPE_ordered       10000 non-null  float64
#  12  NEW_INC_BY_ORG                    10000 non-null  float64
#  13  TARGET                            10000 non-null  int64
# dtypes: float64(13), int64(1)
# memory usage: 1.1 MB

# %%
shap_values = explainer(sample)
# Out:
# ---------------------------------------------------------------------------
# LightGBMError                             Traceback (most recent call last)
# C:\Users\SUDHIR~1\AppData\Local\Temp/ipykernel_9840/368201700.py in <module>
# ----> 1 shap_values = explainer(sample)
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\shap\explainers\_tree.py in __call__(self, X, y, interactions, check_additivity)
#     214
#     215         if not interactions:
# --> 216             v = self.shap_values(X, y=y, from_call=True, check_additivity=check_additivity, approximate=self.approximate)
#     217             if type(v) is list:
#     218                 v = np.stack(v, axis=-1) # put outputs at the end
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\shap\explainers\_tree.py in shap_values(self, X, y, tree_limit, approximate, check_additivity, from_call)
#     345             elif self.model.model_type == "lightgbm":
#     346                 assert not approximate, "approximate=True is not supported for LightGBM models!"
# --> 347                 phi = self.model.original_model.predict(X, num_iteration=tree_limit, pred_contrib=True)
#     348                 # Note: the data must be joined on the last axis
#     349                 if self.model.original_model.params['objective'] == 'binary':
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\lightgbm\basic.py in predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape, **kwargs)
#    3536             else:
#    3537                 num_iteration = -1
# -> 3538         return predictor.predict(data, start_iteration, num_iteration,
#    3539                                  raw_score, pred_leaf, pred_contrib,
#    3540                                  data_has_header, is_reshape)
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\lightgbm\basic.py in predict(self, data, start_iteration, num_iteration, raw_score, pred_leaf, pred_contrib, data_has_header, is_reshape)
#     846             preds, nrow = self.__pred_for_csc(data, start_iteration, num_iteration, predict_type)
#     847         elif isinstance(data, np.ndarray):
# --> 848             preds, nrow = self.__pred_for_np2d(data, start_iteration, num_iteration, predict_type)
#     849         elif isinstance(data, list):
#     850             try:
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\lightgbm\basic.py in __pred_for_np2d(self, mat, start_iteration, num_iteration, predict_type)
#     936             return preds, nrow
#     937         else:
# --> 938             return inner_predict(mat, start_iteration, num_iteration, predict_type)
#     939
#     940     def __create_sparse_native(self, cs, out_shape, out_ptr_indptr, out_ptr_indices, out_ptr_data,
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\lightgbm\basic.py in inner_predict(mat, start_iteration, num_iteration, predict_type, preds)
#     906                 raise ValueError("Wrong length of pre-allocated predict array")
#     907             out_num_preds = ctypes.c_int64(0)
# --> 908             _safe_call(_LIB.LGBM_BoosterPredictForMat(
#     909                 self.handle,
#     910                 ptr_data,
#
# c:\users\sudhirtelkar\anaconda3\envs\newpycaret\lib\site-packages\lightgbm\basic.py in _safe_call(ret)
#     123     """
#     124     if ret != 0:
# --> 125         raise LightGBMError(_LIB.LGBM_GetLastError().decode('utf-8'))
#     126
#     127
#
# LightGBMError: The number of features in data (14) is not the same as it was in training data (13).
# You can set ``predict_disable_shape_check=true`` to discard this error, but please be aware what you are doing.

# %% [markdown]
# ### Tuning Models

# %% [markdown]
# Compare model just evaluates using the default hyperparameters, tune model will use cross validation to tune the models, here we will tune top 3 models selected in compare models.

# %%
tune_model(best_model[0])

# %%
tune_model(best_model[1])

# %%
tune_model(best_model[2])

# %% [markdown]
# ### Dimensionality Reduction using PCA

# %%
features = train_imbalanced

# %%
# features = train_wo_imbalance

# %%
features.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 17982 entries, 0 to 17981
# Columns: 178 entries, index to TARGET
# dtypes: float64(30), int64(19), uint8(129)
# memory usage: 8.9 MB

# %%
X = features
y = features['TARGET']

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components = 2)
X_train = pca.fit_transform(X_train)
X_test = pca.transform(X_test)
explained_variance = pca.explained_variance_ratio_

# %%
explained_variance
# Out:
# array([0.94569089, 0.03947777])
